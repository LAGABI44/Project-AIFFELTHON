# %% [markdown]
# # 당뇨와 고혈압 질병 예측
# - BTH_G : 연령(그룹)
# - SBP : 수축기혈압
# - DBP : 이완기혈압
# - FBS : 공복혈당
# - SEX : 성별(남성:1, 여성:2)
# - DIS : 고혈압/당뇨병 진료여부
#   - 고혈압/당뇨병 진료내역 있음: 1
#   - 고혈압 진료내역 있음: 2
#   - 당뇨병 진료내역 있음: 3
#   - 고혈압/당뇨병 진료내역 없음: 4
# - BMI : 체질량지수

# %% [markdown]
# ## 정상 vs 비정상
# - 4(정상) : 0
# - 1 / 2 / 3(비정상) : 1
#
# - 0(정상) 기준으로 1(비정상) 오버샘플링 : RandomOversampling
# - 1(비정상) : 1 / 2 / 3 각각 레이블링 됨
#
# 1 / 2 / 3 = 비율) 1 : 3 : 1
# => 1 : 1 : 1 비율로 오버샘플링
#
# 1 / 0 = 비율) 1 : 3
# => 1 : 1 비율로 오버샘플링

# %% [markdown]
# # LightGBM
# +
# ## RandomOversampling + 질병 1, 2, 3 비율 => 1 : 1 : 1

# %% [markdown]
# ### LightGBM 설치:
#
# ```
# pip3 install lightgbm
#
# ```

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np 
import pandas as pd # 시리즈, 데이터프레임 포맷 데이터 처리를 위한 라이브러리
import warnings; warnings.filterwarnings(action='ignore') # 경고 메시지 무시
import matplotlib.pyplot as plt # 데이터 시각화 라이브러리
import pickle # 객체 입출력을 위한 라이브러리

from sklearn.model_selection import train_test_split # 훈련 데이터, 테스트 데이터 분리
from sklearn.preprocessing import StandardScaler # 정규화

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import mean_squared_error, r2_score


# LightGBM 임포트
from lightgbm import LGBMClassifier # LightGBM 불러오기

from pandas.core.common import random_state
from sklearn.ensemble import RandomForestClassifier # 랜덤포레스트 분류 알고리즘
from sklearn.tree import DecisionTreeClassifier # 의사결정나무 분류 알고리즘

import matplotlib.pyplot as plt
import seaborn as sns

# 모델 평가를 위한 metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, plot_confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %% [markdown]
# ## 데이터 불러오기

# %%
# Disease 

df = pd.read_csv('/content/drive/MyDrive/health/data/data(over_dis_vs_nor).csv', encoding='cp949')
df
# Out:
#          SEX  BTH_G  SBP  DBP  FBS   BMI  DIS  Dis
# 0          0      1   90   50   86  20.1    2    1
# 1          0      1  120   80   90  27.0    3    1
# 2          0      1  100   60  112  31.8    2    1
# 3          0      1  170  120   86  23.3    2    1
# 4          0      1  135   80  104  35.0    2    1
# ...      ...    ...  ...  ...  ...   ...  ...  ...
# 1481319    1     21  130   90  185  26.3    3    1
# 1481320    1     18  140  100  120  28.8    2    1
# 1481321    0     12  100   60  101  23.0    3    1
# 1481322    1     20  134   72  168  23.1    3    1
# 1481323    1     23  140   90  116  23.7    2    1
#
# [1481324 rows x 8 columns]

# %%
df.drop(df[df['Dis']==0].index, inplace=True)
df
# Out:
#          SEX  BTH_G  SBP  DBP  FBS   BMI  DIS  Dis
# 0          0      1   90   50   86  20.1    2    1
# 1          0      1  120   80   90  27.0    3    1
# 2          0      1  100   60  112  31.8    2    1
# 3          0      1  170  120   86  23.3    2    1
# 4          0      1  135   80  104  35.0    2    1
# ...      ...    ...  ...  ...  ...   ...  ...  ...
# 1481319    1     21  130   90  185  26.3    3    1
# 1481320    1     18  140  100  120  28.8    2    1
# 1481321    0     12  100   60  101  23.0    3    1
# 1481322    1     20  134   72  168  23.1    3    1
# 1481323    1     23  140   90  116  23.7    2    1
#
# [740662 rows x 8 columns]

# %%
# 1,0 정답 레이블 삭제
df.drop(['Dis'], axis=1, inplace=True)
df
# Out:
#          SEX  BTH_G  SBP  DBP  FBS   BMI  DIS
# 0          0      1   90   50   86  20.1    2
# 1          0      1  120   80   90  27.0    3
# 2          0      1  100   60  112  31.8    2
# 3          0      1  170  120   86  23.3    2
# 4          0      1  135   80  104  35.0    2
# ...      ...    ...  ...  ...  ...   ...  ...
# 1481319    1     21  130   90  185  26.3    3
# 1481320    1     18  140  100  120  28.8    2
# 1481321    0     12  100   60  101  23.0    3
# 1481322    1     20  134   72  168  23.1    3
# 1481323    1     23  140   90  116  23.7    2
#
# [740662 rows x 7 columns]

# %%
df.reset_index()
# Out:
#           index  SEX  BTH_G  SBP  DBP  FBS   BMI  DIS
# 0             0    0      1   90   50   86  20.1    2
# 1             1    0      1  120   80   90  27.0    3
# 2             2    0      1  100   60  112  31.8    2
# 3             3    0      1  170  120   86  23.3    2
# 4             4    0      1  135   80  104  35.0    2
# ...         ...  ...    ...  ...  ...  ...   ...  ...
# 740657  1481319    1     21  130   90  185  26.3    3
# 740658  1481320    1     18  140  100  120  28.8    2
# 740659  1481321    0     12  100   60  101  23.0    3
# 740660  1481322    1     20  134   72  168  23.1    3
# 740661  1481323    1     23  140   90  116  23.7    2
#
# [740662 rows x 8 columns]

# %%
df.reset_index(drop=True)
# Out:
#         SEX  BTH_G  SBP  DBP  FBS   BMI  DIS
# 0         0      1   90   50   86  20.1    2
# 1         0      1  120   80   90  27.0    3
# 2         0      1  100   60  112  31.8    2
# 3         0      1  170  120   86  23.3    2
# 4         0      1  135   80  104  35.0    2
# ...     ...    ...  ...  ...  ...   ...  ...
# 740657    1     21  130   90  185  26.3    3
# 740658    1     18  140  100  120  28.8    2
# 740659    0     12  100   60  101  23.0    3
# 740660    1     20  134   72  168  23.1    3
# 740661    1     23  140   90  116  23.7    2
#
# [740662 rows x 7 columns]

# %%
df.sample(frac=1.0, replace=False, weights=None, random_state=None, axis=None, ignore_index=False)
# Out:
#          SEX  BTH_G  SBP  DBP  FBS   BMI  DIS
# 1400105    1     27  130   70  103  24.2    2
# 358545     1     25  160  100  103  24.8    1
# 1324093    1     18  120   80  113  24.2    3
# 169236     1     18  126   80   86  26.0    2
# 51610      0     17  110   80   88  22.9    2
# ...      ...    ...  ...  ...  ...   ...  ...
# 1477690    0     12  127   79  187  29.8    3
# 58423      0     18  130   70   80  28.3    1
# 1259644    0     13  120   70  119  26.8    3
# 182436     1     19  128   70   89  25.2    2
# 200778     1     22  134   84  107  25.8    1
#
# [740662 rows x 7 columns]

# %%
df.reset_index()
# Out:
#           index  SEX  BTH_G  SBP  DBP  FBS   BMI  DIS
# 0             0    0      1   90   50   86  20.1    2
# 1             1    0      1  120   80   90  27.0    3
# 2             2    0      1  100   60  112  31.8    2
# 3             3    0      1  170  120   86  23.3    2
# 4             4    0      1  135   80  104  35.0    2
# ...         ...  ...    ...  ...  ...  ...   ...  ...
# 740657  1481319    1     21  130   90  185  26.3    3
# 740658  1481320    1     18  140  100  120  28.8    2
# 740659  1481321    0     12  100   60  101  23.0    3
# 740660  1481322    1     20  134   72  168  23.1    3
# 740661  1481323    1     23  140   90  116  23.7    2
#
# [740662 rows x 8 columns]

# %%
df.reset_index(drop=True)
# Out:
#         SEX  BTH_G  SBP  DBP  FBS   BMI  DIS
# 0         0      1   90   50   86  20.1    2
# 1         0      1  120   80   90  27.0    3
# 2         0      1  100   60  112  31.8    2
# 3         0      1  170  120   86  23.3    2
# 4         0      1  135   80  104  35.0    2
# ...     ...    ...  ...  ...  ...   ...  ...
# 740657    1     21  130   90  185  26.3    3
# 740658    1     18  140  100  120  28.8    2
# 740659    0     12  100   60  101  23.0    3
# 740660    1     20  134   72  168  23.1    3
# 740661    1     23  140   90  116  23.7    2
#
# [740662 rows x 7 columns]

# %%
df.notnull().sum()
# Out:
# SEX      740662
# BTH_G    740662
# SBP      740662
# DBP      740662
# FBS      740662
# BMI      740662
# DIS      740662
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 740662 entries, 0 to 1481323
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   SEX     740662 non-null  int64
#  1   BTH_G   740662 non-null  int64
#  2   SBP     740662 non-null  int64
#  3   DBP     740662 non-null  int64
#  4   FBS     740662 non-null  int64
#  5   BMI     740662 non-null  float64
#  6   DIS     740662 non-null  int64
# dtypes: float64(1), int64(6)
# memory usage: 45.2 MB

# %%
# feature와 target 분리(설명변수 및 목표변수 분리)
x = df.drop(['DIS'], axis=1) # df[df.columns.difference(['target'])]
y = np.array(df['DIS']) # y = df['target']

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x)
x_test = sc.transform(x)

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2, random_state=42) # 기본 0.25
# x_test,x_val,y_test,y_val=train_test_split(x,y,test_size=0.1, random_state=42)

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# print(x_val.shape)
# print(y_val.shape)
# Out:
# (592529, 6)
# (592529,)
# (148133, 6)
# (148133,)

# %% [markdown]
# ### lightgbm 파라미터 정의

# %%
hyper_params = {
    'num_iterations': 25000,
    'task': 'train',
    'boosting_type': 'gbdt',
    'objective': 'multiclass',
    'metric': 'multi_logloss', # ['auc_mu', 'multi_error', 
    'learning_rate': 0.1, # 0.005
    'feature_fraction': 1.0, # 0.9
    'bagging_fraction': 1.0, # 0.7
    'bagging_freq': 10,
    'verbose': 0,
    'max_depth': 8, # 20
    # 'min_data' : 20
    # 'min_child_samples' =60
    'num_leaves': 128, # 31
    'max_bin': 512, # 255
    # 'device' : 'gpu'
}

# %% [markdown]
# ### 훈련

# %%
from lightgbm import LGBMClassifier

lgb = LGBMClassifier(**hyper_params)
evals = [(x_train, y_train),(x_test, y_test)]

lgb.fit(x_train, y_train, eval_set = evals, early_stopping_rounds=100, verbose = True) # eval_metric='multi_auc'
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# [13003]	training's multi_logloss: 0.114109	valid_1's multi_logloss: 0.273535
# [13004]	training's multi_logloss: 0.114106	valid_1's multi_logloss: 0.273535
# [13005]	training's multi_logloss: 0.114097	valid_1's multi_logloss: 0.273531
# [13006]	training's multi_logloss: 0.114078	valid_1's multi_logloss: 0.273524
# [13007]	training's multi_logloss: 0.114071	valid_1's multi_logloss: 0.273524
# [13008]	training's multi_logloss: 0.114065	valid_1's multi_logloss: 0.273525
# [13009]	training's multi_logloss: 0.114049	valid_1's multi_logloss: 0.273519
# [13010]	training's multi_logloss: 0.114039	valid_1's multi_logloss: 0.273514
# [13011]	training's multi_logloss: 0.114006	valid_1's multi_logloss: 0.273493
# [13012]	training's multi_logloss: 0.113989	valid_1's multi_logloss: 0.273483
# [13013]	training's multi_logloss: 0.113984	valid_1's multi_logloss: 0.273489
# [13014]	training's multi_logloss: 0.113982	valid_1's multi_logloss: 0.273492
# [13015]	training's multi_logloss: 0.113979	valid_1's multi_logloss: 0.273495
# [13016]	training's multi_logloss: 0.11397	valid_1's multi_logloss: 0.273491
# [13017]	training's multi_logloss: 0.113958	valid_1's multi_logloss: 0.273483
# [13018]	training's multi_logloss: 0.113952	valid_1's multi_logloss: 0.273478
# [13019]	training's multi_logloss: 0.113936	valid_1's multi_logloss: 0.273466
# [13020]	training's multi_logloss: 0.113927	valid_1's multi_logloss: 0.273466
# [13021]	training's multi_logloss: 0.113918	valid_1's multi_logloss: 0.273456
# [13022]	training's multi_logloss: 0.11391	valid_1's multi_logloss: 0.273448
# [13023]	training's multi_logloss: 0.113898	valid_1's multi_logloss: 0.27344
# [13024]	training's multi_logloss: 0.113893	valid_1's multi_logloss: 0.27344
# [13025]	training's multi_logloss: 0.113889	valid_1's multi_logloss: 0.273438
# [13026]	training's multi_logloss: 0.113876	valid_1's multi_logloss: 0.273433
# [13027]	training's multi_logloss: 0.113868	valid_1's multi_logloss: 0.273431
# [13028]	training's multi_logloss: 0.113855	valid_1's multi_logloss: 0.273433
# [13029]	training's multi_logloss: 0.113843	valid_1's multi_logloss: 0.273421
# [13030]	training's multi_logloss: 0.113825	valid_1's multi_logloss: 0.273414
# [13031]	training's multi_logloss: 0.113814	valid_1's multi_logloss: 0.273408
# [13032]	training's multi_logloss: 0.113798	valid_1's multi_logloss: 0.273394
# [13033]	training's multi_logloss: 0.113763	valid_1's multi_logloss: 0.27337
# [13034]	training's multi_logloss: 0.113749	valid_1's multi_logloss: 0.273358
# [13035]	training's multi_logloss: 0.113729	valid_1's multi_logloss: 0.273354
# [13036]	training's multi_logloss: 0.113706	valid_1's multi_logloss: 0.273337
# [13037]	training's multi_logloss: 0.11367	valid_1's multi_logloss: 0.273316
# [13038]	training's multi_logloss: 0.11365	valid_1's multi_logloss: 0.273302
# [13039]	training's multi_logloss: 0.113634	valid_1's multi_logloss: 0.273289
# [13040]	training's multi_logloss: 0.1136	valid_1's multi_logloss: 0.273255
# [13041]	training's multi_logloss: 0.113586	valid_1's multi_logloss: 0.273247
# [13042]	training's multi_logloss: 0.113566	valid_1's multi_logloss: 0.273237
# [13043]	training's multi_logloss: 0.113553	valid_1's multi_logloss: 0.273237
# [13044]	training's multi_logloss: 0.113524	valid_1's multi_logloss: 0.273216
# [13045]	training's multi_logloss: 0.113487	valid_1's multi_logloss: 0.273196
# [13046]	training's multi_logloss: 0.113443	valid_1's multi_logloss: 0.273156
# [13047]	training's multi_logloss: 0.113427	valid_1's multi_logloss: 0.273147
# [13048]	training's multi_logloss: 0.113395	valid_1's multi_logloss: 0.27312
# [13049]	training's multi_logloss: 0.113377	valid_1's multi_logloss: 0.273103
# [13050]	training's multi_logloss: 0.113357	valid_1's multi_logloss: 0.273085
# [13051]	training's multi_logloss: 0.113335	valid_1's multi_logloss: 0.273065
# [13052]	training's multi_logloss: 0.113313	valid_1's multi_logloss: 0.273046
# [13053]	training's multi_logloss: 0.113288	valid_1's multi_logloss: 0.273029
# [13054]	training's multi_logloss: 0.113271	valid_1's multi_logloss: 0.273014
# [13055]	training's multi_logloss: 0.11326	valid_1's multi_logloss: 0.273007
# [13056]	training's multi_logloss: 0.113255	valid_1's multi_logloss: 0.273004
# [13057]	training's multi_logloss: 0.11324	valid_1's multi_logloss: 0.27299
# [13058]	training's multi_logloss: 0.113222	valid_1's multi_logloss: 0.272978
# [13059]	training's multi_logloss: 0.113217	valid_1's multi_logloss: 0.272975
# [13060]	training's multi_logloss: 0.113203	valid_1's multi_logloss: 0.272962
# [13061]	training's multi_logloss: 0.113192	valid_1's multi_logloss: 0.27296
# [13062]	training's multi_logloss: 0.113165	valid_1's multi_logloss: 0.272934
# [13063]	training's multi_logloss: 0.113147	valid_1's multi_logloss: 0.272919
# [13064]	training's multi_logloss: 0.113136	valid_1's multi_logloss: 0.272915
# [13065]	training's multi_logloss: 0.113118	valid_1's multi_logloss: 0.2729
# [13066]	training's multi_logloss: 0.11311	valid_1's multi_logloss: 0.272897
# [13067]	training's multi_logloss: 0.113095	valid_1's multi_logloss: 0.272887
# [13068]	training's multi_logloss: 0.113077	valid_1's multi_logloss: 0.272873
# [13069]	training's multi_logloss: 0.113068	valid_1's multi_logloss: 0.272871
# [13070]	training's multi_logloss: 0.113055	valid_1's multi_logloss: 0.272863
# [13071]	training's multi_logloss: 0.113035	valid_1's multi_logloss: 0.272856
# [13072]	training's multi_logloss: 0.113023	valid_1's multi_logloss: 0.272854
# [13073]	training's multi_logloss: 0.112999	valid_1's multi_logloss: 0.27283
# [13074]	training's multi_logloss: 0.112989	valid_1's multi_logloss: 0.272822
# [13075]	training's multi_logloss: 0.112972	valid_1's multi_logloss: 0.272808
# [13076]	training's multi_logloss: 0.112943	valid_1's multi_logloss: 0.272778
# [13077]	training's multi_logloss: 0.112934	valid_1's multi_logloss: 0.27277
# [13078]	training's multi_logloss: 0.112926	valid_1's multi_logloss: 0.272768
# [13079]	training's multi_logloss: 0.11291	valid_1's multi_logloss: 0.272759
# [13080]	training's multi_logloss: 0.112906	valid_1's multi_logloss: 0.272759
# [13081]	training's multi_logloss: 0.112899	valid_1's multi_logloss: 0.272762
# [13082]	training's multi_logloss: 0.112895	valid_1's multi_logloss: 0.272764
# [13083]	training's multi_logloss: 0.112873	valid_1's multi_logloss: 0.272749
# [13084]	training's multi_logloss: 0.112865	valid_1's multi_logloss: 0.272745
# [13085]	training's multi_logloss: 0.112857	valid_1's multi_logloss: 0.272741
# [13086]	training's multi_logloss: 0.112852	valid_1's multi_logloss: 0.272743
# [13087]	training's multi_logloss: 0.112834	valid_1's multi_logloss: 0.272733
# [13088]	training's multi_logloss: 0.112787	valid_1's multi_logloss: 0.272685
# [13089]	training's multi_logloss: 0.112759	valid_1's multi_logloss: 0.272663
# [13090]	training's multi_logloss: 0.112743	valid_1's multi_logloss: 0.272662
# [13091]	training's multi_logloss: 0.112732	valid_1's multi_logloss: 0.272651
# [13092]	training's multi_logloss: 0.112715	valid_1's multi_logloss: 0.272639
# [13093]	training's multi_logloss: 0.112682	valid_1's multi_logloss: 0.272613
# [13094]	training's multi_logloss: 0.112674	valid_1's multi_logloss: 0.272609
# [13095]	training's multi_logloss: 0.112659	valid_1's multi_logloss: 0.272595
# [13096]	training's multi_logloss: 0.112651	valid_1's multi_logloss: 0.272589
# [13097]	training's multi_logloss: 0.112647	valid_1's multi_logloss: 0.27259
# [13098]	training's multi_logloss: 0.112629	valid_1's multi_logloss: 0.272577
# [13099]	training's multi_logloss: 0.112591	valid_1's multi_logloss: 0.272541
# [13100]	training's multi_logloss: 0.112552	valid_1's multi_logloss: 0.272504
# [13101]	training's multi_logloss: 0.112528	valid_1's multi_logloss: 0.272476
# [13102]	training's multi_logloss: 0.112514	valid_1's multi_logloss: 0.272462
# [13103]	training's multi_logloss: 0.112489	valid_1's multi_logloss: 0.27245
# [13104]	training's multi_logloss: 0.112465	valid_1's multi_logloss: 0.272436
# [13105]	training's multi_logloss: 0.112449	valid_1's multi_logloss: 0.272423
# [13106]	training's multi_logloss: 0.11241	valid_1's multi_logloss: 0.272392
# [13107]	training's multi_logloss: 0.112381	valid_1's multi_logloss: 0.272371
# [13108]	training's multi_logloss: 0.112362	valid_1's multi_logloss: 0.272353
# [13109]	training's multi_logloss: 0.112352	valid_1's multi_logloss: 0.272349
# [13110]	training's multi_logloss: 0.112349	valid_1's multi_logloss: 0.272352
# [13111]	training's multi_logloss: 0.112327	valid_1's multi_logloss: 0.272336
# [13112]	training's multi_logloss: 0.112317	valid_1's multi_logloss: 0.272327
# [13113]	training's multi_logloss: 0.112292	valid_1's multi_logloss: 0.272304
# [13114]	training's multi_logloss: 0.112272	valid_1's multi_logloss: 0.272294
# [13115]	training's multi_logloss: 0.112251	valid_1's multi_logloss: 0.272279
# [13116]	training's multi_logloss: 0.112238	valid_1's multi_logloss: 0.272269
# [13117]	training's multi_logloss: 0.11222	valid_1's multi_logloss: 0.272256
# [13118]	training's multi_logloss: 0.112207	valid_1's multi_logloss: 0.272246
# [13119]	training's multi_logloss: 0.112193	valid_1's multi_logloss: 0.272235
# [13120]	training's multi_logloss: 0.112155	valid_1's multi_logloss: 0.272194
# [13121]	training's multi_logloss: 0.112121	valid_1's multi_logloss: 0.272155
# [13122]	training's multi_logloss: 0.112081	valid_1's multi_logloss: 0.272114
# [13123]	training's multi_logloss: 0.112061	valid_1's multi_logloss: 0.272097
# [13124]	training's multi_logloss: 0.11205	valid_1's multi_logloss: 0.272089
# [13125]	training's multi_logloss: 0.112025	valid_1's multi_logloss: 0.272066
# [13126]	training's multi_logloss: 0.11201	valid_1's multi_logloss: 0.27205
# [13127]	training's multi_logloss: 0.112	valid_1's multi_logloss: 0.272039
# [13128]	training's multi_logloss: 0.11199	valid_1's multi_logloss: 0.272032
# [13129]	training's multi_logloss: 0.111988	valid_1's multi_logloss: 0.272037
# [13130]	training's multi_logloss: 0.111981	valid_1's multi_logloss: 0.272032
# [13131]	training's multi_logloss: 0.111957	valid_1's multi_logloss: 0.272018
# [13132]	training's multi_logloss: 0.111941	valid_1's multi_logloss: 0.272004
# [13133]	training's multi_logloss: 0.111934	valid_1's multi_logloss: 0.271998
# [13134]	training's multi_logloss: 0.11192	valid_1's multi_logloss: 0.27199
# [13135]	training's multi_logloss: 0.111913	valid_1's multi_logloss: 0.271983
# [13136]	training's multi_logloss: 0.111903	valid_1's multi_logloss: 0.271976
# [13137]	training's multi_logloss: 0.111896	valid_1's multi_logloss: 0.271972
# [13138]	training's multi_logloss: 0.111893	valid_1's multi_logloss: 0.271974
# [13139]	training's multi_logloss: 0.111884	valid_1's multi_logloss: 0.271972
# [13140]	training's multi_logloss: 0.111878	valid_1's multi_logloss: 0.27197
# [13141]	training's multi_logloss: 0.111873	valid_1's multi_logloss: 0.271968
# [13142]	training's multi_logloss: 0.111864	valid_1's multi_logloss: 0.271961
# [13143]	training's multi_logloss: 0.111845	valid_1's multi_logloss: 0.271945
# [13144]	training's multi_logloss: 0.111836	valid_1's multi_logloss: 0.271935
# [13145]	training's multi_logloss: 0.111828	valid_1's multi_logloss: 0.271928
# [13146]	training's multi_logloss: 0.111806	valid_1's multi_logloss: 0.271911
# [13147]	training's multi_logloss: 0.111798	valid_1's multi_logloss: 0.271911
# [13148]	training's multi_logloss: 0.111793	valid_1's multi_logloss: 0.271906
# [13149]	training's multi_logloss: 0.111787	valid_1's multi_logloss: 0.271914
# [13150]	training's multi_logloss: 0.111782	valid_1's multi_logloss: 0.271916
# [13151]	training's multi_logloss: 0.111776	valid_1's multi_logloss: 0.271911
# [13152]	training's multi_logloss: 0.111766	valid_1's multi_logloss: 0.271911
# [13153]	training's multi_logloss: 0.111746	valid_1's multi_logloss: 0.271906
# [13154]	training's multi_logloss: 0.111724	valid_1's multi_logloss: 0.271885
# [13155]	training's multi_logloss: 0.111712	valid_1's multi_logloss: 0.271878
# [13156]	training's multi_logloss: 0.111691	valid_1's multi_logloss: 0.271868
# [13157]	training's multi_logloss: 0.111684	valid_1's multi_logloss: 0.271865
# [13158]	training's multi_logloss: 0.111673	valid_1's multi_logloss: 0.271861
# [13159]	training's multi_logloss: 0.111665	valid_1's multi_logloss: 0.271854
# [13160]	training's multi_logloss: 0.111656	valid_1's multi_logloss: 0.271851
# [13161]	training's multi_logloss: 0.111636	valid_1's multi_logloss: 0.27183
# [13162]	training's multi_logloss: 0.111622	valid_1's multi_logloss: 0.27182
# [13163]	training's multi_logloss: 0.111616	valid_1's multi_logloss: 0.271821
# [13164]	training's multi_logloss: 0.111609	valid_1's multi_logloss: 0.271825
# [13165]	training's multi_logloss: 0.111603	valid_1's multi_logloss: 0.271826
# [13166]	training's multi_logloss: 0.111584	valid_1's multi_logloss: 0.271814
# [13167]	training's multi_logloss: 0.111566	valid_1's multi_logloss: 0.271803
# [13168]	training's multi_logloss: 0.11156	valid_1's multi_logloss: 0.271799
# [13169]	training's multi_logloss: 0.111554	valid_1's multi_logloss: 0.271802
# [13170]	training's multi_logloss: 0.111549	valid_1's multi_logloss: 0.271807
# [13171]	training's multi_logloss: 0.111543	valid_1's multi_logloss: 0.2718
# [13172]	training's multi_logloss: 0.111525	valid_1's multi_logloss: 0.271785
# [13173]	training's multi_logloss: 0.111511	valid_1's multi_logloss: 0.271776
# [13174]	training's multi_logloss: 0.111499	valid_1's multi_logloss: 0.27177
# [13175]	training's multi_logloss: 0.111493	valid_1's multi_logloss: 0.271765
# [13176]	training's multi_logloss: 0.111477	valid_1's multi_logloss: 0.271755
# [13177]	training's multi_logloss: 0.111456	valid_1's multi_logloss: 0.271747
# [13178]	training's multi_logloss: 0.111432	valid_1's multi_logloss: 0.271723
# [13179]	training's multi_logloss: 0.111422	valid_1's multi_logloss: 0.271715
# [13180]	training's multi_logloss: 0.111412	valid_1's multi_logloss: 0.271708
# [13181]	training's multi_logloss: 0.111397	valid_1's multi_logloss: 0.271698
# [13182]	training's multi_logloss: 0.111378	valid_1's multi_logloss: 0.271685
# [13183]	training's multi_logloss: 0.111362	valid_1's multi_logloss: 0.271678
# [13184]	training's multi_logloss: 0.111341	valid_1's multi_logloss: 0.27166
# [13185]	training's multi_logloss: 0.111337	valid_1's multi_logloss: 0.271659
# [13186]	training's multi_logloss: 0.111331	valid_1's multi_logloss: 0.271654
# [13187]	training's multi_logloss: 0.111312	valid_1's multi_logloss: 0.271641
# [13188]	training's multi_logloss: 0.111302	valid_1's multi_logloss: 0.271636
# [13189]	training's multi_logloss: 0.111296	valid_1's multi_logloss: 0.271635
# [13190]	training's multi_logloss: 0.111279	valid_1's multi_logloss: 0.271613
# [13191]	training's multi_logloss: 0.111277	valid_1's multi_logloss: 0.271614
# [13192]	training's multi_logloss: 0.111263	valid_1's multi_logloss: 0.271611
# [13193]	training's multi_logloss: 0.111231	valid_1's multi_logloss: 0.271583
# [13194]	training's multi_logloss: 0.111217	valid_1's multi_logloss: 0.271575
# [13195]	training's multi_logloss: 0.111186	valid_1's multi_logloss: 0.271547
# [13196]	training's multi_logloss: 0.111173	valid_1's multi_logloss: 0.271537
# [13197]	training's multi_logloss: 0.111167	valid_1's multi_logloss: 0.271535
# [13198]	training's multi_logloss: 0.111149	valid_1's multi_logloss: 0.271519
# [13199]	training's multi_logloss: 0.111131	valid_1's multi_logloss: 0.271509
# [13200]	training's multi_logloss: 0.111122	valid_1's multi_logloss: 0.271511
# [13201]	training's multi_logloss: 0.111101	valid_1's multi_logloss: 0.271499
# [13202]	training's multi_logloss: 0.111085	valid_1's multi_logloss: 0.271482
# [13203]	training's multi_logloss: 0.111073	valid_1's multi_logloss: 0.271469
# [13204]	training's multi_logloss: 0.111066	valid_1's multi_logloss: 0.271466
# [13205]	training's multi_logloss: 0.111049	valid_1's multi_logloss: 0.271451
# [13206]	training's multi_logloss: 0.111035	valid_1's multi_logloss: 0.271443
# [13207]	training's multi_logloss: 0.111011	valid_1's multi_logloss: 0.27143
# [13208]	training's multi_logloss: 0.11098	valid_1's multi_logloss: 0.2714
# [13209]	training's multi_logloss: 0.110957	valid_1's multi_logloss: 0.271388
# [13210]	training's multi_logloss: 0.11095	valid_1's multi_logloss: 0.271383
# [13211]	training's multi_logloss: 0.11094	valid_1's multi_logloss: 0.271381
# [13212]	training's multi_logloss: 0.110935	valid_1's multi_logloss: 0.271381
# [13213]	training's multi_logloss: 0.110926	valid_1's multi_logloss: 0.271372
# [13214]	training's multi_logloss: 0.110908	valid_1's multi_logloss: 0.271354
# [13215]	training's multi_logloss: 0.110895	valid_1's multi_logloss: 0.271346
# [13216]	training's multi_logloss: 0.110882	valid_1's multi_logloss: 0.271338
# [13217]	training's multi_logloss: 0.110868	valid_1's multi_logloss: 0.271328
# [13218]	training's multi_logloss: 0.110852	valid_1's multi_logloss: 0.271311
# [13219]	training's multi_logloss: 0.110839	valid_1's multi_logloss: 0.271302
# [13220]	training's multi_logloss: 0.110823	valid_1's multi_logloss: 0.271288
# [13221]	training's multi_logloss: 0.110816	valid_1's multi_logloss: 0.271286
# [13222]	training's multi_logloss: 0.11081	valid_1's multi_logloss: 0.271277
# [13223]	training's multi_logloss: 0.110799	valid_1's multi_logloss: 0.271275
# [13224]	training's multi_logloss: 0.11078	valid_1's multi_logloss: 0.271263
# [13225]	training's multi_logloss: 0.110769	valid_1's multi_logloss: 0.271259
# [13226]	training's multi_logloss: 0.110766	valid_1's multi_logloss: 0.271268
# [13227]	training's multi_logloss: 0.11076	valid_1's multi_logloss: 0.271269
# [13228]	training's multi_logloss: 0.110726	valid_1's multi_logloss: 0.271247
# [13229]	training's multi_logloss: 0.110709	valid_1's multi_logloss: 0.271237
# [13230]	training's multi_logloss: 0.110699	valid_1's multi_logloss: 0.271234
# [13231]	training's multi_logloss: 0.110685	valid_1's multi_logloss: 0.271227
# [13232]	training's multi_logloss: 0.110679	valid_1's multi_logloss: 0.271228
# [13233]	training's multi_logloss: 0.110672	valid_1's multi_logloss: 0.271227
# [13234]	training's multi_logloss: 0.110665	valid_1's multi_logloss: 0.271222
# [13235]	training's multi_logloss: 0.110657	valid_1's multi_logloss: 0.271216
# [13236]	training's multi_logloss: 0.110649	valid_1's multi_logloss: 0.271212
# [13237]	training's multi_logloss: 0.110637	valid_1's multi_logloss: 0.271201
# [13238]	training's multi_logloss: 0.110627	valid_1's multi_logloss: 0.271192
# [13239]	training's multi_logloss: 0.11062	valid_1's multi_logloss: 0.27119
# [13240]	training's multi_logloss: 0.110617	valid_1's multi_logloss: 0.27119
# [13241]	training's multi_logloss: 0.110596	valid_1's multi_logloss: 0.27117
# [13242]	training's multi_logloss: 0.110592	valid_1's multi_logloss: 0.271167
# [13243]	training's multi_logloss: 0.110586	valid_1's multi_logloss: 0.271164
# [13244]	training's multi_logloss: 0.110572	valid_1's multi_logloss: 0.271153
# [13245]	training's multi_logloss: 0.110567	valid_1's multi_logloss: 0.271148
# [13246]	training's multi_logloss: 0.110555	valid_1's multi_logloss: 0.271136
# [13247]	training's multi_logloss: 0.110548	valid_1's multi_logloss: 0.271133
# [13248]	training's multi_logloss: 0.110525	valid_1's multi_logloss: 0.271112
# [13249]	training's multi_logloss: 0.110505	valid_1's multi_logloss: 0.271103
# [13250]	training's multi_logloss: 0.110481	valid_1's multi_logloss: 0.271087
# [13251]	training's multi_logloss: 0.110466	valid_1's multi_logloss: 0.271078
# [13252]	training's multi_logloss: 0.110439	valid_1's multi_logloss: 0.271058
# [13253]	training's multi_logloss: 0.110423	valid_1's multi_logloss: 0.271052
# [13254]	training's multi_logloss: 0.11041	valid_1's multi_logloss: 0.271053
# [13255]	training's multi_logloss: 0.110407	valid_1's multi_logloss: 0.271061
# [13256]	training's multi_logloss: 0.110387	valid_1's multi_logloss: 0.271048
# [13257]	training's multi_logloss: 0.110365	valid_1's multi_logloss: 0.271028
# [13258]	training's multi_logloss: 0.110343	valid_1's multi_logloss: 0.271012
# [13259]	training's multi_logloss: 0.11033	valid_1's multi_logloss: 0.271009
# [13260]	training's multi_logloss: 0.110309	valid_1's multi_logloss: 0.270992
# [13261]	training's multi_logloss: 0.110289	valid_1's multi_logloss: 0.270979
# [13262]	training's multi_logloss: 0.110272	valid_1's multi_logloss: 0.270967
# [13263]	training's multi_logloss: 0.110254	valid_1's multi_logloss: 0.270958
# [13264]	training's multi_logloss: 0.110236	valid_1's multi_logloss: 0.270943
# [13265]	training's multi_logloss: 0.110225	valid_1's multi_logloss: 0.270934
# [13266]	training's multi_logloss: 0.110212	valid_1's multi_logloss: 0.270923
# [13267]	training's multi_logloss: 0.110198	valid_1's multi_logloss: 0.270909
# [13268]	training's multi_logloss: 0.110191	valid_1's multi_logloss: 0.270906
# [13269]	training's multi_logloss: 0.110171	valid_1's multi_logloss: 0.270893
# [13270]	training's multi_logloss: 0.110164	valid_1's multi_logloss: 0.27089
# [13271]	training's multi_logloss: 0.110158	valid_1's multi_logloss: 0.270887
# [13272]	training's multi_logloss: 0.110154	valid_1's multi_logloss: 0.270888
# [13273]	training's multi_logloss: 0.110143	valid_1's multi_logloss: 0.270878
# [13274]	training's multi_logloss: 0.110134	valid_1's multi_logloss: 0.27087
# [13275]	training's multi_logloss: 0.110127	valid_1's multi_logloss: 0.270867
# [13276]	training's multi_logloss: 0.11011	valid_1's multi_logloss: 0.270857
# [13277]	training's multi_logloss: 0.110093	valid_1's multi_logloss: 0.270837
# [13278]	training's multi_logloss: 0.110084	valid_1's multi_logloss: 0.270828
# [13279]	training's multi_logloss: 0.110065	valid_1's multi_logloss: 0.270816
# [13280]	training's multi_logloss: 0.110034	valid_1's multi_logloss: 0.270787
# [13281]	training's multi_logloss: 0.110012	valid_1's multi_logloss: 0.270766
# [13282]	training's multi_logloss: 0.109989	valid_1's multi_logloss: 0.270746
# [13283]	training's multi_logloss: 0.109977	valid_1's multi_logloss: 0.270739
# [13284]	training's multi_logloss: 0.10994	valid_1's multi_logloss: 0.270711
# [13285]	training's multi_logloss: 0.109914	valid_1's multi_logloss: 0.270688
# [13286]	training's multi_logloss: 0.109902	valid_1's multi_logloss: 0.270675
# [13287]	training's multi_logloss: 0.109897	valid_1's multi_logloss: 0.270673
# [13288]	training's multi_logloss: 0.109886	valid_1's multi_logloss: 0.270661
# [13289]	training's multi_logloss: 0.109864	valid_1's multi_logloss: 0.270651
# [13290]	training's multi_logloss: 0.109837	valid_1's multi_logloss: 0.270628
# [13291]	training's multi_logloss: 0.109817	valid_1's multi_logloss: 0.270615
# [13292]	training's multi_logloss: 0.109804	valid_1's multi_logloss: 0.270609
# [13293]	training's multi_logloss: 0.10979	valid_1's multi_logloss: 0.270598
# [13294]	training's multi_logloss: 0.109786	valid_1's multi_logloss: 0.270601
# [13295]	training's multi_logloss: 0.109781	valid_1's multi_logloss: 0.270601
# [13296]	training's multi_logloss: 0.109763	valid_1's multi_logloss: 0.270591
# [13297]	training's multi_logloss: 0.10975	valid_1's multi_logloss: 0.27058
# [13298]	training's multi_logloss: 0.109744	valid_1's multi_logloss: 0.270578
# [13299]	training's multi_logloss: 0.109737	valid_1's multi_logloss: 0.270581
# [13300]	training's multi_logloss: 0.109732	valid_1's multi_logloss: 0.270586
# [13301]	training's multi_logloss: 0.109721	valid_1's multi_logloss: 0.270576
# [13302]	training's multi_logloss: 0.109707	valid_1's multi_logloss: 0.270566
# [13303]	training's multi_logloss: 0.109695	valid_1's multi_logloss: 0.270559
# [13304]	training's multi_logloss: 0.109689	valid_1's multi_logloss: 0.270559
# [13305]	training's multi_logloss: 0.109677	valid_1's multi_logloss: 0.27055
# [13306]	training's multi_logloss: 0.109668	valid_1's multi_logloss: 0.270542
# [13307]	training's multi_logloss: 0.10966	valid_1's multi_logloss: 0.270538
# [13308]	training's multi_logloss: 0.109635	valid_1's multi_logloss: 0.270513
# [13309]	training's multi_logloss: 0.109606	valid_1's multi_logloss: 0.270494
# [13310]	training's multi_logloss: 0.109588	valid_1's multi_logloss: 0.270479
# [13311]	training's multi_logloss: 0.109576	valid_1's multi_logloss: 0.27047
# [13312]	training's multi_logloss: 0.109563	valid_1's multi_logloss: 0.270462
# [13313]	training's multi_logloss: 0.109549	valid_1's multi_logloss: 0.270451
# [13314]	training's multi_logloss: 0.109533	valid_1's multi_logloss: 0.270433
# [13315]	training's multi_logloss: 0.109521	valid_1's multi_logloss: 0.270428
# [13316]	training's multi_logloss: 0.109515	valid_1's multi_logloss: 0.270426
# [13317]	training's multi_logloss: 0.109508	valid_1's multi_logloss: 0.270423
# [13318]	training's multi_logloss: 0.109479	valid_1's multi_logloss: 0.2704
# [13319]	training's multi_logloss: 0.109473	valid_1's multi_logloss: 0.270401
# [13320]	training's multi_logloss: 0.109471	valid_1's multi_logloss: 0.270399
# [13321]	training's multi_logloss: 0.109454	valid_1's multi_logloss: 0.270387
# [13322]	training's multi_logloss: 0.109444	valid_1's multi_logloss: 0.27038
# [13323]	training's multi_logloss: 0.109436	valid_1's multi_logloss: 0.27037
# [13324]	training's multi_logloss: 0.10943	valid_1's multi_logloss: 0.270366
# [13325]	training's multi_logloss: 0.109417	valid_1's multi_logloss: 0.270356
# [13326]	training's multi_logloss: 0.10941	valid_1's multi_logloss: 0.270356
# [13327]	training's multi_logloss: 0.109405	valid_1's multi_logloss: 0.270355
# [13328]	training's multi_logloss: 0.10938	valid_1's multi_logloss: 0.270333
# [13329]	training's multi_logloss: 0.109374	valid_1's multi_logloss: 0.270333
# [13330]	training's multi_logloss: 0.10937	valid_1's multi_logloss: 0.270338
# [13331]	training's multi_logloss: 0.109365	valid_1's multi_logloss: 0.270335
# [13332]	training's multi_logloss: 0.10934	valid_1's multi_logloss: 0.270315
# [13333]	training's multi_logloss: 0.109321	valid_1's multi_logloss: 0.270296
# [13334]	training's multi_logloss: 0.109318	valid_1's multi_logloss: 0.270301
# [13335]	training's multi_logloss: 0.109299	valid_1's multi_logloss: 0.27028
# [13336]	training's multi_logloss: 0.109287	valid_1's multi_logloss: 0.270271
# [13337]	training's multi_logloss: 0.109266	valid_1's multi_logloss: 0.270249
# [13338]	training's multi_logloss: 0.109243	valid_1's multi_logloss: 0.270236
# [13339]	training's multi_logloss: 0.109236	valid_1's multi_logloss: 0.270235
# [13340]	training's multi_logloss: 0.109234	valid_1's multi_logloss: 0.270242
# [13341]	training's multi_logloss: 0.109217	valid_1's multi_logloss: 0.270236
# [13342]	training's multi_logloss: 0.109191	valid_1's multi_logloss: 0.270217
# [13343]	training's multi_logloss: 0.109176	valid_1's multi_logloss: 0.270204
# [13344]	training's multi_logloss: 0.109165	valid_1's multi_logloss: 0.270195
# [13345]	training's multi_logloss: 0.10914	valid_1's multi_logloss: 0.270165
# [13346]	training's multi_logloss: 0.109134	valid_1's multi_logloss: 0.270163
# [13347]	training's multi_logloss: 0.10912	valid_1's multi_logloss: 0.270155
# [13348]	training's multi_logloss: 0.109103	valid_1's multi_logloss: 0.270137
# [13349]	training's multi_logloss: 0.109092	valid_1's multi_logloss: 0.270128
# [13350]	training's multi_logloss: 0.109075	valid_1's multi_logloss: 0.270108
# [13351]	training's multi_logloss: 0.109065	valid_1's multi_logloss: 0.270101
# [13352]	training's multi_logloss: 0.10905	valid_1's multi_logloss: 0.270086
# [13353]	training's multi_logloss: 0.109039	valid_1's multi_logloss: 0.270078
# [13354]	training's multi_logloss: 0.109029	valid_1's multi_logloss: 0.27007
# [13355]	training's multi_logloss: 0.109011	valid_1's multi_logloss: 0.270054
# [13356]	training's multi_logloss: 0.108999	valid_1's multi_logloss: 0.270046
# [13357]	training's multi_logloss: 0.108994	valid_1's multi_logloss: 0.270052
# [13358]	training's multi_logloss: 0.108983	valid_1's multi_logloss: 0.270048
# [13359]	training's multi_logloss: 0.108981	valid_1's multi_logloss: 0.270051
# [13360]	training's multi_logloss: 0.108974	valid_1's multi_logloss: 0.270053
# [13361]	training's multi_logloss: 0.108955	valid_1's multi_logloss: 0.270039
# [13362]	training's multi_logloss: 0.108932	valid_1's multi_logloss: 0.270017
# [13363]	training's multi_logloss: 0.108912	valid_1's multi_logloss: 0.269997
# [13364]	training's multi_logloss: 0.108904	valid_1's multi_logloss: 0.269992
# [13365]	training's multi_logloss: 0.1089	valid_1's multi_logloss: 0.269993
# [13366]	training's multi_logloss: 0.108894	valid_1's multi_logloss: 0.269989
# [13367]	training's multi_logloss: 0.108887	valid_1's multi_logloss: 0.269988
# [13368]	training's multi_logloss: 0.10888	valid_1's multi_logloss: 0.269987
# [13369]	training's multi_logloss: 0.108879	valid_1's multi_logloss: 0.26999
# [13370]	training's multi_logloss: 0.108873	valid_1's multi_logloss: 0.269986
# [13371]	training's multi_logloss: 0.108868	valid_1's multi_logloss: 0.269982
# [13372]	training's multi_logloss: 0.108858	valid_1's multi_logloss: 0.269977
# [13373]	training's multi_logloss: 0.108828	valid_1's multi_logloss: 0.269956
# [13374]	training's multi_logloss: 0.108808	valid_1's multi_logloss: 0.269942
# [13375]	training's multi_logloss: 0.108794	valid_1's multi_logloss: 0.269929
# [13376]	training's multi_logloss: 0.108789	valid_1's multi_logloss: 0.269927
# [13377]	training's multi_logloss: 0.108782	valid_1's multi_logloss: 0.269922
# [13378]	training's multi_logloss: 0.108766	valid_1's multi_logloss: 0.269911
# [13379]	training's multi_logloss: 0.108745	valid_1's multi_logloss: 0.269884
# [13380]	training's multi_logloss: 0.108719	valid_1's multi_logloss: 0.269865
# [13381]	training's multi_logloss: 0.108707	valid_1's multi_logloss: 0.269856
# [13382]	training's multi_logloss: 0.108689	valid_1's multi_logloss: 0.269839
# [13383]	training's multi_logloss: 0.108671	valid_1's multi_logloss: 0.269822
# [13384]	training's multi_logloss: 0.108664	valid_1's multi_logloss: 0.269825
# [13385]	training's multi_logloss: 0.108653	valid_1's multi_logloss: 0.269816
# [13386]	training's multi_logloss: 0.108638	valid_1's multi_logloss: 0.269798
# [13387]	training's multi_logloss: 0.108623	valid_1's multi_logloss: 0.269781
# [13388]	training's multi_logloss: 0.108613	valid_1's multi_logloss: 0.269773
# [13389]	training's multi_logloss: 0.1086	valid_1's multi_logloss: 0.269761
# [13390]	training's multi_logloss: 0.108587	valid_1's multi_logloss: 0.269755
# [13391]	training's multi_logloss: 0.108576	valid_1's multi_logloss: 0.269749
# [13392]	training's multi_logloss: 0.108556	valid_1's multi_logloss: 0.269731
# [13393]	training's multi_logloss: 0.108535	valid_1's multi_logloss: 0.269719
# [13394]	training's multi_logloss: 0.10852	valid_1's multi_logloss: 0.269713
# [13395]	training's multi_logloss: 0.108503	valid_1's multi_logloss: 0.269699
# [13396]	training's multi_logloss: 0.108492	valid_1's multi_logloss: 0.269699
# [13397]	training's multi_logloss: 0.108468	valid_1's multi_logloss: 0.269682
# [13398]	training's multi_logloss: 0.108441	valid_1's multi_logloss: 0.269674
# [13399]	training's multi_logloss: 0.108431	valid_1's multi_logloss: 0.26967
# [13400]	training's multi_logloss: 0.108427	valid_1's multi_logloss: 0.269668
# [13401]	training's multi_logloss: 0.108423	valid_1's multi_logloss: 0.269665
# [13402]	training's multi_logloss: 0.108407	valid_1's multi_logloss: 0.269649
# [13403]	training's multi_logloss: 0.108379	valid_1's multi_logloss: 0.269623
# [13404]	training's multi_logloss: 0.108364	valid_1's multi_logloss: 0.269616
# [13405]	training's multi_logloss: 0.108351	valid_1's multi_logloss: 0.269606
# [13406]	training's multi_logloss: 0.108327	valid_1's multi_logloss: 0.269596
# [13407]	training's multi_logloss: 0.108313	valid_1's multi_logloss: 0.269586
# [13408]	training's multi_logloss: 0.108299	valid_1's multi_logloss: 0.269573
# [13409]	training's multi_logloss: 0.108278	valid_1's multi_logloss: 0.269556
# [13410]	training's multi_logloss: 0.108264	valid_1's multi_logloss: 0.26955
# [13411]	training's multi_logloss: 0.108253	valid_1's multi_logloss: 0.269542
# [13412]	training's multi_logloss: 0.108239	valid_1's multi_logloss: 0.269541
# [13413]	training's multi_logloss: 0.108237	valid_1's multi_logloss: 0.269548
# [13414]	training's multi_logloss: 0.108226	valid_1's multi_logloss: 0.269541
# [13415]	training's multi_logloss: 0.108203	valid_1's multi_logloss: 0.269521
# [13416]	training's multi_logloss: 0.108188	valid_1's multi_logloss: 0.269516
# [13417]	training's multi_logloss: 0.108169	valid_1's multi_logloss: 0.269507
# [13418]	training's multi_logloss: 0.108159	valid_1's multi_logloss: 0.269505
# [13419]	training's multi_logloss: 0.108146	valid_1's multi_logloss: 0.269494
# [13420]	training's multi_logloss: 0.108142	valid_1's multi_logloss: 0.269499
# [13421]	training's multi_logloss: 0.108131	valid_1's multi_logloss: 0.269493
# [13422]	training's multi_logloss: 0.108126	valid_1's multi_logloss: 0.269487
# [13423]	training's multi_logloss: 0.108102	valid_1's multi_logloss: 0.269465
# [13424]	training's multi_logloss: 0.108073	valid_1's multi_logloss: 0.269443
# [13425]	training's multi_logloss: 0.108057	valid_1's multi_logloss: 0.269429
# [13426]	training's multi_logloss: 0.108053	valid_1's multi_logloss: 0.269433
# [13427]	training's multi_logloss: 0.108042	valid_1's multi_logloss: 0.269421
# [13428]	training's multi_logloss: 0.108037	valid_1's multi_logloss: 0.269419
# [13429]	training's multi_logloss: 0.108024	valid_1's multi_logloss: 0.269405
# [13430]	training's multi_logloss: 0.108016	valid_1's multi_logloss: 0.269402
# [13431]	training's multi_logloss: 0.108012	valid_1's multi_logloss: 0.269407
# [13432]	training's multi_logloss: 0.108007	valid_1's multi_logloss: 0.269411
# [13433]	training's multi_logloss: 0.107994	valid_1's multi_logloss: 0.26941
# [13434]	training's multi_logloss: 0.107987	valid_1's multi_logloss: 0.269409
# [13435]	training's multi_logloss: 0.107972	valid_1's multi_logloss: 0.269388
# [13436]	training's multi_logloss: 0.107961	valid_1's multi_logloss: 0.269387
# [13437]	training's multi_logloss: 0.107949	valid_1's multi_logloss: 0.26938
# [13438]	training's multi_logloss: 0.107946	valid_1's multi_logloss: 0.269377
# [13439]	training's multi_logloss: 0.107939	valid_1's multi_logloss: 0.269375
# [13440]	training's multi_logloss: 0.107934	valid_1's multi_logloss: 0.269376
# [13441]	training's multi_logloss: 0.10793	valid_1's multi_logloss: 0.269379
# [13442]	training's multi_logloss: 0.107925	valid_1's multi_logloss: 0.269387
# [13443]	training's multi_logloss: 0.107919	valid_1's multi_logloss: 0.269392
# [13444]	training's multi_logloss: 0.107887	valid_1's multi_logloss: 0.269356
# [13445]	training's multi_logloss: 0.107873	valid_1's multi_logloss: 0.269341
# [13446]	training's multi_logloss: 0.107867	valid_1's multi_logloss: 0.269337
# [13447]	training's multi_logloss: 0.10786	valid_1's multi_logloss: 0.269334
# [13448]	training's multi_logloss: 0.107839	valid_1's multi_logloss: 0.269318
# [13449]	training's multi_logloss: 0.107813	valid_1's multi_logloss: 0.269298
# [13450]	training's multi_logloss: 0.107783	valid_1's multi_logloss: 0.269266
# [13451]	training's multi_logloss: 0.10777	valid_1's multi_logloss: 0.269264
# [13452]	training's multi_logloss: 0.107766	valid_1's multi_logloss: 0.269268
# [13453]	training's multi_logloss: 0.107753	valid_1's multi_logloss: 0.269257
# [13454]	training's multi_logloss: 0.107735	valid_1's multi_logloss: 0.269244
# [13455]	training's multi_logloss: 0.107721	valid_1's multi_logloss: 0.269243
# [13456]	training's multi_logloss: 0.107708	valid_1's multi_logloss: 0.269237
# [13457]	training's multi_logloss: 0.107702	valid_1's multi_logloss: 0.269243
# [13458]	training's multi_logloss: 0.107693	valid_1's multi_logloss: 0.269239
# [13459]	training's multi_logloss: 0.107672	valid_1's multi_logloss: 0.26922
# [13460]	training's multi_logloss: 0.107659	valid_1's multi_logloss: 0.26921
# [13461]	training's multi_logloss: 0.107655	valid_1's multi_logloss: 0.269212
# [13462]	training's multi_logloss: 0.107648	valid_1's multi_logloss: 0.269214
# [13463]	training's multi_logloss: 0.10764	valid_1's multi_logloss: 0.269217
# [13464]	training's multi_logloss: 0.107632	valid_1's multi_logloss: 0.26921
# [13465]	training's multi_logloss: 0.107625	valid_1's multi_logloss: 0.269208
# [13466]	training's multi_logloss: 0.107619	valid_1's multi_logloss: 0.269208
# [13467]	training's multi_logloss: 0.107609	valid_1's multi_logloss: 0.269197
# [13468]	training's multi_logloss: 0.107584	valid_1's multi_logloss: 0.269179
# [13469]	training's multi_logloss: 0.107579	valid_1's multi_logloss: 0.269177
# [13470]	training's multi_logloss: 0.107576	valid_1's multi_logloss: 0.269179
# [13471]	training's multi_logloss: 0.107558	valid_1's multi_logloss: 0.269173
# [13472]	training's multi_logloss: 0.107548	valid_1's multi_logloss: 0.269168
# [13473]	training's multi_logloss: 0.10754	valid_1's multi_logloss: 0.269165
# [13474]	training's multi_logloss: 0.107532	valid_1's multi_logloss: 0.269161
# [13475]	training's multi_logloss: 0.107529	valid_1's multi_logloss: 0.269158
# [13476]	training's multi_logloss: 0.107524	valid_1's multi_logloss: 0.269156
# [13477]	training's multi_logloss: 0.107498	valid_1's multi_logloss: 0.269135
# [13478]	training's multi_logloss: 0.107485	valid_1's multi_logloss: 0.269125
# [13479]	training's multi_logloss: 0.10748	valid_1's multi_logloss: 0.269128
# [13480]	training's multi_logloss: 0.107466	valid_1's multi_logloss: 0.269122
# [13481]	training's multi_logloss: 0.107459	valid_1's multi_logloss: 0.269121
# [13482]	training's multi_logloss: 0.107452	valid_1's multi_logloss: 0.269121
# [13483]	training's multi_logloss: 0.107449	valid_1's multi_logloss: 0.26912
# [13484]	training's multi_logloss: 0.107425	valid_1's multi_logloss: 0.269107
# [13485]	training's multi_logloss: 0.107407	valid_1's multi_logloss: 0.269104
# [13486]	training's multi_logloss: 0.107385	valid_1's multi_logloss: 0.269098
# [13487]	training's multi_logloss: 0.10738	valid_1's multi_logloss: 0.26909
# [13488]	training's multi_logloss: 0.107376	valid_1's multi_logloss: 0.269088
# [13489]	training's multi_logloss: 0.107361	valid_1's multi_logloss: 0.269078
# [13490]	training's multi_logloss: 0.107344	valid_1's multi_logloss: 0.269063
# [13491]	training's multi_logloss: 0.107322	valid_1's multi_logloss: 0.269048
# [13492]	training's multi_logloss: 0.107314	valid_1's multi_logloss: 0.269043
# [13493]	training's multi_logloss: 0.107304	valid_1's multi_logloss: 0.269036
# [13494]	training's multi_logloss: 0.107297	valid_1's multi_logloss: 0.269035
# [13495]	training's multi_logloss: 0.10728	valid_1's multi_logloss: 0.269026
# [13496]	training's multi_logloss: 0.107268	valid_1's multi_logloss: 0.269019
# [13497]	training's multi_logloss: 0.107248	valid_1's multi_logloss: 0.269003
# [13498]	training's multi_logloss: 0.107215	valid_1's multi_logloss: 0.268982
# [13499]	training's multi_logloss: 0.107185	valid_1's multi_logloss: 0.268956
# [13500]	training's multi_logloss: 0.107171	valid_1's multi_logloss: 0.268944
# [13501]	training's multi_logloss: 0.107158	valid_1's multi_logloss: 0.268936
# [13502]	training's multi_logloss: 0.107139	valid_1's multi_logloss: 0.268922
# [13503]	training's multi_logloss: 0.107125	valid_1's multi_logloss: 0.268911
# [13504]	training's multi_logloss: 0.10711	valid_1's multi_logloss: 0.268901
# [13505]	training's multi_logloss: 0.107079	valid_1's multi_logloss: 0.268873
# [13506]	training's multi_logloss: 0.107071	valid_1's multi_logloss: 0.268868
# [13507]	training's multi_logloss: 0.107063	valid_1's multi_logloss: 0.268871
# [13508]	training's multi_logloss: 0.107059	valid_1's multi_logloss: 0.268876
# [13509]	training's multi_logloss: 0.10705	valid_1's multi_logloss: 0.268869
# [13510]	training's multi_logloss: 0.107046	valid_1's multi_logloss: 0.268871
# [13511]	training's multi_logloss: 0.107039	valid_1's multi_logloss: 0.268863
# [13512]	training's multi_logloss: 0.107032	valid_1's multi_logloss: 0.268856
# [13513]	training's multi_logloss: 0.107014	valid_1's multi_logloss: 0.268842
# [13514]	training's multi_logloss: 0.106983	valid_1's multi_logloss: 0.268816
# [13515]	training's multi_logloss: 0.10696	valid_1's multi_logloss: 0.268792
# [13516]	training's multi_logloss: 0.106941	valid_1's multi_logloss: 0.268781
# [13517]	training's multi_logloss: 0.106918	valid_1's multi_logloss: 0.268759
# [13518]	training's multi_logloss: 0.106899	valid_1's multi_logloss: 0.268746
# [13519]	training's multi_logloss: 0.106885	valid_1's multi_logloss: 0.268738
# [13520]	training's multi_logloss: 0.106872	valid_1's multi_logloss: 0.268735
# [13521]	training's multi_logloss: 0.106843	valid_1's multi_logloss: 0.268708
# [13522]	training's multi_logloss: 0.106828	valid_1's multi_logloss: 0.268701
# [13523]	training's multi_logloss: 0.106811	valid_1's multi_logloss: 0.26869
# [13524]	training's multi_logloss: 0.106794	valid_1's multi_logloss: 0.268674
# [13525]	training's multi_logloss: 0.106779	valid_1's multi_logloss: 0.268668
# [13526]	training's multi_logloss: 0.106757	valid_1's multi_logloss: 0.268648
# [13527]	training's multi_logloss: 0.106743	valid_1's multi_logloss: 0.268639
# [13528]	training's multi_logloss: 0.10672	valid_1's multi_logloss: 0.268619
# [13529]	training's multi_logloss: 0.106705	valid_1's multi_logloss: 0.268607
# [13530]	training's multi_logloss: 0.10669	valid_1's multi_logloss: 0.268604
# [13531]	training's multi_logloss: 0.106672	valid_1's multi_logloss: 0.268593
# [13532]	training's multi_logloss: 0.106649	valid_1's multi_logloss: 0.268575
# [13533]	training's multi_logloss: 0.106632	valid_1's multi_logloss: 0.268555
# [13534]	training's multi_logloss: 0.106603	valid_1's multi_logloss: 0.268533
# [13535]	training's multi_logloss: 0.106577	valid_1's multi_logloss: 0.268516
# [13536]	training's multi_logloss: 0.10656	valid_1's multi_logloss: 0.268503
# [13537]	training's multi_logloss: 0.106538	valid_1's multi_logloss: 0.268486
# [13538]	training's multi_logloss: 0.106516	valid_1's multi_logloss: 0.26847
# [13539]	training's multi_logloss: 0.106497	valid_1's multi_logloss: 0.268456
# [13540]	training's multi_logloss: 0.106478	valid_1's multi_logloss: 0.268441
# [13541]	training's multi_logloss: 0.106461	valid_1's multi_logloss: 0.268427
# [13542]	training's multi_logloss: 0.106441	valid_1's multi_logloss: 0.268403
# [13543]	training's multi_logloss: 0.106411	valid_1's multi_logloss: 0.268379
# [13544]	training's multi_logloss: 0.106386	valid_1's multi_logloss: 0.268353
# [13545]	training's multi_logloss: 0.106359	valid_1's multi_logloss: 0.268329
# [13546]	training's multi_logloss: 0.106349	valid_1's multi_logloss: 0.268324
# [13547]	training's multi_logloss: 0.106337	valid_1's multi_logloss: 0.268317
# [13548]	training's multi_logloss: 0.106324	valid_1's multi_logloss: 0.268305
# [13549]	training's multi_logloss: 0.106305	valid_1's multi_logloss: 0.268291
# [13550]	training's multi_logloss: 0.106287	valid_1's multi_logloss: 0.268274
# [13551]	training's multi_logloss: 0.10627	valid_1's multi_logloss: 0.268252
# [13552]	training's multi_logloss: 0.106244	valid_1's multi_logloss: 0.268228
# [13553]	training's multi_logloss: 0.106232	valid_1's multi_logloss: 0.268218
# [13554]	training's multi_logloss: 0.106213	valid_1's multi_logloss: 0.268195
# [13555]	training's multi_logloss: 0.106198	valid_1's multi_logloss: 0.268179
# [13556]	training's multi_logloss: 0.106192	valid_1's multi_logloss: 0.268172
# [13557]	training's multi_logloss: 0.106176	valid_1's multi_logloss: 0.268159
# [13558]	training's multi_logloss: 0.106158	valid_1's multi_logloss: 0.26815
# [13559]	training's multi_logloss: 0.106139	valid_1's multi_logloss: 0.268126
# [13560]	training's multi_logloss: 0.106118	valid_1's multi_logloss: 0.268108
# [13561]	training's multi_logloss: 0.106101	valid_1's multi_logloss: 0.268092
# [13562]	training's multi_logloss: 0.106092	valid_1's multi_logloss: 0.268091
# [13563]	training's multi_logloss: 0.106088	valid_1's multi_logloss: 0.268096
# [13564]	training's multi_logloss: 0.106073	valid_1's multi_logloss: 0.268084
# [13565]	training's multi_logloss: 0.10604	valid_1's multi_logloss: 0.268055
# [13566]	training's multi_logloss: 0.106018	valid_1's multi_logloss: 0.268037
# [13567]	training's multi_logloss: 0.105996	valid_1's multi_logloss: 0.268023
# [13568]	training's multi_logloss: 0.105964	valid_1's multi_logloss: 0.268001
# [13569]	training's multi_logloss: 0.105955	valid_1's multi_logloss: 0.26799
# [13570]	training's multi_logloss: 0.105944	valid_1's multi_logloss: 0.267981
# [13571]	training's multi_logloss: 0.105928	valid_1's multi_logloss: 0.267971
# [13572]	training's multi_logloss: 0.105899	valid_1's multi_logloss: 0.267952
# [13573]	training's multi_logloss: 0.10588	valid_1's multi_logloss: 0.267935
# [13574]	training's multi_logloss: 0.105854	valid_1's multi_logloss: 0.267917
# [13575]	training's multi_logloss: 0.105841	valid_1's multi_logloss: 0.267906
# [13576]	training's multi_logloss: 0.105815	valid_1's multi_logloss: 0.267891
# [13577]	training's multi_logloss: 0.10579	valid_1's multi_logloss: 0.267877
# [13578]	training's multi_logloss: 0.105756	valid_1's multi_logloss: 0.267846
# [13579]	training's multi_logloss: 0.105739	valid_1's multi_logloss: 0.267834
# [13580]	training's multi_logloss: 0.105725	valid_1's multi_logloss: 0.267827
# [13581]	training's multi_logloss: 0.105697	valid_1's multi_logloss: 0.267815
# [13582]	training's multi_logloss: 0.105685	valid_1's multi_logloss: 0.267806
# [13583]	training's multi_logloss: 0.105665	valid_1's multi_logloss: 0.267789
# [13584]	training's multi_logloss: 0.105645	valid_1's multi_logloss: 0.267773
# [13585]	training's multi_logloss: 0.105614	valid_1's multi_logloss: 0.267751
# [13586]	training's multi_logloss: 0.105598	valid_1's multi_logloss: 0.267744
# [13587]	training's multi_logloss: 0.105571	valid_1's multi_logloss: 0.26772
# [13588]	training's multi_logloss: 0.105565	valid_1's multi_logloss: 0.267717
# [13589]	training's multi_logloss: 0.10556	valid_1's multi_logloss: 0.267722
# [13590]	training's multi_logloss: 0.105543	valid_1's multi_logloss: 0.267702
# [13591]	training's multi_logloss: 0.105534	valid_1's multi_logloss: 0.2677
# [13592]	training's multi_logloss: 0.105522	valid_1's multi_logloss: 0.267688
# [13593]	training's multi_logloss: 0.105513	valid_1's multi_logloss: 0.267687
# [13594]	training's multi_logloss: 0.1055	valid_1's multi_logloss: 0.267677
# [13595]	training's multi_logloss: 0.105486	valid_1's multi_logloss: 0.267665
# [13596]	training's multi_logloss: 0.105466	valid_1's multi_logloss: 0.267647
# [13597]	training's multi_logloss: 0.105456	valid_1's multi_logloss: 0.26764
# [13598]	training's multi_logloss: 0.105446	valid_1's multi_logloss: 0.26764
# [13599]	training's multi_logloss: 0.105437	valid_1's multi_logloss: 0.267635
# [13600]	training's multi_logloss: 0.105414	valid_1's multi_logloss: 0.267611
# [13601]	training's multi_logloss: 0.105401	valid_1's multi_logloss: 0.267603
# [13602]	training's multi_logloss: 0.105354	valid_1's multi_logloss: 0.267565
# [13603]	training's multi_logloss: 0.105327	valid_1's multi_logloss: 0.267541
# [13604]	training's multi_logloss: 0.105319	valid_1's multi_logloss: 0.267537
# [13605]	training's multi_logloss: 0.1053	valid_1's multi_logloss: 0.267516
# [13606]	training's multi_logloss: 0.105291	valid_1's multi_logloss: 0.267511
# [13607]	training's multi_logloss: 0.105286	valid_1's multi_logloss: 0.267511
# [13608]	training's multi_logloss: 0.105281	valid_1's multi_logloss: 0.267511
# [13609]	training's multi_logloss: 0.105258	valid_1's multi_logloss: 0.267496
# [13610]	training's multi_logloss: 0.105225	valid_1's multi_logloss: 0.267469
# [13611]	training's multi_logloss: 0.105204	valid_1's multi_logloss: 0.267455
# [13612]	training's multi_logloss: 0.105192	valid_1's multi_logloss: 0.26744
# [13613]	training's multi_logloss: 0.105176	valid_1's multi_logloss: 0.267426
# [13614]	training's multi_logloss: 0.105162	valid_1's multi_logloss: 0.267415
# [13615]	training's multi_logloss: 0.105131	valid_1's multi_logloss: 0.267394
# [13616]	training's multi_logloss: 0.10511	valid_1's multi_logloss: 0.267373
# [13617]	training's multi_logloss: 0.105103	valid_1's multi_logloss: 0.267368
# [13618]	training's multi_logloss: 0.105093	valid_1's multi_logloss: 0.267358
# [13619]	training's multi_logloss: 0.105052	valid_1's multi_logloss: 0.26732
# [13620]	training's multi_logloss: 0.105042	valid_1's multi_logloss: 0.267311
# [13621]	training's multi_logloss: 0.105024	valid_1's multi_logloss: 0.267303
# [13622]	training's multi_logloss: 0.105007	valid_1's multi_logloss: 0.267292
# [13623]	training's multi_logloss: 0.104999	valid_1's multi_logloss: 0.267284
# [13624]	training's multi_logloss: 0.104975	valid_1's multi_logloss: 0.267267
# [13625]	training's multi_logloss: 0.10496	valid_1's multi_logloss: 0.267258
# [13626]	training's multi_logloss: 0.104932	valid_1's multi_logloss: 0.267235
# ...
# [17801]	training's multi_logloss: 0.0574932	valid_1's multi_logloss: 0.238603
# [17802]	training's multi_logloss: 0.0574888	valid_1's multi_logloss: 0.238602
# [17803]	training's multi_logloss: 0.0574846	valid_1's multi_logloss: 0.238597
# [17804]	training's multi_logloss: 0.0574797	valid_1's multi_logloss: 0.238598
# [17805]	training's multi_logloss: 0.0574762	valid_1's multi_logloss: 0.238601
# [17806]	training's multi_logloss: 0.0574725	valid_1's multi_logloss: 0.238602
# [17807]	training's multi_logloss: 0.0574686	valid_1's multi_logloss: 0.238603
# [17808]	training's multi_logloss: 0.0574646	valid_1's multi_logloss: 0.238604
# [17809]	training's multi_logloss: 0.0574607	valid_1's multi_logloss: 0.238603
# [17810]	training's multi_logloss: 0.0574571	valid_1's multi_logloss: 0.238604
# [17811]	training's multi_logloss: 0.0574529	valid_1's multi_logloss: 0.238599
# [17812]	training's multi_logloss: 0.0574457	valid_1's multi_logloss: 0.238589
# [17813]	training's multi_logloss: 0.0574421	valid_1's multi_logloss: 0.23859
# [17814]	training's multi_logloss: 0.0574388	valid_1's multi_logloss: 0.238589
# [17815]	training's multi_logloss: 0.057434	valid_1's multi_logloss: 0.238588
# [17816]	training's multi_logloss: 0.0574316	valid_1's multi_logloss: 0.238588
# [17817]	training's multi_logloss: 0.0574262	valid_1's multi_logloss: 0.238587
# [17818]	training's multi_logloss: 0.0574212	valid_1's multi_logloss: 0.238582
# [17819]	training's multi_logloss: 0.0574186	valid_1's multi_logloss: 0.238585
# [17820]	training's multi_logloss: 0.0574141	valid_1's multi_logloss: 0.238584
# [17821]	training's multi_logloss: 0.0574109	valid_1's multi_logloss: 0.238588
# [17822]	training's multi_logloss: 0.0574091	valid_1's multi_logloss: 0.238589
# [17823]	training's multi_logloss: 0.0574074	valid_1's multi_logloss: 0.238592
# [17824]	training's multi_logloss: 0.0574003	valid_1's multi_logloss: 0.238589
# [17825]	training's multi_logloss: 0.057391	valid_1's multi_logloss: 0.238583
# [17826]	training's multi_logloss: 0.0573786	valid_1's multi_logloss: 0.238569
# [17827]	training's multi_logloss: 0.0573735	valid_1's multi_logloss: 0.238568
# [17828]	training's multi_logloss: 0.0573683	valid_1's multi_logloss: 0.23857
# [17829]	training's multi_logloss: 0.0573582	valid_1's multi_logloss: 0.238567
# [17830]	training's multi_logloss: 0.0573528	valid_1's multi_logloss: 0.238572
# [17831]	training's multi_logloss: 0.0573486	valid_1's multi_logloss: 0.238569
# [17832]	training's multi_logloss: 0.0573465	valid_1's multi_logloss: 0.238573
# [17833]	training's multi_logloss: 0.0573439	valid_1's multi_logloss: 0.238578
# [17834]	training's multi_logloss: 0.0573417	valid_1's multi_logloss: 0.238583
# [17835]	training's multi_logloss: 0.05733	valid_1's multi_logloss: 0.238581
# [17836]	training's multi_logloss: 0.0573243	valid_1's multi_logloss: 0.238588
# [17837]	training's multi_logloss: 0.0573191	valid_1's multi_logloss: 0.238586
# [17838]	training's multi_logloss: 0.057315	valid_1's multi_logloss: 0.238581
# [17839]	training's multi_logloss: 0.0573088	valid_1's multi_logloss: 0.238584
# [17840]	training's multi_logloss: 0.057298	valid_1's multi_logloss: 0.238577
# [17841]	training's multi_logloss: 0.0572939	valid_1's multi_logloss: 0.238576
# [17842]	training's multi_logloss: 0.0572899	valid_1's multi_logloss: 0.238575
# [17843]	training's multi_logloss: 0.0572832	valid_1's multi_logloss: 0.238573
# [17844]	training's multi_logloss: 0.05728	valid_1's multi_logloss: 0.238571
# [17845]	training's multi_logloss: 0.0572695	valid_1's multi_logloss: 0.238565
# [17846]	training's multi_logloss: 0.0572571	valid_1's multi_logloss: 0.238555
# [17847]	training's multi_logloss: 0.0572395	valid_1's multi_logloss: 0.238542
# [17848]	training's multi_logloss: 0.0572322	valid_1's multi_logloss: 0.238541
# [17849]	training's multi_logloss: 0.0572231	valid_1's multi_logloss: 0.238541
# [17850]	training's multi_logloss: 0.0572198	valid_1's multi_logloss: 0.238544
# [17851]	training's multi_logloss: 0.057205	valid_1's multi_logloss: 0.238528
# [17852]	training's multi_logloss: 0.0571826	valid_1's multi_logloss: 0.238504
# [17853]	training's multi_logloss: 0.0571779	valid_1's multi_logloss: 0.238504
# [17854]	training's multi_logloss: 0.057164	valid_1's multi_logloss: 0.238496
# [17855]	training's multi_logloss: 0.0571569	valid_1's multi_logloss: 0.238494
# [17856]	training's multi_logloss: 0.0571499	valid_1's multi_logloss: 0.238494
# [17857]	training's multi_logloss: 0.0571315	valid_1's multi_logloss: 0.238472
# [17858]	training's multi_logloss: 0.0571276	valid_1's multi_logloss: 0.238478
# [17859]	training's multi_logloss: 0.057121	valid_1's multi_logloss: 0.23848
# [17860]	training's multi_logloss: 0.0571139	valid_1's multi_logloss: 0.238471
# [17861]	training's multi_logloss: 0.0571068	valid_1's multi_logloss: 0.238467
# [17862]	training's multi_logloss: 0.057095	valid_1's multi_logloss: 0.238459
# [17863]	training's multi_logloss: 0.0570852	valid_1's multi_logloss: 0.23845
# [17864]	training's multi_logloss: 0.0570742	valid_1's multi_logloss: 0.23844
# [17865]	training's multi_logloss: 0.0570606	valid_1's multi_logloss: 0.23843
# [17866]	training's multi_logloss: 0.0570409	valid_1's multi_logloss: 0.238414
# [17867]	training's multi_logloss: 0.0570312	valid_1's multi_logloss: 0.238412
# [17868]	training's multi_logloss: 0.0570155	valid_1's multi_logloss: 0.238398
# [17869]	training's multi_logloss: 0.0569953	valid_1's multi_logloss: 0.238377
# [17870]	training's multi_logloss: 0.0569763	valid_1's multi_logloss: 0.238364
# [17871]	training's multi_logloss: 0.0569611	valid_1's multi_logloss: 0.238355
# [17872]	training's multi_logloss: 0.0569459	valid_1's multi_logloss: 0.238344
# [17873]	training's multi_logloss: 0.0569386	valid_1's multi_logloss: 0.238344
# [17874]	training's multi_logloss: 0.0569289	valid_1's multi_logloss: 0.238344
# [17875]	training's multi_logloss: 0.0569193	valid_1's multi_logloss: 0.238337
# [17876]	training's multi_logloss: 0.0569114	valid_1's multi_logloss: 0.238336
# [17877]	training's multi_logloss: 0.0569039	valid_1's multi_logloss: 0.238326
# [17878]	training's multi_logloss: 0.056901	valid_1's multi_logloss: 0.238329
# [17879]	training's multi_logloss: 0.0568892	valid_1's multi_logloss: 0.238324
# [17880]	training's multi_logloss: 0.0568829	valid_1's multi_logloss: 0.238324
# [17881]	training's multi_logloss: 0.056876	valid_1's multi_logloss: 0.23832
# [17882]	training's multi_logloss: 0.0568714	valid_1's multi_logloss: 0.238316
# [17883]	training's multi_logloss: 0.0568627	valid_1's multi_logloss: 0.238309
# [17884]	training's multi_logloss: 0.0568551	valid_1's multi_logloss: 0.238308
# [17885]	training's multi_logloss: 0.0568512	valid_1's multi_logloss: 0.23831
# [17886]	training's multi_logloss: 0.0568423	valid_1's multi_logloss: 0.238306
# [17887]	training's multi_logloss: 0.0568159	valid_1's multi_logloss: 0.238283
# [17888]	training's multi_logloss: 0.0568048	valid_1's multi_logloss: 0.238275
# [17889]	training's multi_logloss: 0.0567946	valid_1's multi_logloss: 0.238262
# [17890]	training's multi_logloss: 0.056786	valid_1's multi_logloss: 0.23826
# [17891]	training's multi_logloss: 0.0567692	valid_1's multi_logloss: 0.238244
# [17892]	training's multi_logloss: 0.0567666	valid_1's multi_logloss: 0.238251
# [17893]	training's multi_logloss: 0.0567598	valid_1's multi_logloss: 0.238252
# [17894]	training's multi_logloss: 0.056752	valid_1's multi_logloss: 0.238251
# [17895]	training's multi_logloss: 0.0567426	valid_1's multi_logloss: 0.238246
# [17896]	training's multi_logloss: 0.0567374	valid_1's multi_logloss: 0.238251
# [17897]	training's multi_logloss: 0.0567272	valid_1's multi_logloss: 0.238247
# [17898]	training's multi_logloss: 0.0567234	valid_1's multi_logloss: 0.238249
# [17899]	training's multi_logloss: 0.0567148	valid_1's multi_logloss: 0.238239
# [17900]	training's multi_logloss: 0.0567004	valid_1's multi_logloss: 0.238226
# [17901]	training's multi_logloss: 0.0566913	valid_1's multi_logloss: 0.238223
# [17902]	training's multi_logloss: 0.0566699	valid_1's multi_logloss: 0.23821
# [17903]	training's multi_logloss: 0.0566606	valid_1's multi_logloss: 0.238207
# [17904]	training's multi_logloss: 0.0566452	valid_1's multi_logloss: 0.238201
# [17905]	training's multi_logloss: 0.0566337	valid_1's multi_logloss: 0.238188
# [17906]	training's multi_logloss: 0.0566241	valid_1's multi_logloss: 0.23818
# [17907]	training's multi_logloss: 0.0566128	valid_1's multi_logloss: 0.238172
# [17908]	training's multi_logloss: 0.0566102	valid_1's multi_logloss: 0.238173
# [17909]	training's multi_logloss: 0.0565961	valid_1's multi_logloss: 0.238166
# [17910]	training's multi_logloss: 0.0565879	valid_1's multi_logloss: 0.238162
# [17911]	training's multi_logloss: 0.0565831	valid_1's multi_logloss: 0.238163
# [17912]	training's multi_logloss: 0.0565732	valid_1's multi_logloss: 0.238153
# [17913]	training's multi_logloss: 0.056564	valid_1's multi_logloss: 0.238149
# [17914]	training's multi_logloss: 0.0565589	valid_1's multi_logloss: 0.238147
# [17915]	training's multi_logloss: 0.056551	valid_1's multi_logloss: 0.238145
# [17916]	training's multi_logloss: 0.0565425	valid_1's multi_logloss: 0.238143
# [17917]	training's multi_logloss: 0.0565388	valid_1's multi_logloss: 0.23814
# [17918]	training's multi_logloss: 0.0565346	valid_1's multi_logloss: 0.238145
# [17919]	training's multi_logloss: 0.056531	valid_1's multi_logloss: 0.238144
# [17920]	training's multi_logloss: 0.0565204	valid_1's multi_logloss: 0.238139
# [17921]	training's multi_logloss: 0.0565145	valid_1's multi_logloss: 0.238137
# [17922]	training's multi_logloss: 0.0565023	valid_1's multi_logloss: 0.238129
# [17923]	training's multi_logloss: 0.0564857	valid_1's multi_logloss: 0.23812
# [17924]	training's multi_logloss: 0.0564757	valid_1's multi_logloss: 0.23811
# [17925]	training's multi_logloss: 0.0564668	valid_1's multi_logloss: 0.238103
# [17926]	training's multi_logloss: 0.0564547	valid_1's multi_logloss: 0.238094
# [17927]	training's multi_logloss: 0.0564425	valid_1's multi_logloss: 0.238085
# [17928]	training's multi_logloss: 0.0564313	valid_1's multi_logloss: 0.238076
# [17929]	training's multi_logloss: 0.0564209	valid_1's multi_logloss: 0.238072
# [17930]	training's multi_logloss: 0.0564096	valid_1's multi_logloss: 0.238059
# [17931]	training's multi_logloss: 0.0564005	valid_1's multi_logloss: 0.238059
# [17932]	training's multi_logloss: 0.0563855	valid_1's multi_logloss: 0.238053
# [17933]	training's multi_logloss: 0.0563754	valid_1's multi_logloss: 0.238044
# [17934]	training's multi_logloss: 0.0563698	valid_1's multi_logloss: 0.238045
# [17935]	training's multi_logloss: 0.0563659	valid_1's multi_logloss: 0.238043
# [17936]	training's multi_logloss: 0.0563614	valid_1's multi_logloss: 0.238046
# [17937]	training's multi_logloss: 0.0563547	valid_1's multi_logloss: 0.238037
# [17938]	training's multi_logloss: 0.0563476	valid_1's multi_logloss: 0.238028
# [17939]	training's multi_logloss: 0.0563407	valid_1's multi_logloss: 0.238026
# [17940]	training's multi_logloss: 0.0563301	valid_1's multi_logloss: 0.238014
# [17941]	training's multi_logloss: 0.0563239	valid_1's multi_logloss: 0.238016
# [17942]	training's multi_logloss: 0.0563165	valid_1's multi_logloss: 0.238016
# [17943]	training's multi_logloss: 0.0562958	valid_1's multi_logloss: 0.237999
# [17944]	training's multi_logloss: 0.05629	valid_1's multi_logloss: 0.23799
# [17945]	training's multi_logloss: 0.0562792	valid_1's multi_logloss: 0.237987
# [17946]	training's multi_logloss: 0.0562726	valid_1's multi_logloss: 0.237984
# [17947]	training's multi_logloss: 0.0562693	valid_1's multi_logloss: 0.237985
# [17948]	training's multi_logloss: 0.0562627	valid_1's multi_logloss: 0.237981
# [17949]	training's multi_logloss: 0.0562506	valid_1's multi_logloss: 0.237973
# [17950]	training's multi_logloss: 0.0562431	valid_1's multi_logloss: 0.237969
# [17951]	training's multi_logloss: 0.0562342	valid_1's multi_logloss: 0.237969
# [17952]	training's multi_logloss: 0.0562208	valid_1's multi_logloss: 0.237953
# [17953]	training's multi_logloss: 0.0562172	valid_1's multi_logloss: 0.237957
# [17954]	training's multi_logloss: 0.0562126	valid_1's multi_logloss: 0.23796
# [17955]	training's multi_logloss: 0.0562061	valid_1's multi_logloss: 0.237954
# [17956]	training's multi_logloss: 0.0561943	valid_1's multi_logloss: 0.237946
# [17957]	training's multi_logloss: 0.0561765	valid_1's multi_logloss: 0.237932
# [17958]	training's multi_logloss: 0.0561661	valid_1's multi_logloss: 0.237921
# [17959]	training's multi_logloss: 0.0561563	valid_1's multi_logloss: 0.237915
# [17960]	training's multi_logloss: 0.0561524	valid_1's multi_logloss: 0.237919
# [17961]	training's multi_logloss: 0.0561449	valid_1's multi_logloss: 0.237912
# [17962]	training's multi_logloss: 0.056129	valid_1's multi_logloss: 0.2379
# [17963]	training's multi_logloss: 0.0561218	valid_1's multi_logloss: 0.237899
# [17964]	training's multi_logloss: 0.0561104	valid_1's multi_logloss: 0.23789
# [17965]	training's multi_logloss: 0.0560997	valid_1's multi_logloss: 0.237891
# [17966]	training's multi_logloss: 0.0560889	valid_1's multi_logloss: 0.237885
# [17967]	training's multi_logloss: 0.0560822	valid_1's multi_logloss: 0.23788
# [17968]	training's multi_logloss: 0.0560774	valid_1's multi_logloss: 0.237884
# [17969]	training's multi_logloss: 0.0560731	valid_1's multi_logloss: 0.237888
# [17970]	training's multi_logloss: 0.0560553	valid_1's multi_logloss: 0.237871
# [17971]	training's multi_logloss: 0.0560491	valid_1's multi_logloss: 0.237867
# [17972]	training's multi_logloss: 0.0560399	valid_1's multi_logloss: 0.237864
# [17973]	training's multi_logloss: 0.0560284	valid_1's multi_logloss: 0.237858
# [17974]	training's multi_logloss: 0.0560212	valid_1's multi_logloss: 0.237861
# [17975]	training's multi_logloss: 0.0560136	valid_1's multi_logloss: 0.237862
# [17976]	training's multi_logloss: 0.05601	valid_1's multi_logloss: 0.237862
# [17977]	training's multi_logloss: 0.056006	valid_1's multi_logloss: 0.237861
# [17978]	training's multi_logloss: 0.056002	valid_1's multi_logloss: 0.237859
# [17979]	training's multi_logloss: 0.0559982	valid_1's multi_logloss: 0.237866
# [17980]	training's multi_logloss: 0.0559932	valid_1's multi_logloss: 0.237858
# [17981]	training's multi_logloss: 0.0559882	valid_1's multi_logloss: 0.237855
# [17982]	training's multi_logloss: 0.0559858	valid_1's multi_logloss: 0.237854
# [17983]	training's multi_logloss: 0.0559792	valid_1's multi_logloss: 0.23785
# [17984]	training's multi_logloss: 0.0559713	valid_1's multi_logloss: 0.237848
# [17985]	training's multi_logloss: 0.0559662	valid_1's multi_logloss: 0.237847
# [17986]	training's multi_logloss: 0.0559648	valid_1's multi_logloss: 0.237851
# [17987]	training's multi_logloss: 0.055955	valid_1's multi_logloss: 0.237848
# [17988]	training's multi_logloss: 0.0559434	valid_1's multi_logloss: 0.237838
# [17989]	training's multi_logloss: 0.0559252	valid_1's multi_logloss: 0.237826
# [17990]	training's multi_logloss: 0.0559182	valid_1's multi_logloss: 0.237819
# [17991]	training's multi_logloss: 0.055911	valid_1's multi_logloss: 0.237812
# [17992]	training's multi_logloss: 0.0559074	valid_1's multi_logloss: 0.237817
# [17993]	training's multi_logloss: 0.0559009	valid_1's multi_logloss: 0.237817
# [17994]	training's multi_logloss: 0.0558989	valid_1's multi_logloss: 0.237829
# [17995]	training's multi_logloss: 0.0558876	valid_1's multi_logloss: 0.23782
# [17996]	training's multi_logloss: 0.0558775	valid_1's multi_logloss: 0.237815
# [17997]	training's multi_logloss: 0.0558709	valid_1's multi_logloss: 0.237812
# [17998]	training's multi_logloss: 0.0558633	valid_1's multi_logloss: 0.237812
# [17999]	training's multi_logloss: 0.0558515	valid_1's multi_logloss: 0.237803
# [18000]	training's multi_logloss: 0.0558324	valid_1's multi_logloss: 0.237791
# Did not meet early stopping. Best iteration is:
# [18000]	training's multi_logloss: 0.0558324	valid_1's multi_logloss: 0.237791
# LGBMClassifier(bagging_fraction=1.0, bagging_freq=10, feature_fraction=1.0,
#                max_bin=512, max_depth=8, metric='multi_logloss',
#                num_iterations=18000, num_leaves=128, objective='multiclass',
#                task='train', verbose=0)

# %%
# metrics = y_test, lgb_pred

# %%
lgb_pred = lgb.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(lgb_pred, y_test)
print('LightGBM accuracy score: {0:0.4f}'.format(accuracy_score(y_test, lgb_pred)))
# Out:
# LightGBM accuracy score: 0.9412

# %%
# Training set score
y_pred_train = lgb.predict(x_train)
print('LightGBM Model training-set accuracy score: {0:0.4f}'. format(accuracy_score(y_train, y_pred_train)))
# Testing set score
accuracy = accuracy_score(lgb_pred, y_test)
print('LightGBM Model testing-set accuracy score: {0:0.4f}'.format(accuracy_score(y_test, lgb_pred)))
# Out:
# LightGBM Model training-set accuracy score: 0.9930
# LightGBM Model testing-set accuracy score: 0.9412

# %%
# view confusion-matrix
# Print the Confusion Matrix and slice it into four pieces

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, lgb_pred)
print('Confusion matrix\n\n', cm)
# print('\nTrue Positives(TP) = ', cm[0,0])
# print('\nTrue Negatives(TN) = ', cm[1,1])
# print('\nFalse Positives(FP) = ', cm[0,1])
# print('\nFalse Negatives(FN) = ', cm[1,0])
# Out:
# Confusion matrix
#
#  [[47425  1408   613]
#  [ 3449 43481  2134]
#  [  443   664 48516]]

# %%
# # visualize confusion matrix with seaborn heatmap

# cm_matrix = pd.DataFrame(data=cm, columns=['Actual Positive:1', 'Actual Negative:0'], 
#                                  index=['Predict Positive:1', 'Predict Negative:0'])

# sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='YlGnBu')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10,8))
cm = confusion_matrix(y_test, lgb_pred)
cm_matrix = pd.DataFrame(data=cm, columns=['1', '2', '3'],
                                 index=['1', '2', '3'])
sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix\n")
plt.tight_layout()

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, lgb_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.92      0.96      0.94     49446
#            2       0.95      0.89      0.92     49064
#            3       0.95      0.98      0.96     49623
#
#     accuracy                           0.94    148133
#    macro avg       0.94      0.94      0.94    148133
# weighted avg       0.94      0.94      0.94    148133

# %% [markdown]
# ----

# %%
predict_train = lgb.predict(x_train)
print("train score : {}".format(lgb.score(x_train, y_train)))
predict_test = lgb.predict(x_test)

from sklearn.metrics import classification_report
print(classification_report(y_test, lgb.predict(x_test)))
print("test score : {}".format(lgb.score(x_test, y_test)))

# %% [markdown]
# ---

# %%
def get_clf_eval(y_test, lgb_pred):
    confusion = confusion_matrix(y_test, lgb_pred)
    accuracy = accuracy_score(y_test, lgb_pred)
    precision = precision_score(y_test, lgb_pred, average = 'macro')
    recall = recall_score(y_test, lgb_pred, average = 'macro')
    F1 = f1_score(y_test, lgb_pred, average = 'macro')
    # AUC = roc_auc_score(y_test, lgb_pred, multi_class='ovo')
    print('오차행렬:\n', confusion)
    print('\n정확도:{:.4f}'.format(accuracy))
    print('정밀도:{:.4f}'.format(precision))
    print('재현율:{:.4f}'.format(recall))
    print('F1:{:.4f}'.format(F1))
    # print('AUC:{:.4f}'.format(AUC))

# %%
get_clf_eval(y_test, lgb_pred)

# %% [markdown]
# ---

# %%
# plot_importance()를 이용한 피처 중요도 시각화

from lightgbm import plot_importance
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(figsize=(6, 6))
plot_importance(lgb, max_num_features=6, ax=ax) # 상위 6개만

# %% [markdown]
# ### 에러 측정

# %%
# mse = mean_squared_error(y_test, predict_test)
# r2 = r2_score(y_test, predict_test)

# %%
# print('Mean squared error: ', mse)
# print('R2 score: ', r2)

# %%
# final_result = pd.concat([y_test.reset_index(drop=True), pd.DataFrame(predict_test)], axis = 1)

# %%
# final_result.columns = ['label','predict']

# %%
# sns.regplot(x = 'label', y = 'predict', data = final_result)

# %% [markdown]
# ----

# %% [markdown]
# ### LGBMClassifier 상위 모델(?) -> HistGradientBoostingClassifier

# %%
# lgb_clf = lgb.LGBMClassifier(num_leaves=31, objective='binary')
# lgb_clf.fit(x_train, y_train)
# y_pred = lgb_clf.predict(x_test)
# accuracy_score(y_test, y_pred)

# d_train = lgb.Dataset(x_train, label=y_train)
# param = {'num_iterations': 100, 'learning_rate' : 0.1, 'max_depth' : -1, 'objective': 'binary', 'metric':'auc'}

# %%
# from sklearn.ensemble import HistGradientBoostingClassifier as hgbc

# %%
# hgbc.score(x_train)
