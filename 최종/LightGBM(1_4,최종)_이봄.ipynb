# %% [markdown]
# # 당뇨와 고혈압 질병 예측
# - BTH_G : 연령(그룹)
# - SBP : 수축기혈압
# - DBP : 이완기혈압
# - FBS : 공복혈당
# - SEX : 성별(남성:1, 여성:2)
# - DIS : 고혈압/당뇨병 진료여부
#   - 고혈압/당뇨병 진료내역 있음: 1
#   - 고혈압 진료내역 있음: 2
#   - 당뇨병 진료내역 있음: 3
#   - 고혈압/당뇨병 진료내역 없음: 4
# - BMI : 체질량지수

# %% [markdown]
# ## 정상 vs 비정상
# - 4(정상) : 0
# - 1 / 2 / 3(비정상) : 1
#
# - 0(정상) 기준으로 1(비정상) 오버샘플링 : RandomOversampling
# - 1(비정상) : 1 / 2 / 3 각각 레이블링 됨
#
# 1 / 2 / 3 = 비율) 1 : 3 : 1
# => 1 : 1 : 1 비율로 오버샘플링
#
# 1 / 0 = 비율) 1 : 3
# => 1 : 1 비율로 오버샘플링

# %% [markdown]
# # LightGBM
# +
# ## RandomOversampling + 질병 1, 2, 3 비율 => 1 : 1 : 1

# %% [markdown]
# ### LightGBM 설치:
#
# ```
# pip3 install lightgbm
#
# ```

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np 
import pandas as pd # 시리즈, 데이터프레임 포맷 데이터 처리를 위한 라이브러리
import warnings; warnings.filterwarnings(action='ignore') # 경고 메시지 무시
import matplotlib.pyplot as plt # 데이터 시각화 라이브러리
import pickle # 객체 입출력을 위한 라이브러리

from sklearn.model_selection import train_test_split # 훈련 데이터, 테스트 데이터 분리
from sklearn.preprocessing import StandardScaler # 정규화

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import mean_squared_error, r2_score


# LightGBM 임포트
from lightgbm import LGBMClassifier # LightGBM 불러오기

from pandas.core.common import random_state
from sklearn.ensemble import RandomForestClassifier # 랜덤포레스트 분류 알고리즘
from sklearn.tree import DecisionTreeClassifier # 의사결정나무 분류 알고리즘

import matplotlib.pyplot as plt
import seaborn as sns

# 모델 평가를 위한 metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, plot_confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %% [markdown]
# ## 데이터 불러오기

# %%
# Disease 

df = pd.read_csv('/content/drive/MyDrive/health/data/data(over_dis_vs_nor).csv', encoding='cp949')
df
# Out:
#          SEX  BTH_G  SBP  DBP  FBS   BMI  DIS  Dis
# 0          0      1   90   50   86  20.1    2    1
# 1          0      1  120   80   90  27.0    3    1
# 2          0      1  100   60  112  31.8    2    1
# 3          0      1  170  120   86  23.3    2    1
# 4          0      1  135   80  104  35.0    2    1
# ...      ...    ...  ...  ...  ...   ...  ...  ...
# 1481319    1     21  130   90  185  26.3    3    1
# 1481320    1     18  140  100  120  28.8    2    1
# 1481321    0     12  100   60  101  23.0    3    1
# 1481322    1     20  134   72  168  23.1    3    1
# 1481323    1     23  140   90  116  23.7    2    1
#
# [1481324 rows x 8 columns]

# %%
# 1,0 정답 레이블 삭제
df.drop(['Dis'], axis=1, inplace=True)
df
# Out:
#          SEX  BTH_G  SBP  DBP  FBS   BMI  DIS
# 0          0      1   90   50   86  20.1    2
# 1          0      1  120   80   90  27.0    3
# 2          0      1  100   60  112  31.8    2
# 3          0      1  170  120   86  23.3    2
# 4          0      1  135   80  104  35.0    2
# ...      ...    ...  ...  ...  ...   ...  ...
# 1481319    1     21  130   90  185  26.3    3
# 1481320    1     18  140  100  120  28.8    2
# 1481321    0     12  100   60  101  23.0    3
# 1481322    1     20  134   72  168  23.1    3
# 1481323    1     23  140   90  116  23.7    2
#
# [1481324 rows x 7 columns]

# %%
df.reset_index()
# Out:
#            index  SEX  BTH_G  SBP  DBP  FBS   BMI  DIS
# 0              0    0      1   90   50   86  20.1    2
# 1              1    0      1  120   80   90  27.0    3
# 2              2    0      1  100   60  112  31.8    2
# 3              3    0      1  170  120   86  23.3    2
# 4              4    0      1  135   80  104  35.0    2
# ...          ...  ...    ...  ...  ...  ...   ...  ...
# 1481319  1481319    1     21  130   90  185  26.3    3
# 1481320  1481320    1     18  140  100  120  28.8    2
# 1481321  1481321    0     12  100   60  101  23.0    3
# 1481322  1481322    1     20  134   72  168  23.1    3
# 1481323  1481323    1     23  140   90  116  23.7    2
#
# [1481324 rows x 8 columns]

# %%
df.reset_index(drop=True)
# Out:
#          SEX  BTH_G  SBP  DBP  FBS   BMI  DIS
# 0          0      1   90   50   86  20.1    2
# 1          0      1  120   80   90  27.0    3
# 2          0      1  100   60  112  31.8    2
# 3          0      1  170  120   86  23.3    2
# 4          0      1  135   80  104  35.0    2
# ...      ...    ...  ...  ...  ...   ...  ...
# 1481319    1     21  130   90  185  26.3    3
# 1481320    1     18  140  100  120  28.8    2
# 1481321    0     12  100   60  101  23.0    3
# 1481322    1     20  134   72  168  23.1    3
# 1481323    1     23  140   90  116  23.7    2
#
# [1481324 rows x 7 columns]

# %%
df.sample(frac=1.0, replace=False, weights=None, random_state=None, axis=None, ignore_index=False)
# Out:
#          SEX  BTH_G  SBP  DBP  FBS   BMI  DIS
# 621054     0      8  137   97   78  20.9    4
# 1457802    0     23  120   80  118  26.5    1
# 679223     0     11  130   80   84  23.4    4
# 694176     0     11  115   80   84  28.4    4
# 251972     1     27  150   70  148  20.9    1
# ...      ...    ...  ...  ...  ...   ...  ...
# 959874     1      8  110   65   85  18.0    4
# 1130036    1     16  109   66   80  26.3    4
# 734045     0     14  120   80   74  22.6    4
# 774088     0     16  128   72  107  27.3    4
# 12966      0     11  130   80  114  30.8    2
#
# [1481324 rows x 7 columns]

# %%
df.reset_index()
# Out:
#            index  SEX  BTH_G  SBP  DBP  FBS   BMI  DIS
# 0              0    0      1   90   50   86  20.1    2
# 1              1    0      1  120   80   90  27.0    3
# 2              2    0      1  100   60  112  31.8    2
# 3              3    0      1  170  120   86  23.3    2
# 4              4    0      1  135   80  104  35.0    2
# ...          ...  ...    ...  ...  ...  ...   ...  ...
# 1481319  1481319    1     21  130   90  185  26.3    3
# 1481320  1481320    1     18  140  100  120  28.8    2
# 1481321  1481321    0     12  100   60  101  23.0    3
# 1481322  1481322    1     20  134   72  168  23.1    3
# 1481323  1481323    1     23  140   90  116  23.7    2
#
# [1481324 rows x 8 columns]

# %%
df.reset_index(drop=True)
# Out:
#          SEX  BTH_G  SBP  DBP  FBS   BMI  DIS
# 0          0      1   90   50   86  20.1    2
# 1          0      1  120   80   90  27.0    3
# 2          0      1  100   60  112  31.8    2
# 3          0      1  170  120   86  23.3    2
# 4          0      1  135   80  104  35.0    2
# ...      ...    ...  ...  ...  ...   ...  ...
# 1481319    1     21  130   90  185  26.3    3
# 1481320    1     18  140  100  120  28.8    2
# 1481321    0     12  100   60  101  23.0    3
# 1481322    1     20  134   72  168  23.1    3
# 1481323    1     23  140   90  116  23.7    2
#
# [1481324 rows x 7 columns]

# %%
df.notnull().sum()
# Out:
# SEX      1481324
# BTH_G    1481324
# SBP      1481324
# DBP      1481324
# FBS      1481324
# BMI      1481324
# DIS      1481324
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1481324 entries, 0 to 1481323
# Data columns (total 7 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   SEX     1481324 non-null  int64
#  1   BTH_G   1481324 non-null  int64
#  2   SBP     1481324 non-null  int64
#  3   DBP     1481324 non-null  int64
#  4   FBS     1481324 non-null  int64
#  5   BMI     1481324 non-null  float64
#  6   DIS     1481324 non-null  int64
# dtypes: float64(1), int64(6)
# memory usage: 79.1 MB

# %%
# feature와 target 분리(설명변수 및 목표변수 분리)
x = df.drop(['DIS'], axis=1) # df[df.columns.difference(['target'])]
y = np.array(df['DIS']) # y = df['target']

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x)
x_test = sc.transform(x)

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2, random_state=42) # 기본 0.25
# x_test,x_val,y_test,y_val=train_test_split(x,y,test_size=0.1, random_state=42)

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# print(x_val.shape)
# print(y_val.shape)
# Out:
# (1185059, 6)
# (1185059,)
# (296265, 6)
# (296265,)

# %% [markdown]
# ### lightgbm 파라미터 정의

# %%
hyper_params = {
    'n_estimators': 100, # 400
    'num_iterations': 28000,
    'task': 'train',
    'boosting_type': 'gbdt',
    'objective': 'multiclass', 
    'metric': 'multi_logloss', # ['auc_mu', 
    'learning_rate': 0.1, # 0.005
    'feature_fraction': 1.0, # 0.9
    'bagging_fraction': 1.0, # 0.7
    'bagging_freq': 10,
    'verbose': 0,
    'max_depth': 8, # 20
    # 'min_data' : 20
    # 'min_child_samples' =60
    'num_leaves': 128, # 31
    'max_bin': 512, # 255
    # 'device' : 'gpu'
}

# %% [markdown]
# ### 훈련

# %%
from lightgbm import LGBMClassifier

lgb = LGBMClassifier(**hyper_params)
evals = [(x_train, y_train),(x_test, y_test)]

lgb.fit(x_train, y_train, eval_set = evals, early_stopping_rounds=10, verbose = True) # eval_metric='auc'
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# [8776]	training's multi_logloss: 0.354655	valid_1's multi_logloss: 0.519738
# [8777]	training's multi_logloss: 0.354629	valid_1's multi_logloss: 0.51972
# [8778]	training's multi_logloss: 0.354611	valid_1's multi_logloss: 0.519711
# [8779]	training's multi_logloss: 0.354583	valid_1's multi_logloss: 0.519698
# [8780]	training's multi_logloss: 0.354566	valid_1's multi_logloss: 0.519691
# [8781]	training's multi_logloss: 0.354537	valid_1's multi_logloss: 0.519674
# [8782]	training's multi_logloss: 0.354518	valid_1's multi_logloss: 0.519664
# [8783]	training's multi_logloss: 0.354497	valid_1's multi_logloss: 0.519658
# [8784]	training's multi_logloss: 0.354465	valid_1's multi_logloss: 0.519646
# [8785]	training's multi_logloss: 0.354449	valid_1's multi_logloss: 0.519642
# [8786]	training's multi_logloss: 0.354423	valid_1's multi_logloss: 0.51963
# [8787]	training's multi_logloss: 0.354399	valid_1's multi_logloss: 0.51962
# [8788]	training's multi_logloss: 0.354375	valid_1's multi_logloss: 0.519612
# [8789]	training's multi_logloss: 0.354342	valid_1's multi_logloss: 0.519592
# [8790]	training's multi_logloss: 0.354319	valid_1's multi_logloss: 0.519585
# [8791]	training's multi_logloss: 0.354291	valid_1's multi_logloss: 0.519572
# [8792]	training's multi_logloss: 0.354276	valid_1's multi_logloss: 0.519564
# [8793]	training's multi_logloss: 0.354262	valid_1's multi_logloss: 0.519561
# [8794]	training's multi_logloss: 0.35425	valid_1's multi_logloss: 0.51956
# [8795]	training's multi_logloss: 0.354214	valid_1's multi_logloss: 0.519541
# [8796]	training's multi_logloss: 0.354179	valid_1's multi_logloss: 0.519517
# [8797]	training's multi_logloss: 0.354161	valid_1's multi_logloss: 0.519504
# [8798]	training's multi_logloss: 0.354131	valid_1's multi_logloss: 0.519489
# [8799]	training's multi_logloss: 0.35411	valid_1's multi_logloss: 0.519484
# [8800]	training's multi_logloss: 0.354076	valid_1's multi_logloss: 0.519464
# [8801]	training's multi_logloss: 0.35403	valid_1's multi_logloss: 0.519433
# [8802]	training's multi_logloss: 0.353977	valid_1's multi_logloss: 0.519402
# [8803]	training's multi_logloss: 0.353959	valid_1's multi_logloss: 0.519395
# [8804]	training's multi_logloss: 0.353934	valid_1's multi_logloss: 0.519385
# [8805]	training's multi_logloss: 0.353897	valid_1's multi_logloss: 0.519354
# [8806]	training's multi_logloss: 0.353877	valid_1's multi_logloss: 0.519342
# [8807]	training's multi_logloss: 0.353847	valid_1's multi_logloss: 0.519327
# [8808]	training's multi_logloss: 0.353829	valid_1's multi_logloss: 0.519318
# [8809]	training's multi_logloss: 0.3538	valid_1's multi_logloss: 0.519303
# [8810]	training's multi_logloss: 0.353782	valid_1's multi_logloss: 0.519298
# [8811]	training's multi_logloss: 0.353765	valid_1's multi_logloss: 0.519295
# [8812]	training's multi_logloss: 0.353749	valid_1's multi_logloss: 0.519291
# [8813]	training's multi_logloss: 0.353718	valid_1's multi_logloss: 0.519276
# [8814]	training's multi_logloss: 0.3537	valid_1's multi_logloss: 0.519266
# [8815]	training's multi_logloss: 0.353684	valid_1's multi_logloss: 0.51926
# [8816]	training's multi_logloss: 0.353664	valid_1's multi_logloss: 0.51925
# [8817]	training's multi_logloss: 0.353652	valid_1's multi_logloss: 0.519251
# [8818]	training's multi_logloss: 0.353643	valid_1's multi_logloss: 0.519249
# [8819]	training's multi_logloss: 0.353633	valid_1's multi_logloss: 0.519245
# [8820]	training's multi_logloss: 0.353621	valid_1's multi_logloss: 0.519241
# [8821]	training's multi_logloss: 0.353596	valid_1's multi_logloss: 0.519227
# [8822]	training's multi_logloss: 0.353577	valid_1's multi_logloss: 0.519222
# [8823]	training's multi_logloss: 0.353565	valid_1's multi_logloss: 0.519221
# [8824]	training's multi_logloss: 0.353555	valid_1's multi_logloss: 0.519218
# [8825]	training's multi_logloss: 0.35354	valid_1's multi_logloss: 0.519212
# [8826]	training's multi_logloss: 0.353525	valid_1's multi_logloss: 0.519208
# [8827]	training's multi_logloss: 0.353506	valid_1's multi_logloss: 0.519203
# [8828]	training's multi_logloss: 0.353486	valid_1's multi_logloss: 0.519198
# [8829]	training's multi_logloss: 0.353469	valid_1's multi_logloss: 0.519194
# [8830]	training's multi_logloss: 0.353449	valid_1's multi_logloss: 0.519181
# [8831]	training's multi_logloss: 0.353431	valid_1's multi_logloss: 0.519176
# [8832]	training's multi_logloss: 0.353415	valid_1's multi_logloss: 0.51917
# [8833]	training's multi_logloss: 0.353401	valid_1's multi_logloss: 0.519165
# [8834]	training's multi_logloss: 0.353386	valid_1's multi_logloss: 0.51916
# [8835]	training's multi_logloss: 0.35337	valid_1's multi_logloss: 0.519151
# [8836]	training's multi_logloss: 0.353354	valid_1's multi_logloss: 0.519149
# [8837]	training's multi_logloss: 0.353337	valid_1's multi_logloss: 0.519144
# [8838]	training's multi_logloss: 0.353308	valid_1's multi_logloss: 0.519134
# [8839]	training's multi_logloss: 0.353283	valid_1's multi_logloss: 0.519123
# [8840]	training's multi_logloss: 0.353258	valid_1's multi_logloss: 0.519106
# [8841]	training's multi_logloss: 0.353227	valid_1's multi_logloss: 0.519082
# [8842]	training's multi_logloss: 0.353209	valid_1's multi_logloss: 0.519075
# [8843]	training's multi_logloss: 0.353185	valid_1's multi_logloss: 0.519059
# [8844]	training's multi_logloss: 0.353156	valid_1's multi_logloss: 0.51904
# [8845]	training's multi_logloss: 0.353115	valid_1's multi_logloss: 0.519014
# [8846]	training's multi_logloss: 0.35309	valid_1's multi_logloss: 0.518998
# [8847]	training's multi_logloss: 0.353062	valid_1's multi_logloss: 0.51898
# [8848]	training's multi_logloss: 0.353037	valid_1's multi_logloss: 0.51896
# [8849]	training's multi_logloss: 0.353014	valid_1's multi_logloss: 0.518945
# [8850]	training's multi_logloss: 0.353004	valid_1's multi_logloss: 0.518945
# [8851]	training's multi_logloss: 0.35299	valid_1's multi_logloss: 0.51894
# [8852]	training's multi_logloss: 0.35297	valid_1's multi_logloss: 0.518928
# [8853]	training's multi_logloss: 0.352934	valid_1's multi_logloss: 0.518907
# [8854]	training's multi_logloss: 0.3529	valid_1's multi_logloss: 0.518885
# [8855]	training's multi_logloss: 0.352871	valid_1's multi_logloss: 0.518868
# [8856]	training's multi_logloss: 0.352858	valid_1's multi_logloss: 0.518868
# [8857]	training's multi_logloss: 0.352842	valid_1's multi_logloss: 0.518863
# [8858]	training's multi_logloss: 0.352814	valid_1's multi_logloss: 0.51885
# [8859]	training's multi_logloss: 0.352796	valid_1's multi_logloss: 0.518846
# [8860]	training's multi_logloss: 0.352775	valid_1's multi_logloss: 0.518835
# [8861]	training's multi_logloss: 0.352746	valid_1's multi_logloss: 0.518822
# [8862]	training's multi_logloss: 0.352699	valid_1's multi_logloss: 0.518791
# [8863]	training's multi_logloss: 0.35266	valid_1's multi_logloss: 0.518764
# [8864]	training's multi_logloss: 0.352639	valid_1's multi_logloss: 0.518751
# [8865]	training's multi_logloss: 0.352612	valid_1's multi_logloss: 0.518732
# [8866]	training's multi_logloss: 0.35259	valid_1's multi_logloss: 0.518719
# [8867]	training's multi_logloss: 0.352546	valid_1's multi_logloss: 0.518688
# [8868]	training's multi_logloss: 0.352519	valid_1's multi_logloss: 0.51867
# [8869]	training's multi_logloss: 0.352489	valid_1's multi_logloss: 0.518661
# [8870]	training's multi_logloss: 0.35246	valid_1's multi_logloss: 0.518642
# [8871]	training's multi_logloss: 0.352434	valid_1's multi_logloss: 0.518629
# [8872]	training's multi_logloss: 0.352405	valid_1's multi_logloss: 0.51861
# [8873]	training's multi_logloss: 0.352369	valid_1's multi_logloss: 0.518588
# [8874]	training's multi_logloss: 0.352329	valid_1's multi_logloss: 0.518567
# [8875]	training's multi_logloss: 0.352285	valid_1's multi_logloss: 0.518537
# [8876]	training's multi_logloss: 0.352259	valid_1's multi_logloss: 0.518524
# [8877]	training's multi_logloss: 0.352233	valid_1's multi_logloss: 0.51851
# [8878]	training's multi_logloss: 0.352207	valid_1's multi_logloss: 0.518489
# [8879]	training's multi_logloss: 0.352177	valid_1's multi_logloss: 0.518464
# [8880]	training's multi_logloss: 0.352155	valid_1's multi_logloss: 0.518458
# [8881]	training's multi_logloss: 0.352127	valid_1's multi_logloss: 0.518439
# [8882]	training's multi_logloss: 0.352093	valid_1's multi_logloss: 0.518416
# [8883]	training's multi_logloss: 0.352075	valid_1's multi_logloss: 0.518405
# [8884]	training's multi_logloss: 0.352031	valid_1's multi_logloss: 0.518373
# [8885]	training's multi_logloss: 0.352012	valid_1's multi_logloss: 0.518363
# [8886]	training's multi_logloss: 0.351979	valid_1's multi_logloss: 0.518345
# [8887]	training's multi_logloss: 0.351956	valid_1's multi_logloss: 0.518331
# [8888]	training's multi_logloss: 0.351926	valid_1's multi_logloss: 0.518313
# [8889]	training's multi_logloss: 0.351903	valid_1's multi_logloss: 0.518294
# [8890]	training's multi_logloss: 0.351889	valid_1's multi_logloss: 0.518291
# [8891]	training's multi_logloss: 0.351865	valid_1's multi_logloss: 0.518281
# [8892]	training's multi_logloss: 0.351833	valid_1's multi_logloss: 0.518263
# [8893]	training's multi_logloss: 0.351812	valid_1's multi_logloss: 0.51825
# [8894]	training's multi_logloss: 0.351795	valid_1's multi_logloss: 0.518242
# [8895]	training's multi_logloss: 0.351785	valid_1's multi_logloss: 0.518239
# [8896]	training's multi_logloss: 0.351752	valid_1's multi_logloss: 0.518217
# [8897]	training's multi_logloss: 0.35173	valid_1's multi_logloss: 0.518201
# [8898]	training's multi_logloss: 0.35171	valid_1's multi_logloss: 0.518197
# [8899]	training's multi_logloss: 0.351694	valid_1's multi_logloss: 0.51819
# [8900]	training's multi_logloss: 0.351683	valid_1's multi_logloss: 0.518188
# [8901]	training's multi_logloss: 0.351671	valid_1's multi_logloss: 0.518184
# [8902]	training's multi_logloss: 0.351647	valid_1's multi_logloss: 0.518174
# [8903]	training's multi_logloss: 0.351627	valid_1's multi_logloss: 0.518168
# [8904]	training's multi_logloss: 0.3516	valid_1's multi_logloss: 0.518157
# [8905]	training's multi_logloss: 0.351583	valid_1's multi_logloss: 0.51815
# [8906]	training's multi_logloss: 0.351568	valid_1's multi_logloss: 0.518144
# [8907]	training's multi_logloss: 0.35156	valid_1's multi_logloss: 0.518141
# [8908]	training's multi_logloss: 0.351542	valid_1's multi_logloss: 0.518129
# [8909]	training's multi_logloss: 0.35153	valid_1's multi_logloss: 0.518126
# [8910]	training's multi_logloss: 0.351502	valid_1's multi_logloss: 0.518109
# [8911]	training's multi_logloss: 0.351492	valid_1's multi_logloss: 0.518109
# [8912]	training's multi_logloss: 0.351466	valid_1's multi_logloss: 0.518095
# [8913]	training's multi_logloss: 0.351447	valid_1's multi_logloss: 0.518089
# [8914]	training's multi_logloss: 0.351425	valid_1's multi_logloss: 0.518082
# [8915]	training's multi_logloss: 0.351408	valid_1's multi_logloss: 0.518075
# [8916]	training's multi_logloss: 0.351398	valid_1's multi_logloss: 0.518071
# [8917]	training's multi_logloss: 0.351376	valid_1's multi_logloss: 0.518064
# [8918]	training's multi_logloss: 0.351353	valid_1's multi_logloss: 0.518048
# [8919]	training's multi_logloss: 0.351332	valid_1's multi_logloss: 0.518032
# [8920]	training's multi_logloss: 0.351314	valid_1's multi_logloss: 0.518024
# [8921]	training's multi_logloss: 0.351305	valid_1's multi_logloss: 0.518023
# [8922]	training's multi_logloss: 0.351294	valid_1's multi_logloss: 0.518018
# [8923]	training's multi_logloss: 0.35128	valid_1's multi_logloss: 0.518013
# [8924]	training's multi_logloss: 0.351268	valid_1's multi_logloss: 0.518008
# [8925]	training's multi_logloss: 0.351256	valid_1's multi_logloss: 0.518005
# [8926]	training's multi_logloss: 0.351247	valid_1's multi_logloss: 0.518001
# [8927]	training's multi_logloss: 0.351227	valid_1's multi_logloss: 0.517992
# [8928]	training's multi_logloss: 0.351212	valid_1's multi_logloss: 0.517982
# [8929]	training's multi_logloss: 0.351196	valid_1's multi_logloss: 0.51797
# [8930]	training's multi_logloss: 0.351178	valid_1's multi_logloss: 0.517958
# [8931]	training's multi_logloss: 0.351167	valid_1's multi_logloss: 0.517952
# [8932]	training's multi_logloss: 0.351151	valid_1's multi_logloss: 0.517945
# [8933]	training's multi_logloss: 0.351134	valid_1's multi_logloss: 0.517932
# [8934]	training's multi_logloss: 0.35112	valid_1's multi_logloss: 0.517926
# [8935]	training's multi_logloss: 0.351104	valid_1's multi_logloss: 0.517918
# [8936]	training's multi_logloss: 0.351088	valid_1's multi_logloss: 0.517913
# [8937]	training's multi_logloss: 0.351069	valid_1's multi_logloss: 0.517904
# [8938]	training's multi_logloss: 0.351046	valid_1's multi_logloss: 0.517894
# [8939]	training's multi_logloss: 0.351027	valid_1's multi_logloss: 0.517885
# [8940]	training's multi_logloss: 0.350996	valid_1's multi_logloss: 0.517872
# [8941]	training's multi_logloss: 0.350966	valid_1's multi_logloss: 0.517852
# [8942]	training's multi_logloss: 0.350944	valid_1's multi_logloss: 0.517848
# [8943]	training's multi_logloss: 0.350913	valid_1's multi_logloss: 0.517832
# [8944]	training's multi_logloss: 0.3509	valid_1's multi_logloss: 0.517828
# [8945]	training's multi_logloss: 0.350878	valid_1's multi_logloss: 0.517818
# [8946]	training's multi_logloss: 0.350856	valid_1's multi_logloss: 0.517806
# [8947]	training's multi_logloss: 0.350837	valid_1's multi_logloss: 0.517799
# [8948]	training's multi_logloss: 0.350802	valid_1's multi_logloss: 0.517767
# [8949]	training's multi_logloss: 0.350769	valid_1's multi_logloss: 0.51775
# [8950]	training's multi_logloss: 0.350743	valid_1's multi_logloss: 0.517744
# [8951]	training's multi_logloss: 0.350729	valid_1's multi_logloss: 0.517738
# [8952]	training's multi_logloss: 0.350708	valid_1's multi_logloss: 0.517729
# [8953]	training's multi_logloss: 0.350687	valid_1's multi_logloss: 0.517719
# [8954]	training's multi_logloss: 0.350676	valid_1's multi_logloss: 0.517715
# [8955]	training's multi_logloss: 0.350641	valid_1's multi_logloss: 0.517694
# [8956]	training's multi_logloss: 0.35063	valid_1's multi_logloss: 0.51769
# [8957]	training's multi_logloss: 0.35062	valid_1's multi_logloss: 0.517685
# [8958]	training's multi_logloss: 0.350603	valid_1's multi_logloss: 0.517678
# [8959]	training's multi_logloss: 0.350574	valid_1's multi_logloss: 0.517665
# [8960]	training's multi_logloss: 0.350549	valid_1's multi_logloss: 0.517653
# [8961]	training's multi_logloss: 0.350513	valid_1's multi_logloss: 0.517633
# [8962]	training's multi_logloss: 0.350496	valid_1's multi_logloss: 0.517622
# [8963]	training's multi_logloss: 0.350477	valid_1's multi_logloss: 0.517609
# [8964]	training's multi_logloss: 0.35045	valid_1's multi_logloss: 0.517588
# [8965]	training's multi_logloss: 0.350419	valid_1's multi_logloss: 0.517562
# [8966]	training's multi_logloss: 0.350393	valid_1's multi_logloss: 0.51755
# [8967]	training's multi_logloss: 0.350379	valid_1's multi_logloss: 0.517544
# [8968]	training's multi_logloss: 0.350363	valid_1's multi_logloss: 0.517541
# [8969]	training's multi_logloss: 0.350357	valid_1's multi_logloss: 0.517542
# [8970]	training's multi_logloss: 0.35035	valid_1's multi_logloss: 0.517545
# [8971]	training's multi_logloss: 0.350331	valid_1's multi_logloss: 0.517529
# [8972]	training's multi_logloss: 0.350314	valid_1's multi_logloss: 0.517516
# [8973]	training's multi_logloss: 0.350288	valid_1's multi_logloss: 0.517498
# [8974]	training's multi_logloss: 0.350237	valid_1's multi_logloss: 0.517463
# [8975]	training's multi_logloss: 0.350203	valid_1's multi_logloss: 0.517444
# [8976]	training's multi_logloss: 0.350174	valid_1's multi_logloss: 0.517427
# [8977]	training's multi_logloss: 0.350144	valid_1's multi_logloss: 0.517408
# [8978]	training's multi_logloss: 0.350109	valid_1's multi_logloss: 0.517387
# [8979]	training's multi_logloss: 0.350077	valid_1's multi_logloss: 0.517362
# [8980]	training's multi_logloss: 0.350052	valid_1's multi_logloss: 0.517348
# [8981]	training's multi_logloss: 0.350022	valid_1's multi_logloss: 0.517327
# [8982]	training's multi_logloss: 0.349998	valid_1's multi_logloss: 0.517314
# [8983]	training's multi_logloss: 0.349961	valid_1's multi_logloss: 0.517288
# [8984]	training's multi_logloss: 0.349927	valid_1's multi_logloss: 0.517262
# [8985]	training's multi_logloss: 0.349908	valid_1's multi_logloss: 0.517253
# [8986]	training's multi_logloss: 0.34988	valid_1's multi_logloss: 0.517234
# [8987]	training's multi_logloss: 0.349857	valid_1's multi_logloss: 0.517221
# [8988]	training's multi_logloss: 0.349825	valid_1's multi_logloss: 0.517195
# [8989]	training's multi_logloss: 0.349781	valid_1's multi_logloss: 0.517166
# [8990]	training's multi_logloss: 0.349747	valid_1's multi_logloss: 0.517145
# [8991]	training's multi_logloss: 0.349711	valid_1's multi_logloss: 0.517122
# [8992]	training's multi_logloss: 0.349669	valid_1's multi_logloss: 0.517096
# [8993]	training's multi_logloss: 0.349624	valid_1's multi_logloss: 0.517069
# [8994]	training's multi_logloss: 0.349591	valid_1's multi_logloss: 0.517044
# [8995]	training's multi_logloss: 0.349547	valid_1's multi_logloss: 0.517017
# [8996]	training's multi_logloss: 0.349512	valid_1's multi_logloss: 0.516993
# [8997]	training's multi_logloss: 0.349473	valid_1's multi_logloss: 0.516962
# [8998]	training's multi_logloss: 0.349453	valid_1's multi_logloss: 0.516953
# [8999]	training's multi_logloss: 0.349414	valid_1's multi_logloss: 0.516927
# [9000]	training's multi_logloss: 0.349389	valid_1's multi_logloss: 0.51691
# [9001]	training's multi_logloss: 0.349349	valid_1's multi_logloss: 0.516884
# [9002]	training's multi_logloss: 0.349316	valid_1's multi_logloss: 0.51686
# [9003]	training's multi_logloss: 0.349286	valid_1's multi_logloss: 0.516843
# [9004]	training's multi_logloss: 0.349257	valid_1's multi_logloss: 0.516835
# [9005]	training's multi_logloss: 0.349235	valid_1's multi_logloss: 0.516824
# [9006]	training's multi_logloss: 0.349198	valid_1's multi_logloss: 0.516797
# [9007]	training's multi_logloss: 0.349174	valid_1's multi_logloss: 0.516784
# [9008]	training's multi_logloss: 0.349131	valid_1's multi_logloss: 0.516756
# [9009]	training's multi_logloss: 0.349101	valid_1's multi_logloss: 0.516742
# [9010]	training's multi_logloss: 0.349061	valid_1's multi_logloss: 0.516715
# [9011]	training's multi_logloss: 0.349017	valid_1's multi_logloss: 0.516687
# [9012]	training's multi_logloss: 0.348984	valid_1's multi_logloss: 0.516666
# [9013]	training's multi_logloss: 0.348959	valid_1's multi_logloss: 0.516655
# [9014]	training's multi_logloss: 0.348936	valid_1's multi_logloss: 0.516646
# [9015]	training's multi_logloss: 0.348916	valid_1's multi_logloss: 0.516631
# [9016]	training's multi_logloss: 0.348884	valid_1's multi_logloss: 0.516611
# [9017]	training's multi_logloss: 0.348843	valid_1's multi_logloss: 0.516579
# [9018]	training's multi_logloss: 0.348835	valid_1's multi_logloss: 0.516579
# [9019]	training's multi_logloss: 0.348793	valid_1's multi_logloss: 0.516547
# [9020]	training's multi_logloss: 0.348765	valid_1's multi_logloss: 0.516528
# [9021]	training's multi_logloss: 0.348745	valid_1's multi_logloss: 0.516514
# [9022]	training's multi_logloss: 0.348719	valid_1's multi_logloss: 0.5165
# [9023]	training's multi_logloss: 0.348696	valid_1's multi_logloss: 0.51649
# [9024]	training's multi_logloss: 0.34868	valid_1's multi_logloss: 0.516481
# [9025]	training's multi_logloss: 0.34867	valid_1's multi_logloss: 0.516483
# [9026]	training's multi_logloss: 0.34864	valid_1's multi_logloss: 0.516463
# [9027]	training's multi_logloss: 0.348622	valid_1's multi_logloss: 0.516451
# [9028]	training's multi_logloss: 0.348601	valid_1's multi_logloss: 0.516439
# [9029]	training's multi_logloss: 0.348578	valid_1's multi_logloss: 0.516422
# [9030]	training's multi_logloss: 0.348557	valid_1's multi_logloss: 0.516411
# [9031]	training's multi_logloss: 0.348538	valid_1's multi_logloss: 0.516402
# [9032]	training's multi_logloss: 0.348506	valid_1's multi_logloss: 0.516384
# [9033]	training's multi_logloss: 0.348479	valid_1's multi_logloss: 0.516366
# [9034]	training's multi_logloss: 0.348454	valid_1's multi_logloss: 0.516349
# [9035]	training's multi_logloss: 0.348437	valid_1's multi_logloss: 0.51634
# [9036]	training's multi_logloss: 0.348424	valid_1's multi_logloss: 0.516331
# [9037]	training's multi_logloss: 0.348396	valid_1's multi_logloss: 0.516309
# [9038]	training's multi_logloss: 0.348382	valid_1's multi_logloss: 0.516307
# [9039]	training's multi_logloss: 0.348367	valid_1's multi_logloss: 0.516305
# [9040]	training's multi_logloss: 0.348346	valid_1's multi_logloss: 0.516293
# [9041]	training's multi_logloss: 0.348329	valid_1's multi_logloss: 0.516285
# [9042]	training's multi_logloss: 0.348307	valid_1's multi_logloss: 0.516274
# [9043]	training's multi_logloss: 0.348284	valid_1's multi_logloss: 0.516257
# [9044]	training's multi_logloss: 0.348247	valid_1's multi_logloss: 0.516233
# [9045]	training's multi_logloss: 0.348226	valid_1's multi_logloss: 0.516222
# [9046]	training's multi_logloss: 0.348208	valid_1's multi_logloss: 0.516211
# [9047]	training's multi_logloss: 0.348175	valid_1's multi_logloss: 0.516191
# [9048]	training's multi_logloss: 0.348145	valid_1's multi_logloss: 0.516171
# [9049]	training's multi_logloss: 0.348124	valid_1's multi_logloss: 0.516156
# [9050]	training's multi_logloss: 0.348104	valid_1's multi_logloss: 0.516144
# [9051]	training's multi_logloss: 0.348088	valid_1's multi_logloss: 0.516133
# [9052]	training's multi_logloss: 0.348073	valid_1's multi_logloss: 0.516127
# [9053]	training's multi_logloss: 0.34806	valid_1's multi_logloss: 0.516125
# [9054]	training's multi_logloss: 0.34805	valid_1's multi_logloss: 0.516124
# [9055]	training's multi_logloss: 0.348036	valid_1's multi_logloss: 0.51612
# [9056]	training's multi_logloss: 0.348026	valid_1's multi_logloss: 0.516115
# [9057]	training's multi_logloss: 0.348013	valid_1's multi_logloss: 0.516113
# [9058]	training's multi_logloss: 0.348	valid_1's multi_logloss: 0.51611
# [9059]	training's multi_logloss: 0.347988	valid_1's multi_logloss: 0.516113
# [9060]	training's multi_logloss: 0.347974	valid_1's multi_logloss: 0.516109
# [9061]	training's multi_logloss: 0.347967	valid_1's multi_logloss: 0.516113
# [9062]	training's multi_logloss: 0.347958	valid_1's multi_logloss: 0.516112
# [9063]	training's multi_logloss: 0.347954	valid_1's multi_logloss: 0.516113
# [9064]	training's multi_logloss: 0.347934	valid_1's multi_logloss: 0.516099
# [9065]	training's multi_logloss: 0.347914	valid_1's multi_logloss: 0.51609
# [9066]	training's multi_logloss: 0.3479	valid_1's multi_logloss: 0.516085
# [9067]	training's multi_logloss: 0.347894	valid_1's multi_logloss: 0.516085
# [9068]	training's multi_logloss: 0.347882	valid_1's multi_logloss: 0.516081
# [9069]	training's multi_logloss: 0.347854	valid_1's multi_logloss: 0.516064
# [9070]	training's multi_logloss: 0.347839	valid_1's multi_logloss: 0.516057
# [9071]	training's multi_logloss: 0.347813	valid_1's multi_logloss: 0.516036
# [9072]	training's multi_logloss: 0.347798	valid_1's multi_logloss: 0.516025
# [9073]	training's multi_logloss: 0.347787	valid_1's multi_logloss: 0.516023
# [9074]	training's multi_logloss: 0.347755	valid_1's multi_logloss: 0.516008
# [9075]	training's multi_logloss: 0.347724	valid_1's multi_logloss: 0.515986
# [9076]	training's multi_logloss: 0.347694	valid_1's multi_logloss: 0.515969
# [9077]	training's multi_logloss: 0.347667	valid_1's multi_logloss: 0.51595
# [9078]	training's multi_logloss: 0.347641	valid_1's multi_logloss: 0.515932
# [9079]	training's multi_logloss: 0.347631	valid_1's multi_logloss: 0.515929
# [9080]	training's multi_logloss: 0.347625	valid_1's multi_logloss: 0.515928
# [9081]	training's multi_logloss: 0.347615	valid_1's multi_logloss: 0.515924
# [9082]	training's multi_logloss: 0.347605	valid_1's multi_logloss: 0.515921
# [9083]	training's multi_logloss: 0.347593	valid_1's multi_logloss: 0.515916
# [9084]	training's multi_logloss: 0.34758	valid_1's multi_logloss: 0.515912
# [9085]	training's multi_logloss: 0.347569	valid_1's multi_logloss: 0.515907
# [9086]	training's multi_logloss: 0.347561	valid_1's multi_logloss: 0.515901
# [9087]	training's multi_logloss: 0.347545	valid_1's multi_logloss: 0.515893
# [9088]	training's multi_logloss: 0.347537	valid_1's multi_logloss: 0.515895
# [9089]	training's multi_logloss: 0.347519	valid_1's multi_logloss: 0.515879
# [9090]	training's multi_logloss: 0.347506	valid_1's multi_logloss: 0.515875
# [9091]	training's multi_logloss: 0.347499	valid_1's multi_logloss: 0.515874
# [9092]	training's multi_logloss: 0.347479	valid_1's multi_logloss: 0.515867
# [9093]	training's multi_logloss: 0.34746	valid_1's multi_logloss: 0.515855
# [9094]	training's multi_logloss: 0.347434	valid_1's multi_logloss: 0.515845
# [9095]	training's multi_logloss: 0.347413	valid_1's multi_logloss: 0.515835
# [9096]	training's multi_logloss: 0.34739	valid_1's multi_logloss: 0.515824
# [9097]	training's multi_logloss: 0.347344	valid_1's multi_logloss: 0.515793
# [9098]	training's multi_logloss: 0.347328	valid_1's multi_logloss: 0.515783
# [9099]	training's multi_logloss: 0.347295	valid_1's multi_logloss: 0.515758
# [9100]	training's multi_logloss: 0.34727	valid_1's multi_logloss: 0.515738
# [9101]	training's multi_logloss: 0.347251	valid_1's multi_logloss: 0.515729
# [9102]	training's multi_logloss: 0.347205	valid_1's multi_logloss: 0.515694
# [9103]	training's multi_logloss: 0.347182	valid_1's multi_logloss: 0.515683
# [9104]	training's multi_logloss: 0.34716	valid_1's multi_logloss: 0.515668
# [9105]	training's multi_logloss: 0.347133	valid_1's multi_logloss: 0.515656
# [9106]	training's multi_logloss: 0.347111	valid_1's multi_logloss: 0.515645
# [9107]	training's multi_logloss: 0.34708	valid_1's multi_logloss: 0.515622
# [9108]	training's multi_logloss: 0.347059	valid_1's multi_logloss: 0.515616
# [9109]	training's multi_logloss: 0.34704	valid_1's multi_logloss: 0.51561
# [9110]	training's multi_logloss: 0.347018	valid_1's multi_logloss: 0.515602
# [9111]	training's multi_logloss: 0.347003	valid_1's multi_logloss: 0.515597
# [9112]	training's multi_logloss: 0.346991	valid_1's multi_logloss: 0.515599
# [9113]	training's multi_logloss: 0.346978	valid_1's multi_logloss: 0.515594
# [9114]	training's multi_logloss: 0.346949	valid_1's multi_logloss: 0.515587
# [9115]	training's multi_logloss: 0.346929	valid_1's multi_logloss: 0.515579
# [9116]	training's multi_logloss: 0.346894	valid_1's multi_logloss: 0.515548
# [9117]	training's multi_logloss: 0.346859	valid_1's multi_logloss: 0.51553
# [9118]	training's multi_logloss: 0.346821	valid_1's multi_logloss: 0.515506
# [9119]	training's multi_logloss: 0.346791	valid_1's multi_logloss: 0.515483
# [9120]	training's multi_logloss: 0.346771	valid_1's multi_logloss: 0.51547
# [9121]	training's multi_logloss: 0.346746	valid_1's multi_logloss: 0.515457
# [9122]	training's multi_logloss: 0.346723	valid_1's multi_logloss: 0.515444
# [9123]	training's multi_logloss: 0.346697	valid_1's multi_logloss: 0.515429
# [9124]	training's multi_logloss: 0.346689	valid_1's multi_logloss: 0.515425
# [9125]	training's multi_logloss: 0.346681	valid_1's multi_logloss: 0.515425
# [9126]	training's multi_logloss: 0.346658	valid_1's multi_logloss: 0.515413
# [9127]	training's multi_logloss: 0.346616	valid_1's multi_logloss: 0.51538
# [9128]	training's multi_logloss: 0.3466	valid_1's multi_logloss: 0.515367
# [9129]	training's multi_logloss: 0.346591	valid_1's multi_logloss: 0.515363
# [9130]	training's multi_logloss: 0.346567	valid_1's multi_logloss: 0.51535
# [9131]	training's multi_logloss: 0.346537	valid_1's multi_logloss: 0.515335
# [9132]	training's multi_logloss: 0.346506	valid_1's multi_logloss: 0.515314
# [9133]	training's multi_logloss: 0.34647	valid_1's multi_logloss: 0.515297
# [9134]	training's multi_logloss: 0.346443	valid_1's multi_logloss: 0.515283
# [9135]	training's multi_logloss: 0.346425	valid_1's multi_logloss: 0.515273
# [9136]	training's multi_logloss: 0.346388	valid_1's multi_logloss: 0.515246
# [9137]	training's multi_logloss: 0.346365	valid_1's multi_logloss: 0.515235
# [9138]	training's multi_logloss: 0.346323	valid_1's multi_logloss: 0.515211
# [9139]	training's multi_logloss: 0.346294	valid_1's multi_logloss: 0.515197
# [9140]	training's multi_logloss: 0.346258	valid_1's multi_logloss: 0.515172
# [9141]	training's multi_logloss: 0.346229	valid_1's multi_logloss: 0.515163
# [9142]	training's multi_logloss: 0.346205	valid_1's multi_logloss: 0.515149
# [9143]	training's multi_logloss: 0.346194	valid_1's multi_logloss: 0.515144
# [9144]	training's multi_logloss: 0.346162	valid_1's multi_logloss: 0.515122
# [9145]	training's multi_logloss: 0.346132	valid_1's multi_logloss: 0.515102
# [9146]	training's multi_logloss: 0.34611	valid_1's multi_logloss: 0.515092
# [9147]	training's multi_logloss: 0.346077	valid_1's multi_logloss: 0.515072
# [9148]	training's multi_logloss: 0.346057	valid_1's multi_logloss: 0.515058
# [9149]	training's multi_logloss: 0.34604	valid_1's multi_logloss: 0.515046
# [9150]	training's multi_logloss: 0.346016	valid_1's multi_logloss: 0.515035
# [9151]	training's multi_logloss: 0.345998	valid_1's multi_logloss: 0.515024
# [9152]	training's multi_logloss: 0.345977	valid_1's multi_logloss: 0.515016
# [9153]	training's multi_logloss: 0.34596	valid_1's multi_logloss: 0.515007
# [9154]	training's multi_logloss: 0.345949	valid_1's multi_logloss: 0.515003
# [9155]	training's multi_logloss: 0.34592	valid_1's multi_logloss: 0.514986
# [9156]	training's multi_logloss: 0.345907	valid_1's multi_logloss: 0.514985
# [9157]	training's multi_logloss: 0.345887	valid_1's multi_logloss: 0.514976
# [9158]	training's multi_logloss: 0.345867	valid_1's multi_logloss: 0.514972
# [9159]	training's multi_logloss: 0.345858	valid_1's multi_logloss: 0.514975
# [9160]	training's multi_logloss: 0.345839	valid_1's multi_logloss: 0.514964
# [9161]	training's multi_logloss: 0.345828	valid_1's multi_logloss: 0.514958
# [9162]	training's multi_logloss: 0.34581	valid_1's multi_logloss: 0.51495
# [9163]	training's multi_logloss: 0.345792	valid_1's multi_logloss: 0.514941
# [9164]	training's multi_logloss: 0.345776	valid_1's multi_logloss: 0.514937
# [9165]	training's multi_logloss: 0.345764	valid_1's multi_logloss: 0.514932
# [9166]	training's multi_logloss: 0.345743	valid_1's multi_logloss: 0.514925
# [9167]	training's multi_logloss: 0.345732	valid_1's multi_logloss: 0.514922
# [9168]	training's multi_logloss: 0.345717	valid_1's multi_logloss: 0.514915
# [9169]	training's multi_logloss: 0.345704	valid_1's multi_logloss: 0.514908
# [9170]	training's multi_logloss: 0.345692	valid_1's multi_logloss: 0.514902
# [9171]	training's multi_logloss: 0.34568	valid_1's multi_logloss: 0.514893
# [9172]	training's multi_logloss: 0.345655	valid_1's multi_logloss: 0.514881
# [9173]	training's multi_logloss: 0.345638	valid_1's multi_logloss: 0.514875
# [9174]	training's multi_logloss: 0.345627	valid_1's multi_logloss: 0.514874
# [9175]	training's multi_logloss: 0.345604	valid_1's multi_logloss: 0.514868
# [9176]	training's multi_logloss: 0.345581	valid_1's multi_logloss: 0.514853
# [9177]	training's multi_logloss: 0.34556	valid_1's multi_logloss: 0.514847
# [9178]	training's multi_logloss: 0.345545	valid_1's multi_logloss: 0.514837
# [9179]	training's multi_logloss: 0.345531	valid_1's multi_logloss: 0.514835
# [9180]	training's multi_logloss: 0.34551	valid_1's multi_logloss: 0.514825
# [9181]	training's multi_logloss: 0.345491	valid_1's multi_logloss: 0.514819
# [9182]	training's multi_logloss: 0.345467	valid_1's multi_logloss: 0.514806
# [9183]	training's multi_logloss: 0.345433	valid_1's multi_logloss: 0.514781
# [9184]	training's multi_logloss: 0.345418	valid_1's multi_logloss: 0.514773
# [9185]	training's multi_logloss: 0.345407	valid_1's multi_logloss: 0.514766
# [9186]	training's multi_logloss: 0.345394	valid_1's multi_logloss: 0.514764
# [9187]	training's multi_logloss: 0.345379	valid_1's multi_logloss: 0.514758
# [9188]	training's multi_logloss: 0.345358	valid_1's multi_logloss: 0.514748
# [9189]	training's multi_logloss: 0.345323	valid_1's multi_logloss: 0.514732
# [9190]	training's multi_logloss: 0.345294	valid_1's multi_logloss: 0.514713
# [9191]	training's multi_logloss: 0.345271	valid_1's multi_logloss: 0.514695
# [9192]	training's multi_logloss: 0.345252	valid_1's multi_logloss: 0.514682
# [9193]	training's multi_logloss: 0.345233	valid_1's multi_logloss: 0.514671
# [9194]	training's multi_logloss: 0.345214	valid_1's multi_logloss: 0.51466
# [9195]	training's multi_logloss: 0.3452	valid_1's multi_logloss: 0.514659
# [9196]	training's multi_logloss: 0.345184	valid_1's multi_logloss: 0.514651
# [9197]	training's multi_logloss: 0.345155	valid_1's multi_logloss: 0.514637
# [9198]	training's multi_logloss: 0.345128	valid_1's multi_logloss: 0.514626
# [9199]	training's multi_logloss: 0.345106	valid_1's multi_logloss: 0.514614
# [9200]	training's multi_logloss: 0.345082	valid_1's multi_logloss: 0.514608
# [9201]	training's multi_logloss: 0.345053	valid_1's multi_logloss: 0.51459
# [9202]	training's multi_logloss: 0.345043	valid_1's multi_logloss: 0.514586
# [9203]	training's multi_logloss: 0.345033	valid_1's multi_logloss: 0.514584
# [9204]	training's multi_logloss: 0.345023	valid_1's multi_logloss: 0.514583
# [9205]	training's multi_logloss: 0.345011	valid_1's multi_logloss: 0.514579
# [9206]	training's multi_logloss: 0.345	valid_1's multi_logloss: 0.514577
# [9207]	training's multi_logloss: 0.34498	valid_1's multi_logloss: 0.514565
# [9208]	training's multi_logloss: 0.344942	valid_1's multi_logloss: 0.514544
# [9209]	training's multi_logloss: 0.344906	valid_1's multi_logloss: 0.514524
# [9210]	training's multi_logloss: 0.344879	valid_1's multi_logloss: 0.514507
# [9211]	training's multi_logloss: 0.344861	valid_1's multi_logloss: 0.514497
# [9212]	training's multi_logloss: 0.344837	valid_1's multi_logloss: 0.514489
# [9213]	training's multi_logloss: 0.344796	valid_1's multi_logloss: 0.514461
# [9214]	training's multi_logloss: 0.344779	valid_1's multi_logloss: 0.514455
# [9215]	training's multi_logloss: 0.344765	valid_1's multi_logloss: 0.514448
# [9216]	training's multi_logloss: 0.34475	valid_1's multi_logloss: 0.514442
# [9217]	training's multi_logloss: 0.344729	valid_1's multi_logloss: 0.514431
# [9218]	training's multi_logloss: 0.344711	valid_1's multi_logloss: 0.514425
# [9219]	training's multi_logloss: 0.344692	valid_1's multi_logloss: 0.514414
# [9220]	training's multi_logloss: 0.344673	valid_1's multi_logloss: 0.514402
# [9221]	training's multi_logloss: 0.344657	valid_1's multi_logloss: 0.514392
# [9222]	training's multi_logloss: 0.344636	valid_1's multi_logloss: 0.51438
# [9223]	training's multi_logloss: 0.344616	valid_1's multi_logloss: 0.51437
# [9224]	training's multi_logloss: 0.344595	valid_1's multi_logloss: 0.514361
# [9225]	training's multi_logloss: 0.344563	valid_1's multi_logloss: 0.514344
# [9226]	training's multi_logloss: 0.344529	valid_1's multi_logloss: 0.514325
# [9227]	training's multi_logloss: 0.344516	valid_1's multi_logloss: 0.514322
# [9228]	training's multi_logloss: 0.344502	valid_1's multi_logloss: 0.514315
# [9229]	training's multi_logloss: 0.344487	valid_1's multi_logloss: 0.51431
# [9230]	training's multi_logloss: 0.344471	valid_1's multi_logloss: 0.514305
# [9231]	training's multi_logloss: 0.344445	valid_1's multi_logloss: 0.514292
# [9232]	training's multi_logloss: 0.344431	valid_1's multi_logloss: 0.514285
# [9233]	training's multi_logloss: 0.344419	valid_1's multi_logloss: 0.514281
# [9234]	training's multi_logloss: 0.344404	valid_1's multi_logloss: 0.514271
# [9235]	training's multi_logloss: 0.344388	valid_1's multi_logloss: 0.514265
# [9236]	training's multi_logloss: 0.344366	valid_1's multi_logloss: 0.514257
# [9237]	training's multi_logloss: 0.344341	valid_1's multi_logloss: 0.514244
# [9238]	training's multi_logloss: 0.344327	valid_1's multi_logloss: 0.514238
# [9239]	training's multi_logloss: 0.3443	valid_1's multi_logloss: 0.514217
# [9240]	training's multi_logloss: 0.344273	valid_1's multi_logloss: 0.514196
# [9241]	training's multi_logloss: 0.34426	valid_1's multi_logloss: 0.514189
# [9242]	training's multi_logloss: 0.344238	valid_1's multi_logloss: 0.51418
# [9243]	training's multi_logloss: 0.344213	valid_1's multi_logloss: 0.514167
# [9244]	training's multi_logloss: 0.344191	valid_1's multi_logloss: 0.514149
# [9245]	training's multi_logloss: 0.344157	valid_1's multi_logloss: 0.514127
# [9246]	training's multi_logloss: 0.344132	valid_1's multi_logloss: 0.514111
# [9247]	training's multi_logloss: 0.344106	valid_1's multi_logloss: 0.514096
# [9248]	training's multi_logloss: 0.344076	valid_1's multi_logloss: 0.514079
# [9249]	training's multi_logloss: 0.344049	valid_1's multi_logloss: 0.514064
# [9250]	training's multi_logloss: 0.344023	valid_1's multi_logloss: 0.514049
# [9251]	training's multi_logloss: 0.344	valid_1's multi_logloss: 0.514033
# [9252]	training's multi_logloss: 0.343979	valid_1's multi_logloss: 0.514026
# [9253]	training's multi_logloss: 0.343952	valid_1's multi_logloss: 0.514006
# [9254]	training's multi_logloss: 0.343935	valid_1's multi_logloss: 0.513998
# [9255]	training's multi_logloss: 0.343905	valid_1's multi_logloss: 0.513975
# [9256]	training's multi_logloss: 0.343879	valid_1's multi_logloss: 0.513959
# [9257]	training's multi_logloss: 0.343851	valid_1's multi_logloss: 0.513936
# [9258]	training's multi_logloss: 0.34383	valid_1's multi_logloss: 0.513921
# [9259]	training's multi_logloss: 0.343799	valid_1's multi_logloss: 0.513899
# [9260]	training's multi_logloss: 0.343772	valid_1's multi_logloss: 0.513874
# [9261]	training's multi_logloss: 0.343747	valid_1's multi_logloss: 0.513859
# [9262]	training's multi_logloss: 0.343727	valid_1's multi_logloss: 0.513848
# [9263]	training's multi_logloss: 0.343705	valid_1's multi_logloss: 0.513832
# [9264]	training's multi_logloss: 0.343687	valid_1's multi_logloss: 0.513821
# [9265]	training's multi_logloss: 0.343658	valid_1's multi_logloss: 0.5138
# [9266]	training's multi_logloss: 0.343632	valid_1's multi_logloss: 0.513779
# [9267]	training's multi_logloss: 0.343607	valid_1's multi_logloss: 0.513765
# [9268]	training's multi_logloss: 0.343586	valid_1's multi_logloss: 0.513753
# [9269]	training's multi_logloss: 0.343571	valid_1's multi_logloss: 0.513749
# [9270]	training's multi_logloss: 0.34355	valid_1's multi_logloss: 0.513739
# [9271]	training's multi_logloss: 0.343533	valid_1's multi_logloss: 0.513733
# [9272]	training's multi_logloss: 0.343505	valid_1's multi_logloss: 0.513716
# [9273]	training's multi_logloss: 0.343474	valid_1's multi_logloss: 0.513703
# [9274]	training's multi_logloss: 0.343452	valid_1's multi_logloss: 0.513687
# [9275]	training's multi_logloss: 0.343428	valid_1's multi_logloss: 0.513669
# [9276]	training's multi_logloss: 0.343416	valid_1's multi_logloss: 0.513667
# [9277]	training's multi_logloss: 0.343396	valid_1's multi_logloss: 0.513657
# [9278]	training's multi_logloss: 0.343369	valid_1's multi_logloss: 0.513647
# [9279]	training's multi_logloss: 0.343355	valid_1's multi_logloss: 0.51364
# [9280]	training's multi_logloss: 0.343342	valid_1's multi_logloss: 0.513631
# [9281]	training's multi_logloss: 0.343328	valid_1's multi_logloss: 0.513624
# [9282]	training's multi_logloss: 0.34332	valid_1's multi_logloss: 0.513622
# [9283]	training's multi_logloss: 0.343304	valid_1's multi_logloss: 0.513617
# [9284]	training's multi_logloss: 0.343292	valid_1's multi_logloss: 0.513616
# [9285]	training's multi_logloss: 0.343284	valid_1's multi_logloss: 0.513616
# [9286]	training's multi_logloss: 0.343267	valid_1's multi_logloss: 0.513608
# [9287]	training's multi_logloss: 0.343252	valid_1's multi_logloss: 0.513608
# [9288]	training's multi_logloss: 0.343238	valid_1's multi_logloss: 0.513601
# [9289]	training's multi_logloss: 0.343222	valid_1's multi_logloss: 0.513599
# [9290]	training's multi_logloss: 0.343192	valid_1's multi_logloss: 0.513582
# [9291]	training's multi_logloss: 0.343182	valid_1's multi_logloss: 0.513581
# [9292]	training's multi_logloss: 0.343168	valid_1's multi_logloss: 0.513575
# [9293]	training's multi_logloss: 0.343152	valid_1's multi_logloss: 0.513568
# [9294]	training's multi_logloss: 0.343144	valid_1's multi_logloss: 0.513567
# [9295]	training's multi_logloss: 0.343138	valid_1's multi_logloss: 0.513569
# [9296]	training's multi_logloss: 0.343128	valid_1's multi_logloss: 0.513568
# [9297]	training's multi_logloss: 0.343119	valid_1's multi_logloss: 0.513565
# [9298]	training's multi_logloss: 0.343112	valid_1's multi_logloss: 0.513561
# [9299]	training's multi_logloss: 0.343093	valid_1's multi_logloss: 0.513548
# [9300]	training's multi_logloss: 0.343077	valid_1's multi_logloss: 0.513543
# [9301]	training's multi_logloss: 0.343054	valid_1's multi_logloss: 0.513533
# [9302]	training's multi_logloss: 0.343028	valid_1's multi_logloss: 0.513508
# [9303]	training's multi_logloss: 0.343009	valid_1's multi_logloss: 0.513501
# [9304]	training's multi_logloss: 0.342981	valid_1's multi_logloss: 0.513493
# [9305]	training's multi_logloss: 0.342957	valid_1's multi_logloss: 0.513474
# [9306]	training's multi_logloss: 0.342922	valid_1's multi_logloss: 0.513449
# [9307]	training's multi_logloss: 0.342901	valid_1's multi_logloss: 0.513435
# [9308]	training's multi_logloss: 0.342884	valid_1's multi_logloss: 0.51343
# [9309]	training's multi_logloss: 0.34286	valid_1's multi_logloss: 0.513414
# [9310]	training's multi_logloss: 0.342839	valid_1's multi_logloss: 0.513401
# [9311]	training's multi_logloss: 0.342803	valid_1's multi_logloss: 0.51337
# [9312]	training's multi_logloss: 0.342772	valid_1's multi_logloss: 0.513352
# [9313]	training's multi_logloss: 0.342757	valid_1's multi_logloss: 0.513344
# [9314]	training's multi_logloss: 0.342749	valid_1's multi_logloss: 0.513344
# [9315]	training's multi_logloss: 0.342721	valid_1's multi_logloss: 0.513324
# [9316]	training's multi_logloss: 0.342691	valid_1's multi_logloss: 0.513303
# [9317]	training's multi_logloss: 0.342674	valid_1's multi_logloss: 0.513292
# [9318]	training's multi_logloss: 0.342658	valid_1's multi_logloss: 0.513281
# [9319]	training's multi_logloss: 0.342629	valid_1's multi_logloss: 0.513261
# [9320]	training's multi_logloss: 0.342598	valid_1's multi_logloss: 0.513243
# [9321]	training's multi_logloss: 0.342574	valid_1's multi_logloss: 0.51323
# [9322]	training's multi_logloss: 0.342539	valid_1's multi_logloss: 0.513212
# [9323]	training's multi_logloss: 0.342501	valid_1's multi_logloss: 0.513187
# [9324]	training's multi_logloss: 0.342475	valid_1's multi_logloss: 0.513177
# [9325]	training's multi_logloss: 0.342455	valid_1's multi_logloss: 0.513171
# [9326]	training's multi_logloss: 0.342438	valid_1's multi_logloss: 0.513163
# [9327]	training's multi_logloss: 0.342407	valid_1's multi_logloss: 0.513148
# [9328]	training's multi_logloss: 0.342388	valid_1's multi_logloss: 0.513135
# [9329]	training's multi_logloss: 0.342348	valid_1's multi_logloss: 0.513105
# [9330]	training's multi_logloss: 0.342323	valid_1's multi_logloss: 0.513091
# [9331]	training's multi_logloss: 0.342299	valid_1's multi_logloss: 0.513078
# [9332]	training's multi_logloss: 0.342281	valid_1's multi_logloss: 0.513072
# [9333]	training's multi_logloss: 0.342249	valid_1's multi_logloss: 0.513057
# [9334]	training's multi_logloss: 0.342232	valid_1's multi_logloss: 0.513051
# [9335]	training's multi_logloss: 0.342214	valid_1's multi_logloss: 0.51304
# [9336]	training's multi_logloss: 0.342195	valid_1's multi_logloss: 0.513038
# [9337]	training's multi_logloss: 0.34217	valid_1's multi_logloss: 0.51303
# [9338]	training's multi_logloss: 0.342143	valid_1's multi_logloss: 0.513016
# [9339]	training's multi_logloss: 0.34211	valid_1's multi_logloss: 0.513
# [9340]	training's multi_logloss: 0.342067	valid_1's multi_logloss: 0.512965
# [9341]	training's multi_logloss: 0.342055	valid_1's multi_logloss: 0.512961
# [9342]	training's multi_logloss: 0.342044	valid_1's multi_logloss: 0.51296
# [9343]	training's multi_logloss: 0.34203	valid_1's multi_logloss: 0.51296
# [9344]	training's multi_logloss: 0.342002	valid_1's multi_logloss: 0.512942
# [9345]	training's multi_logloss: 0.341989	valid_1's multi_logloss: 0.512936
# [9346]	training's multi_logloss: 0.341967	valid_1's multi_logloss: 0.512928
# [9347]	training's multi_logloss: 0.341941	valid_1's multi_logloss: 0.512908
# [9348]	training's multi_logloss: 0.341914	valid_1's multi_logloss: 0.512893
# [9349]	training's multi_logloss: 0.341896	valid_1's multi_logloss: 0.512882
# [9350]	training's multi_logloss: 0.341872	valid_1's multi_logloss: 0.512867
# [9351]	training's multi_logloss: 0.341856	valid_1's multi_logloss: 0.512862
# [9352]	training's multi_logloss: 0.341838	valid_1's multi_logloss: 0.512856
# [9353]	training's multi_logloss: 0.341814	valid_1's multi_logloss: 0.512847
# [9354]	training's multi_logloss: 0.341797	valid_1's multi_logloss: 0.512838
# [9355]	training's multi_logloss: 0.341779	valid_1's multi_logloss: 0.51283
# [9356]	training's multi_logloss: 0.341755	valid_1's multi_logloss: 0.512818
# [9357]	training's multi_logloss: 0.341719	valid_1's multi_logloss: 0.512788
# [9358]	training's multi_logloss: 0.341697	valid_1's multi_logloss: 0.512781
# [9359]	training's multi_logloss: 0.341665	valid_1's multi_logloss: 0.512759
# [9360]	training's multi_logloss: 0.341646	valid_1's multi_logloss: 0.512752
# [9361]	training's multi_logloss: 0.341622	valid_1's multi_logloss: 0.512739
# [9362]	training's multi_logloss: 0.341595	valid_1's multi_logloss: 0.512722
# [9363]	training's multi_logloss: 0.341576	valid_1's multi_logloss: 0.512715
# [9364]	training's multi_logloss: 0.341563	valid_1's multi_logloss: 0.512713
# [9365]	training's multi_logloss: 0.341548	valid_1's multi_logloss: 0.512709
# [9366]	training's multi_logloss: 0.341539	valid_1's multi_logloss: 0.512708
# [9367]	training's multi_logloss: 0.341527	valid_1's multi_logloss: 0.512706
# [9368]	training's multi_logloss: 0.341509	valid_1's multi_logloss: 0.5127
# [9369]	training's multi_logloss: 0.341491	valid_1's multi_logloss: 0.512694
# [9370]	training's multi_logloss: 0.341471	valid_1's multi_logloss: 0.512685
# [9371]	training's multi_logloss: 0.341457	valid_1's multi_logloss: 0.512684
# [9372]	training's multi_logloss: 0.34144	valid_1's multi_logloss: 0.512673
# [9373]	training's multi_logloss: 0.34143	valid_1's multi_logloss: 0.51267
# [9374]	training's multi_logloss: 0.341416	valid_1's multi_logloss: 0.512663
# [9375]	training's multi_logloss: 0.341381	valid_1's multi_logloss: 0.512643
# [9376]	training's multi_logloss: 0.341362	valid_1's multi_logloss: 0.512636
# [9377]	training's multi_logloss: 0.341345	valid_1's multi_logloss: 0.512628
# [9378]	training's multi_logloss: 0.341336	valid_1's multi_logloss: 0.512625
# [9379]	training's multi_logloss: 0.34133	valid_1's multi_logloss: 0.512629
# [9380]	training's multi_logloss: 0.341321	valid_1's multi_logloss: 0.512626
# [9381]	training's multi_logloss: 0.341306	valid_1's multi_logloss: 0.512621
# [9382]	training's multi_logloss: 0.341293	valid_1's multi_logloss: 0.512618
# [9383]	training's multi_logloss: 0.341272	valid_1's multi_logloss: 0.512607
# [9384]	training's multi_logloss: 0.341256	valid_1's multi_logloss: 0.512598
# [9385]	training's multi_logloss: 0.341229	valid_1's multi_logloss: 0.512585
# [9386]	training's multi_logloss: 0.341201	valid_1's multi_logloss: 0.512566
# [9387]	training's multi_logloss: 0.341179	valid_1's multi_logloss: 0.512554
# [9388]	training's multi_logloss: 0.341167	valid_1's multi_logloss: 0.512553
# [9389]	training's multi_logloss: 0.34115	valid_1's multi_logloss: 0.512552
# [9390]	training's multi_logloss: 0.34114	valid_1's multi_logloss: 0.51255
# [9391]	training's multi_logloss: 0.341125	valid_1's multi_logloss: 0.512545
# [9392]	training's multi_logloss: 0.341106	valid_1's multi_logloss: 0.512534
# [9393]	training's multi_logloss: 0.341082	valid_1's multi_logloss: 0.512512
# [9394]	training's multi_logloss: 0.341058	valid_1's multi_logloss: 0.512502
# [9395]	training's multi_logloss: 0.34103	valid_1's multi_logloss: 0.512481
# [9396]	training's multi_logloss: 0.34099	valid_1's multi_logloss: 0.512452
# [9397]	training's multi_logloss: 0.340966	valid_1's multi_logloss: 0.512433
# [9398]	training's multi_logloss: 0.340942	valid_1's multi_logloss: 0.512419
# [9399]	training's multi_logloss: 0.340917	valid_1's multi_logloss: 0.512398
# [9400]	training's multi_logloss: 0.340894	valid_1's multi_logloss: 0.512387
# [9401]	training's multi_logloss: 0.340869	valid_1's multi_logloss: 0.512371
# [9402]	training's multi_logloss: 0.340842	valid_1's multi_logloss: 0.512351
# [9403]	training's multi_logloss: 0.340816	valid_1's multi_logloss: 0.512337
# [9404]	training's multi_logloss: 0.340789	valid_1's multi_logloss: 0.512324
# [9405]	training's multi_logloss: 0.340762	valid_1's multi_logloss: 0.512309
# [9406]	training's multi_logloss: 0.340734	valid_1's multi_logloss: 0.512293
# [9407]	training's multi_logloss: 0.340719	valid_1's multi_logloss: 0.512287
# [9408]	training's multi_logloss: 0.340706	valid_1's multi_logloss: 0.512279
# ...
# [13571]	training's multi_logloss: 0.26638	valid_1's multi_logloss: 0.477435
# [13572]	training's multi_logloss: 0.266355	valid_1's multi_logloss: 0.477419
# [13573]	training's multi_logloss: 0.266323	valid_1's multi_logloss: 0.477398
# [13574]	training's multi_logloss: 0.266286	valid_1's multi_logloss: 0.477377
# [13575]	training's multi_logloss: 0.266275	valid_1's multi_logloss: 0.477371
# [13576]	training's multi_logloss: 0.266258	valid_1's multi_logloss: 0.477361
# [13577]	training's multi_logloss: 0.266237	valid_1's multi_logloss: 0.477351
# [13578]	training's multi_logloss: 0.266215	valid_1's multi_logloss: 0.477339
# [13579]	training's multi_logloss: 0.266202	valid_1's multi_logloss: 0.477329
# [13580]	training's multi_logloss: 0.26619	valid_1's multi_logloss: 0.477324
# [13581]	training's multi_logloss: 0.26617	valid_1's multi_logloss: 0.477314
# [13582]	training's multi_logloss: 0.266156	valid_1's multi_logloss: 0.477306
# [13583]	training's multi_logloss: 0.266151	valid_1's multi_logloss: 0.477306
# [13584]	training's multi_logloss: 0.266146	valid_1's multi_logloss: 0.477307
# [13585]	training's multi_logloss: 0.266131	valid_1's multi_logloss: 0.4773
# [13586]	training's multi_logloss: 0.266124	valid_1's multi_logloss: 0.477298
# [13587]	training's multi_logloss: 0.266109	valid_1's multi_logloss: 0.477289
# [13588]	training's multi_logloss: 0.266101	valid_1's multi_logloss: 0.477286
# [13589]	training's multi_logloss: 0.266098	valid_1's multi_logloss: 0.47729
# [13590]	training's multi_logloss: 0.266094	valid_1's multi_logloss: 0.477289
# [13591]	training's multi_logloss: 0.266084	valid_1's multi_logloss: 0.47729
# [13592]	training's multi_logloss: 0.266081	valid_1's multi_logloss: 0.477292
# [13593]	training's multi_logloss: 0.266074	valid_1's multi_logloss: 0.477293
# [13594]	training's multi_logloss: 0.266064	valid_1's multi_logloss: 0.477292
# [13595]	training's multi_logloss: 0.266049	valid_1's multi_logloss: 0.477289
# [13596]	training's multi_logloss: 0.266029	valid_1's multi_logloss: 0.477283
# [13597]	training's multi_logloss: 0.266014	valid_1's multi_logloss: 0.47728
# [13598]	training's multi_logloss: 0.266	valid_1's multi_logloss: 0.477276
# [13599]	training's multi_logloss: 0.265989	valid_1's multi_logloss: 0.477274
# [13600]	training's multi_logloss: 0.265965	valid_1's multi_logloss: 0.477263
# [13601]	training's multi_logloss: 0.265953	valid_1's multi_logloss: 0.477256
# [13602]	training's multi_logloss: 0.265944	valid_1's multi_logloss: 0.477253
# [13603]	training's multi_logloss: 0.265936	valid_1's multi_logloss: 0.477246
# [13604]	training's multi_logloss: 0.265923	valid_1's multi_logloss: 0.477241
# [13605]	training's multi_logloss: 0.26592	valid_1's multi_logloss: 0.477247
# [13606]	training's multi_logloss: 0.265916	valid_1's multi_logloss: 0.47725
# [13607]	training's multi_logloss: 0.265903	valid_1's multi_logloss: 0.477249
# [13608]	training's multi_logloss: 0.265883	valid_1's multi_logloss: 0.47724
# [13609]	training's multi_logloss: 0.265876	valid_1's multi_logloss: 0.47724
# [13610]	training's multi_logloss: 0.265863	valid_1's multi_logloss: 0.477236
# [13611]	training's multi_logloss: 0.265844	valid_1's multi_logloss: 0.477228
# [13612]	training's multi_logloss: 0.265825	valid_1's multi_logloss: 0.477215
# [13613]	training's multi_logloss: 0.265811	valid_1's multi_logloss: 0.477207
# [13614]	training's multi_logloss: 0.265792	valid_1's multi_logloss: 0.477202
# [13615]	training's multi_logloss: 0.265778	valid_1's multi_logloss: 0.477195
# [13616]	training's multi_logloss: 0.265769	valid_1's multi_logloss: 0.477195
# [13617]	training's multi_logloss: 0.265739	valid_1's multi_logloss: 0.477183
# [13618]	training's multi_logloss: 0.265711	valid_1's multi_logloss: 0.477171
# [13619]	training's multi_logloss: 0.265688	valid_1's multi_logloss: 0.477155
# [13620]	training's multi_logloss: 0.265668	valid_1's multi_logloss: 0.477144
# [13621]	training's multi_logloss: 0.265651	valid_1's multi_logloss: 0.477132
# [13622]	training's multi_logloss: 0.265634	valid_1's multi_logloss: 0.477122
# [13623]	training's multi_logloss: 0.265618	valid_1's multi_logloss: 0.47711
# [13624]	training's multi_logloss: 0.265598	valid_1's multi_logloss: 0.477105
# [13625]	training's multi_logloss: 0.265581	valid_1's multi_logloss: 0.477097
# [13626]	training's multi_logloss: 0.265563	valid_1's multi_logloss: 0.47709
# [13627]	training's multi_logloss: 0.265539	valid_1's multi_logloss: 0.477076
# [13628]	training's multi_logloss: 0.265523	valid_1's multi_logloss: 0.47707
# [13629]	training's multi_logloss: 0.265504	valid_1's multi_logloss: 0.47706
# [13630]	training's multi_logloss: 0.265497	valid_1's multi_logloss: 0.477057
# [13631]	training's multi_logloss: 0.265486	valid_1's multi_logloss: 0.477055
# [13632]	training's multi_logloss: 0.265466	valid_1's multi_logloss: 0.477044
# [13633]	training's multi_logloss: 0.265451	valid_1's multi_logloss: 0.477039
# [13634]	training's multi_logloss: 0.265426	valid_1's multi_logloss: 0.477024
# [13635]	training's multi_logloss: 0.265413	valid_1's multi_logloss: 0.47702
# [13636]	training's multi_logloss: 0.265396	valid_1's multi_logloss: 0.477015
# [13637]	training's multi_logloss: 0.265381	valid_1's multi_logloss: 0.47701
# [13638]	training's multi_logloss: 0.265367	valid_1's multi_logloss: 0.477004
# [13639]	training's multi_logloss: 0.265356	valid_1's multi_logloss: 0.477001
# [13640]	training's multi_logloss: 0.265344	valid_1's multi_logloss: 0.476996
# [13641]	training's multi_logloss: 0.265336	valid_1's multi_logloss: 0.476996
# [13642]	training's multi_logloss: 0.265318	valid_1's multi_logloss: 0.476987
# [13643]	training's multi_logloss: 0.265303	valid_1's multi_logloss: 0.47698
# [13644]	training's multi_logloss: 0.265284	valid_1's multi_logloss: 0.476974
# [13645]	training's multi_logloss: 0.265272	valid_1's multi_logloss: 0.476971
# [13646]	training's multi_logloss: 0.265249	valid_1's multi_logloss: 0.476956
# [13647]	training's multi_logloss: 0.265227	valid_1's multi_logloss: 0.476948
# [13648]	training's multi_logloss: 0.265211	valid_1's multi_logloss: 0.476946
# [13649]	training's multi_logloss: 0.265192	valid_1's multi_logloss: 0.476938
# [13650]	training's multi_logloss: 0.265168	valid_1's multi_logloss: 0.476925
# [13651]	training's multi_logloss: 0.265143	valid_1's multi_logloss: 0.476909
# [13652]	training's multi_logloss: 0.265111	valid_1's multi_logloss: 0.476888
# [13653]	training's multi_logloss: 0.265092	valid_1's multi_logloss: 0.47688
# [13654]	training's multi_logloss: 0.265073	valid_1's multi_logloss: 0.47687
# [13655]	training's multi_logloss: 0.265056	valid_1's multi_logloss: 0.476862
# [13656]	training's multi_logloss: 0.265031	valid_1's multi_logloss: 0.476848
# [13657]	training's multi_logloss: 0.265018	valid_1's multi_logloss: 0.47684
# [13658]	training's multi_logloss: 0.265004	valid_1's multi_logloss: 0.476831
# [13659]	training's multi_logloss: 0.264998	valid_1's multi_logloss: 0.476836
# [13660]	training's multi_logloss: 0.26499	valid_1's multi_logloss: 0.47684
# [13661]	training's multi_logloss: 0.264985	valid_1's multi_logloss: 0.47684
# [13662]	training's multi_logloss: 0.264976	valid_1's multi_logloss: 0.476841
# [13663]	training's multi_logloss: 0.264965	valid_1's multi_logloss: 0.476841
# [13664]	training's multi_logloss: 0.264943	valid_1's multi_logloss: 0.476829
# [13665]	training's multi_logloss: 0.26492	valid_1's multi_logloss: 0.476814
# [13666]	training's multi_logloss: 0.264901	valid_1's multi_logloss: 0.476806
# [13667]	training's multi_logloss: 0.264878	valid_1's multi_logloss: 0.476802
# [13668]	training's multi_logloss: 0.264855	valid_1's multi_logloss: 0.476787
# [13669]	training's multi_logloss: 0.264838	valid_1's multi_logloss: 0.476785
# [13670]	training's multi_logloss: 0.264819	valid_1's multi_logloss: 0.476773
# [13671]	training's multi_logloss: 0.264805	valid_1's multi_logloss: 0.476771
# [13672]	training's multi_logloss: 0.264787	valid_1's multi_logloss: 0.476763
# [13673]	training's multi_logloss: 0.264775	valid_1's multi_logloss: 0.476757
# [13674]	training's multi_logloss: 0.264757	valid_1's multi_logloss: 0.476747
# [13675]	training's multi_logloss: 0.264752	valid_1's multi_logloss: 0.476746
# [13676]	training's multi_logloss: 0.264743	valid_1's multi_logloss: 0.476744
# [13677]	training's multi_logloss: 0.264735	valid_1's multi_logloss: 0.476741
# [13678]	training's multi_logloss: 0.264719	valid_1's multi_logloss: 0.47673
# [13679]	training's multi_logloss: 0.264711	valid_1's multi_logloss: 0.476729
# [13680]	training's multi_logloss: 0.2647	valid_1's multi_logloss: 0.476726
# [13681]	training's multi_logloss: 0.264688	valid_1's multi_logloss: 0.476725
# [13682]	training's multi_logloss: 0.264675	valid_1's multi_logloss: 0.476719
# [13683]	training's multi_logloss: 0.264665	valid_1's multi_logloss: 0.476718
# [13684]	training's multi_logloss: 0.264653	valid_1's multi_logloss: 0.476715
# [13685]	training's multi_logloss: 0.264648	valid_1's multi_logloss: 0.476716
# [13686]	training's multi_logloss: 0.264639	valid_1's multi_logloss: 0.476715
# [13687]	training's multi_logloss: 0.264624	valid_1's multi_logloss: 0.476712
# [13688]	training's multi_logloss: 0.26461	valid_1's multi_logloss: 0.476703
# [13689]	training's multi_logloss: 0.264592	valid_1's multi_logloss: 0.4767
# [13690]	training's multi_logloss: 0.264587	valid_1's multi_logloss: 0.476701
# [13691]	training's multi_logloss: 0.264581	valid_1's multi_logloss: 0.476703
# [13692]	training's multi_logloss: 0.26457	valid_1's multi_logloss: 0.4767
# [13693]	training's multi_logloss: 0.264557	valid_1's multi_logloss: 0.476697
# [13694]	training's multi_logloss: 0.264549	valid_1's multi_logloss: 0.476694
# [13695]	training's multi_logloss: 0.26454	valid_1's multi_logloss: 0.476693
# [13696]	training's multi_logloss: 0.26453	valid_1's multi_logloss: 0.476692
# [13697]	training's multi_logloss: 0.264513	valid_1's multi_logloss: 0.476686
# [13698]	training's multi_logloss: 0.264496	valid_1's multi_logloss: 0.476675
# [13699]	training's multi_logloss: 0.264485	valid_1's multi_logloss: 0.476671
# [13700]	training's multi_logloss: 0.264467	valid_1's multi_logloss: 0.476666
# [13701]	training's multi_logloss: 0.264436	valid_1's multi_logloss: 0.476643
# [13702]	training's multi_logloss: 0.264415	valid_1's multi_logloss: 0.476633
# [13703]	training's multi_logloss: 0.264403	valid_1's multi_logloss: 0.476625
# [13704]	training's multi_logloss: 0.264395	valid_1's multi_logloss: 0.476623
# [13705]	training's multi_logloss: 0.264385	valid_1's multi_logloss: 0.476619
# [13706]	training's multi_logloss: 0.264375	valid_1's multi_logloss: 0.476615
# [13707]	training's multi_logloss: 0.264368	valid_1's multi_logloss: 0.476614
# [13708]	training's multi_logloss: 0.264351	valid_1's multi_logloss: 0.476605
# [13709]	training's multi_logloss: 0.264334	valid_1's multi_logloss: 0.476598
# [13710]	training's multi_logloss: 0.264324	valid_1's multi_logloss: 0.476598
# [13711]	training's multi_logloss: 0.264305	valid_1's multi_logloss: 0.47659
# [13712]	training's multi_logloss: 0.264286	valid_1's multi_logloss: 0.476582
# [13713]	training's multi_logloss: 0.264274	valid_1's multi_logloss: 0.476581
# [13714]	training's multi_logloss: 0.264261	valid_1's multi_logloss: 0.476578
# [13715]	training's multi_logloss: 0.264245	valid_1's multi_logloss: 0.476571
# [13716]	training's multi_logloss: 0.264229	valid_1's multi_logloss: 0.476563
# [13717]	training's multi_logloss: 0.264209	valid_1's multi_logloss: 0.476552
# [13718]	training's multi_logloss: 0.264191	valid_1's multi_logloss: 0.476541
# [13719]	training's multi_logloss: 0.264176	valid_1's multi_logloss: 0.476537
# [13720]	training's multi_logloss: 0.264151	valid_1's multi_logloss: 0.476521
# [13721]	training's multi_logloss: 0.264127	valid_1's multi_logloss: 0.476506
# [13722]	training's multi_logloss: 0.264109	valid_1's multi_logloss: 0.476492
# [13723]	training's multi_logloss: 0.26409	valid_1's multi_logloss: 0.476481
# [13724]	training's multi_logloss: 0.264076	valid_1's multi_logloss: 0.476475
# [13725]	training's multi_logloss: 0.264064	valid_1's multi_logloss: 0.476469
# [13726]	training's multi_logloss: 0.264044	valid_1's multi_logloss: 0.476463
# [13727]	training's multi_logloss: 0.264031	valid_1's multi_logloss: 0.476455
# [13728]	training's multi_logloss: 0.264021	valid_1's multi_logloss: 0.476454
# [13729]	training's multi_logloss: 0.263994	valid_1's multi_logloss: 0.476438
# [13730]	training's multi_logloss: 0.263978	valid_1's multi_logloss: 0.476431
# [13731]	training's multi_logloss: 0.263964	valid_1's multi_logloss: 0.476426
# [13732]	training's multi_logloss: 0.263948	valid_1's multi_logloss: 0.476412
# [13733]	training's multi_logloss: 0.263937	valid_1's multi_logloss: 0.476407
# [13734]	training's multi_logloss: 0.263918	valid_1's multi_logloss: 0.476395
# [13735]	training's multi_logloss: 0.263895	valid_1's multi_logloss: 0.476389
# [13736]	training's multi_logloss: 0.263876	valid_1's multi_logloss: 0.476379
# [13737]	training's multi_logloss: 0.263861	valid_1's multi_logloss: 0.476375
# [13738]	training's multi_logloss: 0.263845	valid_1's multi_logloss: 0.476371
# [13739]	training's multi_logloss: 0.263826	valid_1's multi_logloss: 0.47636
# [13740]	training's multi_logloss: 0.263801	valid_1's multi_logloss: 0.476351
# [13741]	training's multi_logloss: 0.263771	valid_1's multi_logloss: 0.47633
# [13742]	training's multi_logloss: 0.263747	valid_1's multi_logloss: 0.476312
# [13743]	training's multi_logloss: 0.263729	valid_1's multi_logloss: 0.476304
# [13744]	training's multi_logloss: 0.263707	valid_1's multi_logloss: 0.476288
# [13745]	training's multi_logloss: 0.263694	valid_1's multi_logloss: 0.476281
# [13746]	training's multi_logloss: 0.263684	valid_1's multi_logloss: 0.476277
# [13747]	training's multi_logloss: 0.263671	valid_1's multi_logloss: 0.476267
# [13748]	training's multi_logloss: 0.263659	valid_1's multi_logloss: 0.476263
# [13749]	training's multi_logloss: 0.263629	valid_1's multi_logloss: 0.476236
# [13750]	training's multi_logloss: 0.263602	valid_1's multi_logloss: 0.476219
# [13751]	training's multi_logloss: 0.263576	valid_1's multi_logloss: 0.476205
# [13752]	training's multi_logloss: 0.263558	valid_1's multi_logloss: 0.476204
# [13753]	training's multi_logloss: 0.263541	valid_1's multi_logloss: 0.476194
# [13754]	training's multi_logloss: 0.263521	valid_1's multi_logloss: 0.476187
# [13755]	training's multi_logloss: 0.263501	valid_1's multi_logloss: 0.476175
# [13756]	training's multi_logloss: 0.263493	valid_1's multi_logloss: 0.476175
# [13757]	training's multi_logloss: 0.263485	valid_1's multi_logloss: 0.476176
# [13758]	training's multi_logloss: 0.263474	valid_1's multi_logloss: 0.476176
# [13759]	training's multi_logloss: 0.263456	valid_1's multi_logloss: 0.476168
# [13760]	training's multi_logloss: 0.263442	valid_1's multi_logloss: 0.476164
# [13761]	training's multi_logloss: 0.263431	valid_1's multi_logloss: 0.476161
# [13762]	training's multi_logloss: 0.263415	valid_1's multi_logloss: 0.476153
# [13763]	training's multi_logloss: 0.263404	valid_1's multi_logloss: 0.476151
# [13764]	training's multi_logloss: 0.263398	valid_1's multi_logloss: 0.476154
# [13765]	training's multi_logloss: 0.26339	valid_1's multi_logloss: 0.476156
# [13766]	training's multi_logloss: 0.263383	valid_1's multi_logloss: 0.476161
# [13767]	training's multi_logloss: 0.263366	valid_1's multi_logloss: 0.476158
# [13768]	training's multi_logloss: 0.263362	valid_1's multi_logloss: 0.476159
# [13769]	training's multi_logloss: 0.263354	valid_1's multi_logloss: 0.476162
# [13770]	training's multi_logloss: 0.263335	valid_1's multi_logloss: 0.476155
# [13771]	training's multi_logloss: 0.263329	valid_1's multi_logloss: 0.476159
# [13772]	training's multi_logloss: 0.263322	valid_1's multi_logloss: 0.476161
# [13773]	training's multi_logloss: 0.263314	valid_1's multi_logloss: 0.476161
# Early stopping, best iteration is:
# [13763]	training's multi_logloss: 0.263404	valid_1's multi_logloss: 0.476151
# LGBMClassifier(bagging_fraction=1.0, bagging_freq=10, feature_fraction=1.0,
#                max_bin=512, max_depth=8, metric='multi_logloss',
#                num_iterations=28000, num_leaves=128, objective='multiclass',
#                task='train', verbose=0)

# %%
# metrics = y_test, lgb_pred

# %%
lgb_pred = lgb.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(lgb_pred, y_test)
print('LightGBM accuracy score: {0:0.4f}'.format(accuracy_score(y_test, lgb_pred)))
# Out:
# LightGBM accuracy score: 0.8320

# %%
# Training set score
y_pred_train = lgb.predict(x_train)
print('LightGBM Model training-set accuracy score: {0:0.4f}'. format(accuracy_score(y_train, y_pred_train)))
# Testing set score
accuracy = accuracy_score(lgb_pred, y_test)
print('LightGBM Model testing-set accuracy score: {0:0.4f}'.format(accuracy_score(y_test, lgb_pred)))
# Out:
# LightGBM Model training-set accuracy score: 0.9209
# LightGBM Model testing-set accuracy score: 0.8320

# %%
# view confusion-matrix
# Print the Confusion Matrix and slice it into four pieces

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, lgb_pred)
print('Confusion matrix\n\n', cm)
# print('\nTrue Positives(TP) = ', cm[0,0])
# print('\nTrue Negatives(TN) = ', cm[1,1])
# print('\nFalse Positives(FP) = ', cm[0,1])
# print('\nFalse Negatives(FN) = ', cm[1,0])
# Out:
# Confusion matrix
#
#  [[ 44454   1793    932   2184]
#  [  2978  26217   1296  18820]
#  [   904    743  44969   3084]
#  [  2806  11218   3004 130863]]

# %%
# # visualize confusion matrix with seaborn heatmap

# cm_matrix = pd.DataFrame(data=cm, columns=['Actual Positive:1', 'Actual Negative:0'], 
#                                  index=['Predict Positive:1', 'Predict Negative:0'])

# sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='YlGnBu')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10,8))
cm = confusion_matrix(y_test, lgb_pred)
cm_matrix = pd.DataFrame(data=cm, columns=['Actual Positive:1', 'Actual Negative:0', 'Predict Positive:1', 'Predict Negative:0'],
                                 index=['Predict Positive:1', 'Predict Negative:0', 'Actual Positive:1', 'Actual Negative:0'])
sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix\n")
plt.tight_layout()

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, lgb_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.87      0.90      0.88     49363
#            2       0.66      0.53      0.59     49311
#            3       0.90      0.90      0.90     49700
#            4       0.84      0.88      0.86    147891
#
#     accuracy                           0.83    296265
#    macro avg       0.82      0.81      0.81    296265
# weighted avg       0.83      0.83      0.83    296265

# %% [markdown]
# ----

# %%
predict_train = lgb.predict(x_train)
print("train score : {}".format(lgb.score(x_train, y_train)))
predict_test = lgb.predict(x_test) 

from sklearn.metrics import classification_report
print(classification_report(y_test, lgb.predict(x_test)))
print("test score : {}".format(lgb.score(x_test, y_test)))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-c6965ad97f67> in <module>()
# ----> 1 predict_train = lgb.predict(x_train)
#       2 print("train score : {}".format(lgb.score(x_train, y_train)))
#       3 predict_test = lgb.predict(x_test)
#       4
#       5 from sklearn.metrics import classification_report
#
# /usr/local/lib/python3.7/dist-packages/lightgbm/sklearn.py in predict(self, X, raw_score, num_iteration, pred_leaf, pred_contrib, **kwargs)
#     751         """Docstring is inherited from the LGBMModel."""
#     752         result = self.predict_proba(X, raw_score, num_iteration,
# --> 753                                     pred_leaf, pred_contrib, **kwargs)
#     754         if raw_score or pred_leaf or pred_contrib:
#     755             return result
#
# /usr/local/lib/python3.7/dist-packages/lightgbm/sklearn.py in predict_proba(self, X, raw_score, num_iteration, pred_leaf, pred_contrib, **kwargs)
#     798         """
#     799         result = super(LGBMClassifier, self).predict(X, raw_score, num_iteration,
# --> 800                                                      pred_leaf, pred_contrib, **kwargs)
#     801         if self._n_classes > 2 or raw_score or pred_leaf or pred_contrib:
#     802             return result
#
# /usr/local/lib/python3.7/dist-packages/lightgbm/sklearn.py in predict(self, X, raw_score, num_iteration, pred_leaf, pred_contrib, **kwargs)
#     605                              % (self._n_features, n_features))
#     606         return self.booster_.predict(X, raw_score=raw_score, num_iteration=num_iteration,
# --> 607                                      pred_leaf=pred_leaf, pred_contrib=pred_contrib, **kwargs)
#     608
#     609     @property
#
# /usr/local/lib/python3.7/dist-packages/lightgbm/basic.py in predict(self, data, num_iteration, raw_score, pred_leaf, pred_contrib, data_has_header, is_reshape, **kwargs)
#    2201         return predictor.predict(data, num_iteration,
#    2202                                  raw_score, pred_leaf, pred_contrib,
# -> 2203                                  data_has_header, is_reshape)
#    2204
#    2205     def refit(self, data, label, decay_rate=0.9, **kwargs):
#
# /usr/local/lib/python3.7/dist-packages/lightgbm/basic.py in predict(self, data, num_iteration, raw_score, pred_leaf, pred_contrib, data_has_header, is_reshape)
#     465             preds, nrow = self.__pred_for_csc(data, num_iteration, predict_type)
#     466         elif isinstance(data, np.ndarray):
# --> 467             preds, nrow = self.__pred_for_np2d(data, num_iteration, predict_type)
#     468         elif isinstance(data, list):
#     469             try:
#
# /usr/local/lib/python3.7/dist-packages/lightgbm/basic.py in __pred_for_np2d(self, mat, num_iteration, predict_type)
#     554             return preds, nrow
#     555         else:
# --> 556             return inner_predict(mat, num_iteration, predict_type)
#     557
#     558     def __pred_for_csr(self, csr, num_iteration, predict_type):
#
# /usr/local/lib/python3.7/dist-packages/lightgbm/basic.py in inner_predict(mat, num_iteration, predict_type, preds)
#     536                 c_str(self.pred_parameter),
#     537                 ctypes.byref(out_num_preds),
# --> 538                 preds.ctypes.data_as(ctypes.POINTER(ctypes.c_double))))
#     539             if n_preds != out_num_preds.value:
#     540                 raise ValueError("Wrong length for predict results")
#
# KeyboardInterrupt:

# %% [markdown]
# ---

# %%
def get_clf_eval(y_test, lgb_pred):
    confusion = confusion_matrix(y_test, lgb_pred)
    accuracy = accuracy_score(y_test, lgb_pred)
    precision = precision_score(y_test, lgb_pred, average = 'macro')
    recall = recall_score(y_test, lgb_pred, average = 'macro')
    F1 = f1_score(y_test, lgb_pred, average = 'macro')
    # AUC = roc_auc_score(y_test, lgb_pred, multi_class='ovo')
    print('오차행렬:\n', confusion)
    print('\n정확도:{:.4f}'.format(accuracy))
    print('정밀도:{:.4f}'.format(precision))
    print('재현율:{:.4f}'.format(recall))
    print('F1:{:.4f}'.format(F1))
    # print('AUC:{:.4f}'.format(AUC))

# %%
get_clf_eval(y_test, lgb_pred)

# %% [markdown]
# ---

# %%
# plot_importance()를 이용한 피처 중요도 시각화

from lightgbm import plot_importance
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(figsize=(6, 6))
plot_importance(lgb, max_num_features=6, ax=ax) # 상위 6개만

# %% [markdown]
# ### 에러 측정

# %%
# mse = mean_squared_error(y_test, predict_test)
# r2 = r2_score(y_test, predict_test)

# %%
# print('Mean squared error: ', mse)
# print('R2 score: ', r2)

# %%
# final_result = pd.concat([y_test.reset_index(drop=True), pd.DataFrame(predict_test)], axis = 1)

# %%
# final_result.columns = ['label','predict']

# %%
# sns.regplot(x = 'label', y = 'predict', data = final_result)

# %% [markdown]
# ----

# %% [markdown]
# ### LGBMClassifier 상위 모델(?) -> HistGradientBoostingClassifier

# %%
# lgb_clf = lgb.LGBMClassifier(num_leaves=31, objective='binary')
# lgb_clf.fit(x_train, y_train)
# y_pred = lgb_clf.predict(x_test)
# accuracy_score(y_test, y_pred)

# d_train = lgb.Dataset(x_train, label=y_train)
# param = {'num_iterations': 100, 'learning_rate' : 0.1, 'max_depth' : -1, 'objective': 'binary', 'metric':'auc'}

# %%
# from sklearn.ensemble import HistGradientBoostingClassifier as hgbc

# %%
# hgbc.score(x_train)
