# %% [markdown]
# # 당뇨와 고혈압 질병 예측
# - BTH_G : 연령(그룹)
# - SBP : 수축기혈압
# - DBP : 이완기혈압
# - FBS : 공복혈당
# - SEX : 성별(남성:1, 여성:2)
# - DIS : 고혈압/당뇨병 진료여부
#   - 고혈압/당뇨병 진료내역 있음: 1
#   - 고혈압 진료내역 있음: 2
#   - 당뇨병 진료내역 있음: 3
#   - 고혈압/당뇨병 진료내역 없음: 4
# - BMI : 체질량지수

# %% [markdown]
# ## 정상 vs 비정상
# - 4(정상) : 0
# - 1 / 2 / 3(비정상) : 1
#
# - 0(정상) 기준으로 1(비정상) 오버샘플링 : RandomOversampling
# - 1(비정상) : 1 / 2 / 3 각각 레이블링 됨
#
# 1 / 2 / 3 = 비율) 1 : 3 : 1
# => 1 : 1 : 1 비율로 오버샘플링
#
# 1 / 0 = 비율) 1 : 3
# => 1 : 1 비율로 오버샘플링

# %% [markdown]
# # LightGBM
# +
# ## RandomOversampling + 질병 1, 2, 3 비율 => 1 : 1 : 1

# %% [markdown]
# ### LightGBM 설치:
#
# ```
# pip3 install lightgbm
#
# ```

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np 
import pandas as pd # 시리즈, 데이터프레임 포맷 데이터 처리를 위한 라이브러리
import warnings; warnings.filterwarnings(action='ignore') # 경고 메시지 무시
import matplotlib.pyplot as plt # 데이터 시각화 라이브러리
import pickle # 객체 입출력을 위한 라이브러리

from sklearn.model_selection import train_test_split # 훈련 데이터, 테스트 데이터 분리
from sklearn.preprocessing import StandardScaler # 정규화

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import mean_squared_error, r2_score


# LightGBM 임포트
from lightgbm import LGBMClassifier # LightGBM 불러오기

from pandas.core.common import random_state
from sklearn.ensemble import RandomForestClassifier # 랜덤포레스트 분류 알고리즘
from sklearn.tree import DecisionTreeClassifier # 의사결정나무 분류 알고리즘

import matplotlib.pyplot as plt
import seaborn as sns

# 모델 평가를 위한 metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, plot_confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %% [markdown]
# ## 데이터 불러오기

# %%
# Disease 

df = pd.read_csv('/content/drive/MyDrive/health/data/data(over_dis_vs_nor).csv', encoding='cp949')
df
# Out:
#          SEX  BTH_G  SBP  DBP  FBS   BMI  DIS  Dis
# 0          0      1   90   50   86  20.1    2    1
# 1          0      1  120   80   90  27.0    3    1
# 2          0      1  100   60  112  31.8    2    1
# 3          0      1  170  120   86  23.3    2    1
# 4          0      1  135   80  104  35.0    2    1
# ...      ...    ...  ...  ...  ...   ...  ...  ...
# 1481319    1     21  130   90  185  26.3    3    1
# 1481320    1     18  140  100  120  28.8    2    1
# 1481321    0     12  100   60  101  23.0    3    1
# 1481322    1     20  134   72  168  23.1    3    1
# 1481323    1     23  140   90  116  23.7    2    1
#
# [1481324 rows x 8 columns]

# %%
df.drop(df[df['Dis']==0].index, inplace=True)
df
# Out:
#          SEX  BTH_G  SBP  DBP  FBS   BMI  DIS  Dis
# 0          0      1   90   50   86  20.1    2    1
# 1          0      1  120   80   90  27.0    3    1
# 2          0      1  100   60  112  31.8    2    1
# 3          0      1  170  120   86  23.3    2    1
# 4          0      1  135   80  104  35.0    2    1
# ...      ...    ...  ...  ...  ...   ...  ...  ...
# 1481319    1     21  130   90  185  26.3    3    1
# 1481320    1     18  140  100  120  28.8    2    1
# 1481321    0     12  100   60  101  23.0    3    1
# 1481322    1     20  134   72  168  23.1    3    1
# 1481323    1     23  140   90  116  23.7    2    1
#
# [740662 rows x 8 columns]

# %%
# 1,0 정답 레이블 삭제
df.drop(['Dis'], axis=1, inplace=True)
df
# Out:
#          SEX  BTH_G  SBP  DBP  FBS   BMI  DIS
# 0          0      1   90   50   86  20.1    2
# 1          0      1  120   80   90  27.0    3
# 2          0      1  100   60  112  31.8    2
# 3          0      1  170  120   86  23.3    2
# 4          0      1  135   80  104  35.0    2
# ...      ...    ...  ...  ...  ...   ...  ...
# 1481319    1     21  130   90  185  26.3    3
# 1481320    1     18  140  100  120  28.8    2
# 1481321    0     12  100   60  101  23.0    3
# 1481322    1     20  134   72  168  23.1    3
# 1481323    1     23  140   90  116  23.7    2
#
# [740662 rows x 7 columns]

# %%
df.reset_index()
# Out:
#           index  SEX  BTH_G  SBP  DBP  FBS   BMI  DIS
# 0             0    0      1   90   50   86  20.1    2
# 1             1    0      1  120   80   90  27.0    3
# 2             2    0      1  100   60  112  31.8    2
# 3             3    0      1  170  120   86  23.3    2
# 4             4    0      1  135   80  104  35.0    2
# ...         ...  ...    ...  ...  ...  ...   ...  ...
# 740657  1481319    1     21  130   90  185  26.3    3
# 740658  1481320    1     18  140  100  120  28.8    2
# 740659  1481321    0     12  100   60  101  23.0    3
# 740660  1481322    1     20  134   72  168  23.1    3
# 740661  1481323    1     23  140   90  116  23.7    2
#
# [740662 rows x 8 columns]

# %%
df.reset_index(drop=True)
# Out:
#         SEX  BTH_G  SBP  DBP  FBS   BMI  DIS
# 0         0      1   90   50   86  20.1    2
# 1         0      1  120   80   90  27.0    3
# 2         0      1  100   60  112  31.8    2
# 3         0      1  170  120   86  23.3    2
# 4         0      1  135   80  104  35.0    2
# ...     ...    ...  ...  ...  ...   ...  ...
# 740657    1     21  130   90  185  26.3    3
# 740658    1     18  140  100  120  28.8    2
# 740659    0     12  100   60  101  23.0    3
# 740660    1     20  134   72  168  23.1    3
# 740661    1     23  140   90  116  23.7    2
#
# [740662 rows x 7 columns]

# %%
df.sample(frac=1.0, replace=False, weights=None, random_state=None, axis=None, ignore_index=False)
# Out:
#          SEX  BTH_G  SBP  DBP  FBS   BMI  DIS
# 387898     0     26  120   80   96  26.4    3
# 1295702    0     24  120   80  111  23.0    3
# 128321     0     27  130   80   97  25.2    3
# 334193     0     27  130  110   84  23.6    1
# 1460229    0     26  120   70  119  23.1    3
# ...      ...    ...  ...  ...  ...   ...  ...
# 436552     0      8  134   71  170  25.0    3
# 1307348    0     27  124   66  108  17.8    2
# 1320351    0     18  110   70  142  26.0    3
# 1249393    1     23  116   56   87  27.3    2
# 1453608    0     18  137   81  110  25.5    2
#
# [740662 rows x 7 columns]

# %%
df.reset_index()
# Out:
#           index  SEX  BTH_G  SBP  DBP  FBS   BMI  DIS
# 0             0    0      1   90   50   86  20.1    2
# 1             1    0      1  120   80   90  27.0    3
# 2             2    0      1  100   60  112  31.8    2
# 3             3    0      1  170  120   86  23.3    2
# 4             4    0      1  135   80  104  35.0    2
# ...         ...  ...    ...  ...  ...  ...   ...  ...
# 740657  1481319    1     21  130   90  185  26.3    3
# 740658  1481320    1     18  140  100  120  28.8    2
# 740659  1481321    0     12  100   60  101  23.0    3
# 740660  1481322    1     20  134   72  168  23.1    3
# 740661  1481323    1     23  140   90  116  23.7    2
#
# [740662 rows x 8 columns]

# %%
df.reset_index(drop=True)
# Out:
#         SEX  BTH_G  SBP  DBP  FBS   BMI  DIS
# 0         0      1   90   50   86  20.1    2
# 1         0      1  120   80   90  27.0    3
# 2         0      1  100   60  112  31.8    2
# 3         0      1  170  120   86  23.3    2
# 4         0      1  135   80  104  35.0    2
# ...     ...    ...  ...  ...  ...   ...  ...
# 740657    1     21  130   90  185  26.3    3
# 740658    1     18  140  100  120  28.8    2
# 740659    0     12  100   60  101  23.0    3
# 740660    1     20  134   72  168  23.1    3
# 740661    1     23  140   90  116  23.7    2
#
# [740662 rows x 7 columns]

# %%
df.notnull().sum()
# Out:
# SEX      740662
# BTH_G    740662
# SBP      740662
# DBP      740662
# FBS      740662
# BMI      740662
# DIS      740662
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 740662 entries, 0 to 1481323
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   SEX     740662 non-null  int64
#  1   BTH_G   740662 non-null  int64
#  2   SBP     740662 non-null  int64
#  3   DBP     740662 non-null  int64
#  4   FBS     740662 non-null  int64
#  5   BMI     740662 non-null  float64
#  6   DIS     740662 non-null  int64
# dtypes: float64(1), int64(6)
# memory usage: 45.2 MB

# %%
# feature와 target 분리(설명변수 및 목표변수 분리)
x = df.drop(['DIS'], axis=1) # df[df.columns.difference(['target'])]
y = np.array(df['DIS']) # y = df['target']

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x)
x_test = sc.transform(x)

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2, random_state=42) # 기본 0.25
# x_test,x_val,y_test,y_val=train_test_split(x,y,test_size=0.1, random_state=42)

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# print(x_val.shape)
# print(y_val.shape)
# Out:
# (592529, 6)
# (592529,)
# (148133, 6)
# (148133,)

# %% [markdown]
# ### lightgbm 파라미터 정의

# %%
hyper_params = {
    'num_iterations': 28000,
    'task': 'train',
    'boosting_type': 'gbdt',
    'objective': 'multiclass',
    'metric': 'multi_logloss', # ['auc_mu', 'multi_error', 
    'learning_rate': 0.1, # 0.005
    'feature_fraction': 1.0, # 0.9
    'bagging_fraction': 1.0, # 0.7
    'bagging_freq': 10,
    'verbose': 0,
    'max_depth': 8, # 20
    # 'min_data' : 20
    # 'min_child_samples' =60
    'num_leaves': 128, # 31
    'max_bin': 512, # 255
    # 'device' : 'gpu'
}

# %% [markdown]
# ### 훈련

# %%
from lightgbm import LGBMClassifier

lgb = LGBMClassifier(**hyper_params)
evals = [(x_train, y_train),(x_test, y_test)]

lgb.fit(x_train, y_train, eval_set = evals, early_stopping_rounds=100, verbose = True) # eval_metric='multi_auc'
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# [16826]	training's multi_logloss: 0.0662123	valid_1's multi_logloss: 0.242761
# [16827]	training's multi_logloss: 0.0662079	valid_1's multi_logloss: 0.242764
# [16828]	training's multi_logloss: 0.0662006	valid_1's multi_logloss: 0.24276
# [16829]	training's multi_logloss: 0.0661911	valid_1's multi_logloss: 0.242751
# [16830]	training's multi_logloss: 0.0661811	valid_1's multi_logloss: 0.242741
# [16831]	training's multi_logloss: 0.0661656	valid_1's multi_logloss: 0.242725
# [16832]	training's multi_logloss: 0.0661568	valid_1's multi_logloss: 0.242721
# [16833]	training's multi_logloss: 0.066151	valid_1's multi_logloss: 0.242715
# [16834]	training's multi_logloss: 0.0661486	valid_1's multi_logloss: 0.242715
# [16835]	training's multi_logloss: 0.0661406	valid_1's multi_logloss: 0.242711
# [16836]	training's multi_logloss: 0.0661355	valid_1's multi_logloss: 0.242712
# [16837]	training's multi_logloss: 0.0661283	valid_1's multi_logloss: 0.242708
# [16838]	training's multi_logloss: 0.0661227	valid_1's multi_logloss: 0.242711
# [16839]	training's multi_logloss: 0.0661175	valid_1's multi_logloss: 0.242708
# [16840]	training's multi_logloss: 0.0661048	valid_1's multi_logloss: 0.242698
# [16841]	training's multi_logloss: 0.0661	valid_1's multi_logloss: 0.242706
# [16842]	training's multi_logloss: 0.0660952	valid_1's multi_logloss: 0.242701
# [16843]	training's multi_logloss: 0.0660936	valid_1's multi_logloss: 0.242705
# [16844]	training's multi_logloss: 0.0660883	valid_1's multi_logloss: 0.242703
# [16845]	training's multi_logloss: 0.0660802	valid_1's multi_logloss: 0.242693
# [16846]	training's multi_logloss: 0.0660709	valid_1's multi_logloss: 0.242683
# [16847]	training's multi_logloss: 0.0660694	valid_1's multi_logloss: 0.242687
# [16848]	training's multi_logloss: 0.0660686	valid_1's multi_logloss: 0.242693
# [16849]	training's multi_logloss: 0.0660655	valid_1's multi_logloss: 0.242694
# [16850]	training's multi_logloss: 0.0660614	valid_1's multi_logloss: 0.242694
# [16851]	training's multi_logloss: 0.066058	valid_1's multi_logloss: 0.242693
# [16852]	training's multi_logloss: 0.0660552	valid_1's multi_logloss: 0.242689
# [16853]	training's multi_logloss: 0.0660491	valid_1's multi_logloss: 0.24269
# [16854]	training's multi_logloss: 0.0660461	valid_1's multi_logloss: 0.242692
# [16855]	training's multi_logloss: 0.0660441	valid_1's multi_logloss: 0.242695
# [16856]	training's multi_logloss: 0.0660295	valid_1's multi_logloss: 0.242695
# [16857]	training's multi_logloss: 0.066011	valid_1's multi_logloss: 0.242681
# [16858]	training's multi_logloss: 0.066002	valid_1's multi_logloss: 0.242679
# [16859]	training's multi_logloss: 0.0659874	valid_1's multi_logloss: 0.242674
# [16860]	training's multi_logloss: 0.06598	valid_1's multi_logloss: 0.242672
# [16861]	training's multi_logloss: 0.065977	valid_1's multi_logloss: 0.242675
# [16862]	training's multi_logloss: 0.065968	valid_1's multi_logloss: 0.242672
# [16863]	training's multi_logloss: 0.0659545	valid_1's multi_logloss: 0.242662
# [16864]	training's multi_logloss: 0.0659476	valid_1's multi_logloss: 0.24266
# [16865]	training's multi_logloss: 0.0659394	valid_1's multi_logloss: 0.242664
# [16866]	training's multi_logloss: 0.0659317	valid_1's multi_logloss: 0.242658
# [16867]	training's multi_logloss: 0.065927	valid_1's multi_logloss: 0.242655
# [16868]	training's multi_logloss: 0.0659253	valid_1's multi_logloss: 0.242662
# [16869]	training's multi_logloss: 0.0659222	valid_1's multi_logloss: 0.242668
# [16870]	training's multi_logloss: 0.0659163	valid_1's multi_logloss: 0.242663
# [16871]	training's multi_logloss: 0.0659103	valid_1's multi_logloss: 0.242657
# [16872]	training's multi_logloss: 0.065907	valid_1's multi_logloss: 0.24266
# [16873]	training's multi_logloss: 0.0659023	valid_1's multi_logloss: 0.242659
# [16874]	training's multi_logloss: 0.0658938	valid_1's multi_logloss: 0.242651
# [16875]	training's multi_logloss: 0.0658912	valid_1's multi_logloss: 0.242656
# [16876]	training's multi_logloss: 0.0658846	valid_1's multi_logloss: 0.242655
# [16877]	training's multi_logloss: 0.0658705	valid_1's multi_logloss: 0.242651
# [16878]	training's multi_logloss: 0.065866	valid_1's multi_logloss: 0.242646
# [16879]	training's multi_logloss: 0.0658613	valid_1's multi_logloss: 0.242649
# [16880]	training's multi_logloss: 0.065855	valid_1's multi_logloss: 0.242649
# [16881]	training's multi_logloss: 0.0658499	valid_1's multi_logloss: 0.242651
# [16882]	training's multi_logloss: 0.0658447	valid_1's multi_logloss: 0.242648
# [16883]	training's multi_logloss: 0.0658394	valid_1's multi_logloss: 0.24265
# [16884]	training's multi_logloss: 0.0658252	valid_1's multi_logloss: 0.242633
# [16885]	training's multi_logloss: 0.0658178	valid_1's multi_logloss: 0.242628
# [16886]	training's multi_logloss: 0.0658135	valid_1's multi_logloss: 0.24263
# [16887]	training's multi_logloss: 0.0658085	valid_1's multi_logloss: 0.242632
# [16888]	training's multi_logloss: 0.0657977	valid_1's multi_logloss: 0.242638
# [16889]	training's multi_logloss: 0.0657884	valid_1's multi_logloss: 0.242632
# [16890]	training's multi_logloss: 0.0657844	valid_1's multi_logloss: 0.242627
# [16891]	training's multi_logloss: 0.0657776	valid_1's multi_logloss: 0.24262
# [16892]	training's multi_logloss: 0.0657735	valid_1's multi_logloss: 0.242615
# [16893]	training's multi_logloss: 0.0657657	valid_1's multi_logloss: 0.242613
# [16894]	training's multi_logloss: 0.0657533	valid_1's multi_logloss: 0.242608
# [16895]	training's multi_logloss: 0.0657433	valid_1's multi_logloss: 0.242602
# [16896]	training's multi_logloss: 0.0657367	valid_1's multi_logloss: 0.242595
# [16897]	training's multi_logloss: 0.0657341	valid_1's multi_logloss: 0.242599
# [16898]	training's multi_logloss: 0.0657209	valid_1's multi_logloss: 0.242596
# [16899]	training's multi_logloss: 0.0657093	valid_1's multi_logloss: 0.24259
# [16900]	training's multi_logloss: 0.0657016	valid_1's multi_logloss: 0.242587
# [16901]	training's multi_logloss: 0.0657002	valid_1's multi_logloss: 0.242589
# [16902]	training's multi_logloss: 0.0656954	valid_1's multi_logloss: 0.24259
# [16903]	training's multi_logloss: 0.0656946	valid_1's multi_logloss: 0.242596
# [16904]	training's multi_logloss: 0.0656855	valid_1's multi_logloss: 0.24259
# [16905]	training's multi_logloss: 0.0656801	valid_1's multi_logloss: 0.242594
# [16906]	training's multi_logloss: 0.0656795	valid_1's multi_logloss: 0.242598
# [16907]	training's multi_logloss: 0.0656785	valid_1's multi_logloss: 0.242601
# [16908]	training's multi_logloss: 0.0656747	valid_1's multi_logloss: 0.242601
# [16909]	training's multi_logloss: 0.0656703	valid_1's multi_logloss: 0.242601
# [16910]	training's multi_logloss: 0.0656694	valid_1's multi_logloss: 0.242608
# [16911]	training's multi_logloss: 0.0656648	valid_1's multi_logloss: 0.242601
# [16912]	training's multi_logloss: 0.0656637	valid_1's multi_logloss: 0.242603
# [16913]	training's multi_logloss: 0.0656472	valid_1's multi_logloss: 0.242595
# [16914]	training's multi_logloss: 0.0656382	valid_1's multi_logloss: 0.242596
# [16915]	training's multi_logloss: 0.0656297	valid_1's multi_logloss: 0.242596
# [16916]	training's multi_logloss: 0.0656183	valid_1's multi_logloss: 0.242586
# [16917]	training's multi_logloss: 0.0656003	valid_1's multi_logloss: 0.242573
# [16918]	training's multi_logloss: 0.0655817	valid_1's multi_logloss: 0.242562
# [16919]	training's multi_logloss: 0.0655699	valid_1's multi_logloss: 0.242552
# [16920]	training's multi_logloss: 0.0655513	valid_1's multi_logloss: 0.242536
# [16921]	training's multi_logloss: 0.0655355	valid_1's multi_logloss: 0.24252
# [16922]	training's multi_logloss: 0.065517	valid_1's multi_logloss: 0.242506
# [16923]	training's multi_logloss: 0.065502	valid_1's multi_logloss: 0.242496
# [16924]	training's multi_logloss: 0.0654884	valid_1's multi_logloss: 0.242491
# [16925]	training's multi_logloss: 0.0654773	valid_1's multi_logloss: 0.242485
# [16926]	training's multi_logloss: 0.0654562	valid_1's multi_logloss: 0.242464
# [16927]	training's multi_logloss: 0.0654494	valid_1's multi_logloss: 0.242456
# [16928]	training's multi_logloss: 0.0654386	valid_1's multi_logloss: 0.242454
# [16929]	training's multi_logloss: 0.0654246	valid_1's multi_logloss: 0.24244
# [16930]	training's multi_logloss: 0.0654157	valid_1's multi_logloss: 0.242438
# [16931]	training's multi_logloss: 0.0654004	valid_1's multi_logloss: 0.24243
# [16932]	training's multi_logloss: 0.065385	valid_1's multi_logloss: 0.242418
# [16933]	training's multi_logloss: 0.0653628	valid_1's multi_logloss: 0.242397
# [16934]	training's multi_logloss: 0.065346	valid_1's multi_logloss: 0.242385
# [16935]	training's multi_logloss: 0.0653309	valid_1's multi_logloss: 0.242375
# [16936]	training's multi_logloss: 0.0653065	valid_1's multi_logloss: 0.242346
# [16937]	training's multi_logloss: 0.0653024	valid_1's multi_logloss: 0.24235
# [16938]	training's multi_logloss: 0.0652951	valid_1's multi_logloss: 0.242347
# [16939]	training's multi_logloss: 0.0652916	valid_1's multi_logloss: 0.242349
# [16940]	training's multi_logloss: 0.0652864	valid_1's multi_logloss: 0.242344
# [16941]	training's multi_logloss: 0.0652788	valid_1's multi_logloss: 0.242338
# [16942]	training's multi_logloss: 0.0652721	valid_1's multi_logloss: 0.242338
# [16943]	training's multi_logloss: 0.065266	valid_1's multi_logloss: 0.242345
# [16944]	training's multi_logloss: 0.0652581	valid_1's multi_logloss: 0.242336
# [16945]	training's multi_logloss: 0.065254	valid_1's multi_logloss: 0.242336
# [16946]	training's multi_logloss: 0.0652477	valid_1's multi_logloss: 0.242338
# [16947]	training's multi_logloss: 0.0652438	valid_1's multi_logloss: 0.242344
# [16948]	training's multi_logloss: 0.0652397	valid_1's multi_logloss: 0.242349
# [16949]	training's multi_logloss: 0.0652314	valid_1's multi_logloss: 0.242345
# [16950]	training's multi_logloss: 0.0652259	valid_1's multi_logloss: 0.242346
# [16951]	training's multi_logloss: 0.0652204	valid_1's multi_logloss: 0.242341
# [16952]	training's multi_logloss: 0.0652151	valid_1's multi_logloss: 0.242349
# [16953]	training's multi_logloss: 0.0652088	valid_1's multi_logloss: 0.242354
# [16954]	training's multi_logloss: 0.0651915	valid_1's multi_logloss: 0.242348
# [16955]	training's multi_logloss: 0.0651809	valid_1's multi_logloss: 0.242343
# [16956]	training's multi_logloss: 0.0651732	valid_1's multi_logloss: 0.242337
# [16957]	training's multi_logloss: 0.0651679	valid_1's multi_logloss: 0.242338
# [16958]	training's multi_logloss: 0.0651622	valid_1's multi_logloss: 0.242334
# [16959]	training's multi_logloss: 0.0651538	valid_1's multi_logloss: 0.242341
# [16960]	training's multi_logloss: 0.065143	valid_1's multi_logloss: 0.242333
# [16961]	training's multi_logloss: 0.0651339	valid_1's multi_logloss: 0.242328
# [16962]	training's multi_logloss: 0.0651302	valid_1's multi_logloss: 0.242326
# [16963]	training's multi_logloss: 0.0651221	valid_1's multi_logloss: 0.242327
# [16964]	training's multi_logloss: 0.0651125	valid_1's multi_logloss: 0.242319
# [16965]	training's multi_logloss: 0.065106	valid_1's multi_logloss: 0.242317
# [16966]	training's multi_logloss: 0.0651002	valid_1's multi_logloss: 0.242313
# [16967]	training's multi_logloss: 0.0650894	valid_1's multi_logloss: 0.242306
# [16968]	training's multi_logloss: 0.0650733	valid_1's multi_logloss: 0.242301
# [16969]	training's multi_logloss: 0.0650595	valid_1's multi_logloss: 0.242293
# [16970]	training's multi_logloss: 0.0650455	valid_1's multi_logloss: 0.242285
# [16971]	training's multi_logloss: 0.0650337	valid_1's multi_logloss: 0.242281
# [16972]	training's multi_logloss: 0.0650301	valid_1's multi_logloss: 0.242285
# [16973]	training's multi_logloss: 0.0650242	valid_1's multi_logloss: 0.242289
# [16974]	training's multi_logloss: 0.0650193	valid_1's multi_logloss: 0.242291
# [16975]	training's multi_logloss: 0.0650013	valid_1's multi_logloss: 0.242283
# [16976]	training's multi_logloss: 0.0649948	valid_1's multi_logloss: 0.242278
# [16977]	training's multi_logloss: 0.0649878	valid_1's multi_logloss: 0.242272
# [16978]	training's multi_logloss: 0.0649831	valid_1's multi_logloss: 0.242269
# [16979]	training's multi_logloss: 0.064978	valid_1's multi_logloss: 0.242273
# [16980]	training's multi_logloss: 0.0649643	valid_1's multi_logloss: 0.242264
# [16981]	training's multi_logloss: 0.0649542	valid_1's multi_logloss: 0.242257
# [16982]	training's multi_logloss: 0.0649462	valid_1's multi_logloss: 0.242248
# [16983]	training's multi_logloss: 0.0649389	valid_1's multi_logloss: 0.242238
# [16984]	training's multi_logloss: 0.0649194	valid_1's multi_logloss: 0.242216
# [16985]	training's multi_logloss: 0.0649108	valid_1's multi_logloss: 0.242208
# [16986]	training's multi_logloss: 0.0648935	valid_1's multi_logloss: 0.242197
# [16987]	training's multi_logloss: 0.0648878	valid_1's multi_logloss: 0.242194
# [16988]	training's multi_logloss: 0.0648785	valid_1's multi_logloss: 0.24219
# [16989]	training's multi_logloss: 0.0648746	valid_1's multi_logloss: 0.242189
# [16990]	training's multi_logloss: 0.0648644	valid_1's multi_logloss: 0.242186
# [16991]	training's multi_logloss: 0.0648496	valid_1's multi_logloss: 0.24218
# [16992]	training's multi_logloss: 0.0648281	valid_1's multi_logloss: 0.242157
# [16993]	training's multi_logloss: 0.0648226	valid_1's multi_logloss: 0.242154
# [16994]	training's multi_logloss: 0.0648185	valid_1's multi_logloss: 0.242156
# [16995]	training's multi_logloss: 0.0648114	valid_1's multi_logloss: 0.242156
# [16996]	training's multi_logloss: 0.0648074	valid_1's multi_logloss: 0.242153
# [16997]	training's multi_logloss: 0.0647929	valid_1's multi_logloss: 0.242146
# [16998]	training's multi_logloss: 0.0647723	valid_1's multi_logloss: 0.242129
# [16999]	training's multi_logloss: 0.0647569	valid_1's multi_logloss: 0.242123
# [17000]	training's multi_logloss: 0.0647526	valid_1's multi_logloss: 0.24213
# [17001]	training's multi_logloss: 0.0647463	valid_1's multi_logloss: 0.242127
# [17002]	training's multi_logloss: 0.0647356	valid_1's multi_logloss: 0.242123
# [17003]	training's multi_logloss: 0.0647277	valid_1's multi_logloss: 0.242119
# [17004]	training's multi_logloss: 0.0647116	valid_1's multi_logloss: 0.242106
# [17005]	training's multi_logloss: 0.0647065	valid_1's multi_logloss: 0.242104
# [17006]	training's multi_logloss: 0.0647022	valid_1's multi_logloss: 0.242103
# [17007]	training's multi_logloss: 0.0646771	valid_1's multi_logloss: 0.242083
# [17008]	training's multi_logloss: 0.0646731	valid_1's multi_logloss: 0.24209
# [17009]	training's multi_logloss: 0.0646658	valid_1's multi_logloss: 0.242078
# [17010]	training's multi_logloss: 0.0646581	valid_1's multi_logloss: 0.242077
# [17011]	training's multi_logloss: 0.0646501	valid_1's multi_logloss: 0.242069
# [17012]	training's multi_logloss: 0.0646352	valid_1's multi_logloss: 0.24206
# [17013]	training's multi_logloss: 0.0646249	valid_1's multi_logloss: 0.242062
# [17014]	training's multi_logloss: 0.0646147	valid_1's multi_logloss: 0.242058
# [17015]	training's multi_logloss: 0.0646058	valid_1's multi_logloss: 0.24205
# [17016]	training's multi_logloss: 0.0645912	valid_1's multi_logloss: 0.24204
# [17017]	training's multi_logloss: 0.064587	valid_1's multi_logloss: 0.242042
# [17018]	training's multi_logloss: 0.0645812	valid_1's multi_logloss: 0.242041
# [17019]	training's multi_logloss: 0.0645665	valid_1's multi_logloss: 0.24203
# [17020]	training's multi_logloss: 0.0645549	valid_1's multi_logloss: 0.242027
# [17021]	training's multi_logloss: 0.0645495	valid_1's multi_logloss: 0.242028
# [17022]	training's multi_logloss: 0.0645418	valid_1's multi_logloss: 0.24202
# [17023]	training's multi_logloss: 0.0645312	valid_1's multi_logloss: 0.242009
# [17024]	training's multi_logloss: 0.0645233	valid_1's multi_logloss: 0.242008
# [17025]	training's multi_logloss: 0.0645142	valid_1's multi_logloss: 0.242009
# [17026]	training's multi_logloss: 0.0645042	valid_1's multi_logloss: 0.242011
# [17027]	training's multi_logloss: 0.0644992	valid_1's multi_logloss: 0.242014
# [17028]	training's multi_logloss: 0.064492	valid_1's multi_logloss: 0.24201
# [17029]	training's multi_logloss: 0.0644855	valid_1's multi_logloss: 0.242007
# [17030]	training's multi_logloss: 0.064475	valid_1's multi_logloss: 0.242001
# [17031]	training's multi_logloss: 0.0644642	valid_1's multi_logloss: 0.241997
# [17032]	training's multi_logloss: 0.0644557	valid_1's multi_logloss: 0.241995
# [17033]	training's multi_logloss: 0.0644411	valid_1's multi_logloss: 0.241981
# [17034]	training's multi_logloss: 0.064434	valid_1's multi_logloss: 0.241979
# [17035]	training's multi_logloss: 0.0644263	valid_1's multi_logloss: 0.241978
# [17036]	training's multi_logloss: 0.0644185	valid_1's multi_logloss: 0.241974
# [17037]	training's multi_logloss: 0.0644072	valid_1's multi_logloss: 0.241966
# [17038]	training's multi_logloss: 0.0644004	valid_1's multi_logloss: 0.241963
# [17039]	training's multi_logloss: 0.0643957	valid_1's multi_logloss: 0.241967
# [17040]	training's multi_logloss: 0.0643856	valid_1's multi_logloss: 0.241959
# [17041]	training's multi_logloss: 0.0643825	valid_1's multi_logloss: 0.241966
# [17042]	training's multi_logloss: 0.0643791	valid_1's multi_logloss: 0.241967
# [17043]	training's multi_logloss: 0.0643748	valid_1's multi_logloss: 0.241966
# [17044]	training's multi_logloss: 0.0643717	valid_1's multi_logloss: 0.241966
# [17045]	training's multi_logloss: 0.0643687	valid_1's multi_logloss: 0.241978
# [17046]	training's multi_logloss: 0.0643613	valid_1's multi_logloss: 0.241979
# [17047]	training's multi_logloss: 0.0643544	valid_1's multi_logloss: 0.241976
# [17048]	training's multi_logloss: 0.0643466	valid_1's multi_logloss: 0.241973
# [17049]	training's multi_logloss: 0.0643231	valid_1's multi_logloss: 0.241958
# [17050]	training's multi_logloss: 0.0643109	valid_1's multi_logloss: 0.241952
# [17051]	training's multi_logloss: 0.0642896	valid_1's multi_logloss: 0.241934
# [17052]	training's multi_logloss: 0.0642706	valid_1's multi_logloss: 0.241918
# [17053]	training's multi_logloss: 0.0642612	valid_1's multi_logloss: 0.241908
# [17054]	training's multi_logloss: 0.0642561	valid_1's multi_logloss: 0.241907
# [17055]	training's multi_logloss: 0.0642499	valid_1's multi_logloss: 0.241903
# [17056]	training's multi_logloss: 0.0642424	valid_1's multi_logloss: 0.241897
# [17057]	training's multi_logloss: 0.0642281	valid_1's multi_logloss: 0.241883
# [17058]	training's multi_logloss: 0.0642125	valid_1's multi_logloss: 0.241877
# [17059]	training's multi_logloss: 0.0641988	valid_1's multi_logloss: 0.241863
# [17060]	training's multi_logloss: 0.0641826	valid_1's multi_logloss: 0.241849
# [17061]	training's multi_logloss: 0.0641664	valid_1's multi_logloss: 0.241831
# [17062]	training's multi_logloss: 0.0641572	valid_1's multi_logloss: 0.24182
# [17063]	training's multi_logloss: 0.0641515	valid_1's multi_logloss: 0.241815
# [17064]	training's multi_logloss: 0.0641436	valid_1's multi_logloss: 0.241815
# [17065]	training's multi_logloss: 0.0641397	valid_1's multi_logloss: 0.241812
# [17066]	training's multi_logloss: 0.0641352	valid_1's multi_logloss: 0.241808
# [17067]	training's multi_logloss: 0.0641294	valid_1's multi_logloss: 0.241801
# [17068]	training's multi_logloss: 0.0641115	valid_1's multi_logloss: 0.241787
# [17069]	training's multi_logloss: 0.0641019	valid_1's multi_logloss: 0.241787
# [17070]	training's multi_logloss: 0.0640868	valid_1's multi_logloss: 0.241772
# [17071]	training's multi_logloss: 0.0640804	valid_1's multi_logloss: 0.241772
# [17072]	training's multi_logloss: 0.0640749	valid_1's multi_logloss: 0.241766
# [17073]	training's multi_logloss: 0.064072	valid_1's multi_logloss: 0.241771
# [17074]	training's multi_logloss: 0.0640675	valid_1's multi_logloss: 0.241769
# [17075]	training's multi_logloss: 0.0640645	valid_1's multi_logloss: 0.241774
# [17076]	training's multi_logloss: 0.0640499	valid_1's multi_logloss: 0.241768
# [17077]	training's multi_logloss: 0.0640356	valid_1's multi_logloss: 0.24176
# [17078]	training's multi_logloss: 0.064028	valid_1's multi_logloss: 0.241758
# [17079]	training's multi_logloss: 0.0640226	valid_1's multi_logloss: 0.241757
# [17080]	training's multi_logloss: 0.0640207	valid_1's multi_logloss: 0.241761
# [17081]	training's multi_logloss: 0.0640139	valid_1's multi_logloss: 0.241759
# [17082]	training's multi_logloss: 0.0640083	valid_1's multi_logloss: 0.241755
# [17083]	training's multi_logloss: 0.0639934	valid_1's multi_logloss: 0.241749
# [17084]	training's multi_logloss: 0.0639901	valid_1's multi_logloss: 0.241749
# [17085]	training's multi_logloss: 0.0639753	valid_1's multi_logloss: 0.24174
# [17086]	training's multi_logloss: 0.0639704	valid_1's multi_logloss: 0.241736
# [17087]	training's multi_logloss: 0.0639599	valid_1's multi_logloss: 0.241728
# [17088]	training's multi_logloss: 0.063957	valid_1's multi_logloss: 0.241727
# [17089]	training's multi_logloss: 0.0639486	valid_1's multi_logloss: 0.241724
# [17090]	training's multi_logloss: 0.0639443	valid_1's multi_logloss: 0.241724
# [17091]	training's multi_logloss: 0.0639337	valid_1's multi_logloss: 0.241718
# [17092]	training's multi_logloss: 0.0639186	valid_1's multi_logloss: 0.241705
# [17093]	training's multi_logloss: 0.0639106	valid_1's multi_logloss: 0.241706
# [17094]	training's multi_logloss: 0.0638944	valid_1's multi_logloss: 0.241694
# [17095]	training's multi_logloss: 0.0638757	valid_1's multi_logloss: 0.241673
# [17096]	training's multi_logloss: 0.0638652	valid_1's multi_logloss: 0.241675
# [17097]	training's multi_logloss: 0.0638614	valid_1's multi_logloss: 0.241678
# [17098]	training's multi_logloss: 0.0638479	valid_1's multi_logloss: 0.241672
# [17099]	training's multi_logloss: 0.0638385	valid_1's multi_logloss: 0.241661
# [17100]	training's multi_logloss: 0.0638277	valid_1's multi_logloss: 0.241664
# [17101]	training's multi_logloss: 0.0638158	valid_1's multi_logloss: 0.241654
# [17102]	training's multi_logloss: 0.0638104	valid_1's multi_logloss: 0.241653
# [17103]	training's multi_logloss: 0.0638045	valid_1's multi_logloss: 0.241648
# [17104]	training's multi_logloss: 0.0637973	valid_1's multi_logloss: 0.241646
# [17105]	training's multi_logloss: 0.0637935	valid_1's multi_logloss: 0.241651
# [17106]	training's multi_logloss: 0.0637819	valid_1's multi_logloss: 0.24165
# [17107]	training's multi_logloss: 0.0637784	valid_1's multi_logloss: 0.241652
# [17108]	training's multi_logloss: 0.0637742	valid_1's multi_logloss: 0.241659
# [17109]	training's multi_logloss: 0.0637585	valid_1's multi_logloss: 0.241644
# [17110]	training's multi_logloss: 0.0637541	valid_1's multi_logloss: 0.241654
# [17111]	training's multi_logloss: 0.063747	valid_1's multi_logloss: 0.24166
# [17112]	training's multi_logloss: 0.0637303	valid_1's multi_logloss: 0.241652
# [17113]	training's multi_logloss: 0.0637261	valid_1's multi_logloss: 0.241653
# [17114]	training's multi_logloss: 0.0637099	valid_1's multi_logloss: 0.241641
# [17115]	training's multi_logloss: 0.0636937	valid_1's multi_logloss: 0.241633
# [17116]	training's multi_logloss: 0.0636678	valid_1's multi_logloss: 0.241609
# [17117]	training's multi_logloss: 0.0636606	valid_1's multi_logloss: 0.241604
# [17118]	training's multi_logloss: 0.0636377	valid_1's multi_logloss: 0.241586
# [17119]	training's multi_logloss: 0.0636256	valid_1's multi_logloss: 0.241581
# [17120]	training's multi_logloss: 0.0636071	valid_1's multi_logloss: 0.241566
# [17121]	training's multi_logloss: 0.0636013	valid_1's multi_logloss: 0.241566
# [17122]	training's multi_logloss: 0.0635957	valid_1's multi_logloss: 0.24157
# [17123]	training's multi_logloss: 0.0635837	valid_1's multi_logloss: 0.24156
# [17124]	training's multi_logloss: 0.063558	valid_1's multi_logloss: 0.241542
# [17125]	training's multi_logloss: 0.063541	valid_1's multi_logloss: 0.241536
# [17126]	training's multi_logloss: 0.0635162	valid_1's multi_logloss: 0.241513
# [17127]	training's multi_logloss: 0.0635069	valid_1's multi_logloss: 0.241509
# [17128]	training's multi_logloss: 0.0635035	valid_1's multi_logloss: 0.241511
# [17129]	training's multi_logloss: 0.0634836	valid_1's multi_logloss: 0.241499
# [17130]	training's multi_logloss: 0.0634737	valid_1's multi_logloss: 0.241493
# [17131]	training's multi_logloss: 0.0634608	valid_1's multi_logloss: 0.24148
# [17132]	training's multi_logloss: 0.0634534	valid_1's multi_logloss: 0.241485
# [17133]	training's multi_logloss: 0.0634441	valid_1's multi_logloss: 0.241485
# [17134]	training's multi_logloss: 0.0634319	valid_1's multi_logloss: 0.241476
# [17135]	training's multi_logloss: 0.0634189	valid_1's multi_logloss: 0.24147
# [17136]	training's multi_logloss: 0.0634028	valid_1's multi_logloss: 0.241458
# [17137]	training's multi_logloss: 0.0633849	valid_1's multi_logloss: 0.241445
# [17138]	training's multi_logloss: 0.0633734	valid_1's multi_logloss: 0.241437
# [17139]	training's multi_logloss: 0.0633636	valid_1's multi_logloss: 0.241436
# [17140]	training's multi_logloss: 0.0633537	valid_1's multi_logloss: 0.241429
# [17141]	training's multi_logloss: 0.0633433	valid_1's multi_logloss: 0.241418
# [17142]	training's multi_logloss: 0.0633232	valid_1's multi_logloss: 0.241408
# [17143]	training's multi_logloss: 0.0633133	valid_1's multi_logloss: 0.241406
# [17144]	training's multi_logloss: 0.0633097	valid_1's multi_logloss: 0.241407
# [17145]	training's multi_logloss: 0.0633051	valid_1's multi_logloss: 0.241406
# [17146]	training's multi_logloss: 0.0632989	valid_1's multi_logloss: 0.241407
# [17147]	training's multi_logloss: 0.0632938	valid_1's multi_logloss: 0.241408
# [17148]	training's multi_logloss: 0.0632873	valid_1's multi_logloss: 0.241413
# [17149]	training's multi_logloss: 0.0632767	valid_1's multi_logloss: 0.241408
# [17150]	training's multi_logloss: 0.0632605	valid_1's multi_logloss: 0.241397
# [17151]	training's multi_logloss: 0.0632469	valid_1's multi_logloss: 0.24139
# [17152]	training's multi_logloss: 0.0632437	valid_1's multi_logloss: 0.241392
# [17153]	training's multi_logloss: 0.0632298	valid_1's multi_logloss: 0.241392
# [17154]	training's multi_logloss: 0.0632234	valid_1's multi_logloss: 0.24139
# [17155]	training's multi_logloss: 0.0632158	valid_1's multi_logloss: 0.241387
# [17156]	training's multi_logloss: 0.0632118	valid_1's multi_logloss: 0.241388
# [17157]	training's multi_logloss: 0.0632084	valid_1's multi_logloss: 0.24139
# [17158]	training's multi_logloss: 0.0631997	valid_1's multi_logloss: 0.241379
# [17159]	training's multi_logloss: 0.0631807	valid_1's multi_logloss: 0.241362
# [17160]	training's multi_logloss: 0.0631747	valid_1's multi_logloss: 0.241361
# [17161]	training's multi_logloss: 0.0631587	valid_1's multi_logloss: 0.241349
# [17162]	training's multi_logloss: 0.0631438	valid_1's multi_logloss: 0.241338
# [17163]	training's multi_logloss: 0.0631308	valid_1's multi_logloss: 0.241332
# [17164]	training's multi_logloss: 0.0631121	valid_1's multi_logloss: 0.241321
# [17165]	training's multi_logloss: 0.063101	valid_1's multi_logloss: 0.241321
# [17166]	training's multi_logloss: 0.0630931	valid_1's multi_logloss: 0.241316
# [17167]	training's multi_logloss: 0.0630894	valid_1's multi_logloss: 0.241314
# [17168]	training's multi_logloss: 0.063082	valid_1's multi_logloss: 0.241317
# [17169]	training's multi_logloss: 0.0630731	valid_1's multi_logloss: 0.241313
# [17170]	training's multi_logloss: 0.0630606	valid_1's multi_logloss: 0.241303
# [17171]	training's multi_logloss: 0.0630548	valid_1's multi_logloss: 0.241306
# [17172]	training's multi_logloss: 0.0630363	valid_1's multi_logloss: 0.24129
# [17173]	training's multi_logloss: 0.0630252	valid_1's multi_logloss: 0.241281
# [17174]	training's multi_logloss: 0.0630137	valid_1's multi_logloss: 0.24128
# [17175]	training's multi_logloss: 0.063001	valid_1's multi_logloss: 0.241272
# [17176]	training's multi_logloss: 0.0629946	valid_1's multi_logloss: 0.241269
# [17177]	training's multi_logloss: 0.0629871	valid_1's multi_logloss: 0.241263
# [17178]	training's multi_logloss: 0.0629808	valid_1's multi_logloss: 0.241261
# [17179]	training's multi_logloss: 0.0629752	valid_1's multi_logloss: 0.24126
# [17180]	training's multi_logloss: 0.0629527	valid_1's multi_logloss: 0.241243
# [17181]	training's multi_logloss: 0.0629423	valid_1's multi_logloss: 0.241235
# [17182]	training's multi_logloss: 0.062934	valid_1's multi_logloss: 0.241229
# [17183]	training's multi_logloss: 0.06292	valid_1's multi_logloss: 0.24122
# [17184]	training's multi_logloss: 0.0629072	valid_1's multi_logloss: 0.241212
# [17185]	training's multi_logloss: 0.0628954	valid_1's multi_logloss: 0.241204
# [17186]	training's multi_logloss: 0.0628692	valid_1's multi_logloss: 0.24118
# [17187]	training's multi_logloss: 0.0628499	valid_1's multi_logloss: 0.241162
# [17188]	training's multi_logloss: 0.0628417	valid_1's multi_logloss: 0.241159
# [17189]	training's multi_logloss: 0.0628292	valid_1's multi_logloss: 0.241153
# [17190]	training's multi_logloss: 0.0628162	valid_1's multi_logloss: 0.241145
# [17191]	training's multi_logloss: 0.0627916	valid_1's multi_logloss: 0.241127
# [17192]	training's multi_logloss: 0.0627705	valid_1's multi_logloss: 0.241111
# [17193]	training's multi_logloss: 0.0627516	valid_1's multi_logloss: 0.241095
# [17194]	training's multi_logloss: 0.0627414	valid_1's multi_logloss: 0.241084
# [17195]	training's multi_logloss: 0.0627321	valid_1's multi_logloss: 0.241081
# [17196]	training's multi_logloss: 0.06272	valid_1's multi_logloss: 0.241066
# [17197]	training's multi_logloss: 0.062715	valid_1's multi_logloss: 0.241065
# [17198]	training's multi_logloss: 0.062712	valid_1's multi_logloss: 0.241063
# [17199]	training's multi_logloss: 0.0627082	valid_1's multi_logloss: 0.241069
# [17200]	training's multi_logloss: 0.0626968	valid_1's multi_logloss: 0.241062
# [17201]	training's multi_logloss: 0.0626772	valid_1's multi_logloss: 0.241048
# [17202]	training's multi_logloss: 0.0626706	valid_1's multi_logloss: 0.241052
# [17203]	training's multi_logloss: 0.0626578	valid_1's multi_logloss: 0.241044
# [17204]	training's multi_logloss: 0.0626489	valid_1's multi_logloss: 0.24104
# [17205]	training's multi_logloss: 0.062633	valid_1's multi_logloss: 0.241025
# [17206]	training's multi_logloss: 0.062626	valid_1's multi_logloss: 0.24102
# [17207]	training's multi_logloss: 0.0626195	valid_1's multi_logloss: 0.241018
# [17208]	training's multi_logloss: 0.0626176	valid_1's multi_logloss: 0.241023
# [17209]	training's multi_logloss: 0.0626144	valid_1's multi_logloss: 0.241018
# [17210]	training's multi_logloss: 0.0626104	valid_1's multi_logloss: 0.241023
# [17211]	training's multi_logloss: 0.0626042	valid_1's multi_logloss: 0.241019
# [17212]	training's multi_logloss: 0.0625993	valid_1's multi_logloss: 0.241016
# [17213]	training's multi_logloss: 0.0625857	valid_1's multi_logloss: 0.241009
# [17214]	training's multi_logloss: 0.0625646	valid_1's multi_logloss: 0.241
# [17215]	training's multi_logloss: 0.0625521	valid_1's multi_logloss: 0.240995
# [17216]	training's multi_logloss: 0.062542	valid_1's multi_logloss: 0.240992
# [17217]	training's multi_logloss: 0.0625358	valid_1's multi_logloss: 0.240994
# [17218]	training's multi_logloss: 0.062528	valid_1's multi_logloss: 0.240989
# [17219]	training's multi_logloss: 0.0625252	valid_1's multi_logloss: 0.240993
# [17220]	training's multi_logloss: 0.0625119	valid_1's multi_logloss: 0.24098
# [17221]	training's multi_logloss: 0.0624971	valid_1's multi_logloss: 0.240972
# [17222]	training's multi_logloss: 0.0624904	valid_1's multi_logloss: 0.240964
# [17223]	training's multi_logloss: 0.0624863	valid_1's multi_logloss: 0.240963
# [17224]	training's multi_logloss: 0.0624808	valid_1's multi_logloss: 0.240962
# [17225]	training's multi_logloss: 0.0624628	valid_1's multi_logloss: 0.240945
# [17226]	training's multi_logloss: 0.0624546	valid_1's multi_logloss: 0.240937
# [17227]	training's multi_logloss: 0.0624501	valid_1's multi_logloss: 0.240937
# [17228]	training's multi_logloss: 0.062446	valid_1's multi_logloss: 0.240931
# [17229]	training's multi_logloss: 0.0624308	valid_1's multi_logloss: 0.240925
# [17230]	training's multi_logloss: 0.0624149	valid_1's multi_logloss: 0.240913
# [17231]	training's multi_logloss: 0.062408	valid_1's multi_logloss: 0.24092
# [17232]	training's multi_logloss: 0.0623912	valid_1's multi_logloss: 0.2409
# [17233]	training's multi_logloss: 0.0623742	valid_1's multi_logloss: 0.24089
# [17234]	training's multi_logloss: 0.0623668	valid_1's multi_logloss: 0.240884
# [17235]	training's multi_logloss: 0.0623607	valid_1's multi_logloss: 0.240881
# [17236]	training's multi_logloss: 0.0623572	valid_1's multi_logloss: 0.240876
# [17237]	training's multi_logloss: 0.0623328	valid_1's multi_logloss: 0.240857
# [17238]	training's multi_logloss: 0.0623117	valid_1's multi_logloss: 0.240844
# [17239]	training's multi_logloss: 0.0622971	valid_1's multi_logloss: 0.240834
# [17240]	training's multi_logloss: 0.0622837	valid_1's multi_logloss: 0.240825
# [17241]	training's multi_logloss: 0.0622732	valid_1's multi_logloss: 0.24082
# [17242]	training's multi_logloss: 0.0622559	valid_1's multi_logloss: 0.240817
# [17243]	training's multi_logloss: 0.0622496	valid_1's multi_logloss: 0.240816
# [17244]	training's multi_logloss: 0.0622456	valid_1's multi_logloss: 0.240816
# [17245]	training's multi_logloss: 0.0622345	valid_1's multi_logloss: 0.240808
# [17246]	training's multi_logloss: 0.062225	valid_1's multi_logloss: 0.240809
# [17247]	training's multi_logloss: 0.0622174	valid_1's multi_logloss: 0.240808
# [17248]	training's multi_logloss: 0.0622141	valid_1's multi_logloss: 0.240804
# [17249]	training's multi_logloss: 0.0622109	valid_1's multi_logloss: 0.240806
# [17250]	training's multi_logloss: 0.0622041	valid_1's multi_logloss: 0.240801
# [17251]	training's multi_logloss: 0.0621907	valid_1's multi_logloss: 0.240789
# [17252]	training's multi_logloss: 0.0621857	valid_1's multi_logloss: 0.240788
# [17253]	training's multi_logloss: 0.0621814	valid_1's multi_logloss: 0.240786
# [17254]	training's multi_logloss: 0.0621742	valid_1's multi_logloss: 0.240782
# [17255]	training's multi_logloss: 0.0621683	valid_1's multi_logloss: 0.240781
# [17256]	training's multi_logloss: 0.0621656	valid_1's multi_logloss: 0.240782
# [17257]	training's multi_logloss: 0.0621617	valid_1's multi_logloss: 0.240781
# [17258]	training's multi_logloss: 0.0621569	valid_1's multi_logloss: 0.240785
# [17259]	training's multi_logloss: 0.0621532	valid_1's multi_logloss: 0.240786
# [17260]	training's multi_logloss: 0.0621455	valid_1's multi_logloss: 0.240784
# [17261]	training's multi_logloss: 0.0621354	valid_1's multi_logloss: 0.240782
# [17262]	training's multi_logloss: 0.0621312	valid_1's multi_logloss: 0.240783
# [17263]	training's multi_logloss: 0.0621305	valid_1's multi_logloss: 0.240787
# [17264]	training's multi_logloss: 0.0621265	valid_1's multi_logloss: 0.240789
# [17265]	training's multi_logloss: 0.0621199	valid_1's multi_logloss: 0.240786
# [17266]	training's multi_logloss: 0.0621192	valid_1's multi_logloss: 0.240798
# [17267]	training's multi_logloss: 0.0621185	valid_1's multi_logloss: 0.240806
# [17268]	training's multi_logloss: 0.0621142	valid_1's multi_logloss: 0.240805
# [17269]	training's multi_logloss: 0.0621099	valid_1's multi_logloss: 0.240802
# [17270]	training's multi_logloss: 0.062106	valid_1's multi_logloss: 0.240806
# [17271]	training's multi_logloss: 0.0621051	valid_1's multi_logloss: 0.24081
# [17272]	training's multi_logloss: 0.0620891	valid_1's multi_logloss: 0.240804
# [17273]	training's multi_logloss: 0.0620797	valid_1's multi_logloss: 0.240804
# [17274]	training's multi_logloss: 0.0620675	valid_1's multi_logloss: 0.240795
# [17275]	training's multi_logloss: 0.0620566	valid_1's multi_logloss: 0.24078
# [17276]	training's multi_logloss: 0.0620464	valid_1's multi_logloss: 0.240782
# [17277]	training's multi_logloss: 0.0620365	valid_1's multi_logloss: 0.240785
# [17278]	training's multi_logloss: 0.0620279	valid_1's multi_logloss: 0.240784
# [17279]	training's multi_logloss: 0.0620121	valid_1's multi_logloss: 0.240774
# [17280]	training's multi_logloss: 0.0620037	valid_1's multi_logloss: 0.240772
# [17281]	training's multi_logloss: 0.0619877	valid_1's multi_logloss: 0.240761
# [17282]	training's multi_logloss: 0.0619766	valid_1's multi_logloss: 0.240757
# [17283]	training's multi_logloss: 0.0619654	valid_1's multi_logloss: 0.240752
# [17284]	training's multi_logloss: 0.0619598	valid_1's multi_logloss: 0.240749
# [17285]	training's multi_logloss: 0.0619568	valid_1's multi_logloss: 0.240753
# [17286]	training's multi_logloss: 0.0619492	valid_1's multi_logloss: 0.240752
# [17287]	training's multi_logloss: 0.0619432	valid_1's multi_logloss: 0.240755
# [17288]	training's multi_logloss: 0.0619331	valid_1's multi_logloss: 0.240755
# [17289]	training's multi_logloss: 0.0619193	valid_1's multi_logloss: 0.240743
# [17290]	training's multi_logloss: 0.0619089	valid_1's multi_logloss: 0.240733
# [17291]	training's multi_logloss: 0.0619014	valid_1's multi_logloss: 0.240737
# [17292]	training's multi_logloss: 0.0618774	valid_1's multi_logloss: 0.240719
# [17293]	training's multi_logloss: 0.0618697	valid_1's multi_logloss: 0.240714
# [17294]	training's multi_logloss: 0.0618514	valid_1's multi_logloss: 0.240704
# [17295]	training's multi_logloss: 0.0618299	valid_1's multi_logloss: 0.240687
# [17296]	training's multi_logloss: 0.0618101	valid_1's multi_logloss: 0.240674
# [17297]	training's multi_logloss: 0.0617924	valid_1's multi_logloss: 0.240663
# [17298]	training's multi_logloss: 0.0617816	valid_1's multi_logloss: 0.240654
# [17299]	training's multi_logloss: 0.061773	valid_1's multi_logloss: 0.240645
# [17300]	training's multi_logloss: 0.061763	valid_1's multi_logloss: 0.240641
# [17301]	training's multi_logloss: 0.0617571	valid_1's multi_logloss: 0.240631
# [17302]	training's multi_logloss: 0.0617496	valid_1's multi_logloss: 0.240632
# [17303]	training's multi_logloss: 0.0617454	valid_1's multi_logloss: 0.240634
# [17304]	training's multi_logloss: 0.0617386	valid_1's multi_logloss: 0.240626
# [17305]	training's multi_logloss: 0.0617287	valid_1's multi_logloss: 0.240623
# [17306]	training's multi_logloss: 0.0617245	valid_1's multi_logloss: 0.240626
# [17307]	training's multi_logloss: 0.0617173	valid_1's multi_logloss: 0.240623
# [17308]	training's multi_logloss: 0.0617121	valid_1's multi_logloss: 0.240627
# [17309]	training's multi_logloss: 0.0617054	valid_1's multi_logloss: 0.240623
# [17310]	training's multi_logloss: 0.0616948	valid_1's multi_logloss: 0.24062
# [17311]	training's multi_logloss: 0.0616903	valid_1's multi_logloss: 0.240619
# [17312]	training's multi_logloss: 0.0616777	valid_1's multi_logloss: 0.24061
# [17313]	training's multi_logloss: 0.0616723	valid_1's multi_logloss: 0.240611
# [17314]	training's multi_logloss: 0.0616647	valid_1's multi_logloss: 0.240614
# [17315]	training's multi_logloss: 0.0616612	valid_1's multi_logloss: 0.240613
# [17316]	training's multi_logloss: 0.061659	valid_1's multi_logloss: 0.240621
# [17317]	training's multi_logloss: 0.0616529	valid_1's multi_logloss: 0.240627
# [17318]	training's multi_logloss: 0.0616404	valid_1's multi_logloss: 0.240626
# [17319]	training's multi_logloss: 0.0616272	valid_1's multi_logloss: 0.240621
# [17320]	training's multi_logloss: 0.0616213	valid_1's multi_logloss: 0.240617
# [17321]	training's multi_logloss: 0.0616113	valid_1's multi_logloss: 0.240613
# [17322]	training's multi_logloss: 0.0616033	valid_1's multi_logloss: 0.240609
# [17323]	training's multi_logloss: 0.0615975	valid_1's multi_logloss: 0.240609
# [17324]	training's multi_logloss: 0.0615892	valid_1's multi_logloss: 0.2406
# [17325]	training's multi_logloss: 0.0615741	valid_1's multi_logloss: 0.240594
# [17326]	training's multi_logloss: 0.0615546	valid_1's multi_logloss: 0.240573
# [17327]	training's multi_logloss: 0.061543	valid_1's multi_logloss: 0.240568
# [17328]	training's multi_logloss: 0.0615346	valid_1's multi_logloss: 0.240562
# [17329]	training's multi_logloss: 0.0615192	valid_1's multi_logloss: 0.240553
# [17330]	training's multi_logloss: 0.0615106	valid_1's multi_logloss: 0.240554
# [17331]	training's multi_logloss: 0.0614993	valid_1's multi_logloss: 0.240548
# [17332]	training's multi_logloss: 0.0614904	valid_1's multi_logloss: 0.240551
# [17333]	training's multi_logloss: 0.0614782	valid_1's multi_logloss: 0.240546
# [17334]	training's multi_logloss: 0.0614721	valid_1's multi_logloss: 0.240545
# [17335]	training's multi_logloss: 0.0614546	valid_1's multi_logloss: 0.240535
# [17336]	training's multi_logloss: 0.0614438	valid_1's multi_logloss: 0.240525
# [17337]	training's multi_logloss: 0.0614335	valid_1's multi_logloss: 0.240517
# [17338]	training's multi_logloss: 0.0614212	valid_1's multi_logloss: 0.240509
# [17339]	training's multi_logloss: 0.0614126	valid_1's multi_logloss: 0.240505
# [17340]	training's multi_logloss: 0.0614095	valid_1's multi_logloss: 0.240514
# [17341]	training's multi_logloss: 0.0613999	valid_1's multi_logloss: 0.240501
# [17342]	training's multi_logloss: 0.0613911	valid_1's multi_logloss: 0.240491
# [17343]	training's multi_logloss: 0.0613816	valid_1's multi_logloss: 0.24048
# [17344]	training's multi_logloss: 0.0613703	valid_1's multi_logloss: 0.240484
# [17345]	training's multi_logloss: 0.0613581	valid_1's multi_logloss: 0.240474
# [17346]	training's multi_logloss: 0.0613543	valid_1's multi_logloss: 0.240474
# [17347]	training's multi_logloss: 0.0613431	valid_1's multi_logloss: 0.240475
# [17348]	training's multi_logloss: 0.0613342	valid_1's multi_logloss: 0.240475
# [17349]	training's multi_logloss: 0.0613308	valid_1's multi_logloss: 0.240481
# [17350]	training's multi_logloss: 0.0613205	valid_1's multi_logloss: 0.240482
# [17351]	training's multi_logloss: 0.06131	valid_1's multi_logloss: 0.240471
# [17352]	training's multi_logloss: 0.0612951	valid_1's multi_logloss: 0.240458
# [17353]	training's multi_logloss: 0.0612853	valid_1's multi_logloss: 0.240442
# [17354]	training's multi_logloss: 0.0612688	valid_1's multi_logloss: 0.240427
# [17355]	training's multi_logloss: 0.0612535	valid_1's multi_logloss: 0.240415
# [17356]	training's multi_logloss: 0.0612388	valid_1's multi_logloss: 0.240404
# [17357]	training's multi_logloss: 0.0612289	valid_1's multi_logloss: 0.240396
# [17358]	training's multi_logloss: 0.0612163	valid_1's multi_logloss: 0.24039
# [17359]	training's multi_logloss: 0.0612077	valid_1's multi_logloss: 0.240387
# [17360]	training's multi_logloss: 0.061199	valid_1's multi_logloss: 0.240385
# [17361]	training's multi_logloss: 0.0611927	valid_1's multi_logloss: 0.240389
# [17362]	training's multi_logloss: 0.0611848	valid_1's multi_logloss: 0.240385
# [17363]	training's multi_logloss: 0.0611615	valid_1's multi_logloss: 0.240363
# [17364]	training's multi_logloss: 0.0611561	valid_1's multi_logloss: 0.240361
# [17365]	training's multi_logloss: 0.0611332	valid_1's multi_logloss: 0.240349
# [17366]	training's multi_logloss: 0.0611191	valid_1's multi_logloss: 0.240338
# [17367]	training's multi_logloss: 0.0611069	valid_1's multi_logloss: 0.240332
# [17368]	training's multi_logloss: 0.0611011	valid_1's multi_logloss: 0.240325
# [17369]	training's multi_logloss: 0.0610895	valid_1's multi_logloss: 0.240314
# [17370]	training's multi_logloss: 0.0610796	valid_1's multi_logloss: 0.240307
# [17371]	training's multi_logloss: 0.0610717	valid_1's multi_logloss: 0.240301
# [17372]	training's multi_logloss: 0.0610669	valid_1's multi_logloss: 0.240299
# [17373]	training's multi_logloss: 0.0610586	valid_1's multi_logloss: 0.240292
# [17374]	training's multi_logloss: 0.0610526	valid_1's multi_logloss: 0.240291
# [17375]	training's multi_logloss: 0.0610482	valid_1's multi_logloss: 0.240296
# [17376]	training's multi_logloss: 0.0610409	valid_1's multi_logloss: 0.240295
# [17377]	training's multi_logloss: 0.0610327	valid_1's multi_logloss: 0.240289
# [17378]	training's multi_logloss: 0.0610171	valid_1's multi_logloss: 0.24028
# [17379]	training's multi_logloss: 0.0609944	valid_1's multi_logloss: 0.240259
# [17380]	training's multi_logloss: 0.0609813	valid_1's multi_logloss: 0.240246
# [17381]	training's multi_logloss: 0.0609742	valid_1's multi_logloss: 0.240245
# [17382]	training's multi_logloss: 0.0609683	valid_1's multi_logloss: 0.240242
# [17383]	training's multi_logloss: 0.0609471	valid_1's multi_logloss: 0.240225
# [17384]	training's multi_logloss: 0.0609404	valid_1's multi_logloss: 0.240217
# [17385]	training's multi_logloss: 0.0609342	valid_1's multi_logloss: 0.24021
# [17386]	training's multi_logloss: 0.0609295	valid_1's multi_logloss: 0.24021
# [17387]	training's multi_logloss: 0.0609264	valid_1's multi_logloss: 0.240212
# [17388]	training's multi_logloss: 0.0609156	valid_1's multi_logloss: 0.24021
# [17389]	training's multi_logloss: 0.0609053	valid_1's multi_logloss: 0.240207
# [17390]	training's multi_logloss: 0.0608959	valid_1's multi_logloss: 0.240202
# [17391]	training's multi_logloss: 0.0608826	valid_1's multi_logloss: 0.240184
# [17392]	training's multi_logloss: 0.0608744	valid_1's multi_logloss: 0.240174
# [17393]	training's multi_logloss: 0.0608676	valid_1's multi_logloss: 0.240172
# [17394]	training's multi_logloss: 0.0608581	valid_1's multi_logloss: 0.240168
# [17395]	training's multi_logloss: 0.0608461	valid_1's multi_logloss: 0.240167
# [17396]	training's multi_logloss: 0.0608316	valid_1's multi_logloss: 0.24015
# [17397]	training's multi_logloss: 0.0608255	valid_1's multi_logloss: 0.240146
# [17398]	training's multi_logloss: 0.0608197	valid_1's multi_logloss: 0.240152
# [17399]	training's multi_logloss: 0.0608051	valid_1's multi_logloss: 0.240138
# [17400]	training's multi_logloss: 0.0608001	valid_1's multi_logloss: 0.240139
# [17401]	training's multi_logloss: 0.0607963	valid_1's multi_logloss: 0.240144
# [17402]	training's multi_logloss: 0.0607932	valid_1's multi_logloss: 0.240141
# [17403]	training's multi_logloss: 0.06079	valid_1's multi_logloss: 0.240149
# [17404]	training's multi_logloss: 0.0607816	valid_1's multi_logloss: 0.240145
# [17405]	training's multi_logloss: 0.0607675	valid_1's multi_logloss: 0.240133
# [17406]	training's multi_logloss: 0.0607611	valid_1's multi_logloss: 0.240125
# [17407]	training's multi_logloss: 0.0607463	valid_1's multi_logloss: 0.240116
# [17408]	training's multi_logloss: 0.0607426	valid_1's multi_logloss: 0.240122
# [17409]	training's multi_logloss: 0.0607352	valid_1's multi_logloss: 0.240119
# [17410]	training's multi_logloss: 0.0607312	valid_1's multi_logloss: 0.240127
# [17411]	training's multi_logloss: 0.0607235	valid_1's multi_logloss: 0.240126
# [17412]	training's multi_logloss: 0.0607187	valid_1's multi_logloss: 0.240124
# [17413]	training's multi_logloss: 0.0606972	valid_1's multi_logloss: 0.2401
# [17414]	training's multi_logloss: 0.0606908	valid_1's multi_logloss: 0.240095
# [17415]	training's multi_logloss: 0.0606792	valid_1's multi_logloss: 0.240089
# [17416]	training's multi_logloss: 0.0606747	valid_1's multi_logloss: 0.240088
# [17417]	training's multi_logloss: 0.0606659	valid_1's multi_logloss: 0.240081
# [17418]	training's multi_logloss: 0.0606526	valid_1's multi_logloss: 0.240076
# [17419]	training's multi_logloss: 0.0606389	valid_1's multi_logloss: 0.240067
# [17420]	training's multi_logloss: 0.0606343	valid_1's multi_logloss: 0.240064
# [17421]	training's multi_logloss: 0.0606297	valid_1's multi_logloss: 0.240059
# [17422]	training's multi_logloss: 0.060621	valid_1's multi_logloss: 0.240052
# [17423]	training's multi_logloss: 0.0606149	valid_1's multi_logloss: 0.240054
# [17424]	training's multi_logloss: 0.0606084	valid_1's multi_logloss: 0.24005
# [17425]	training's multi_logloss: 0.060606	valid_1's multi_logloss: 0.240051
# [17426]	training's multi_logloss: 0.0606045	valid_1's multi_logloss: 0.240057
# [17427]	training's multi_logloss: 0.0605978	valid_1's multi_logloss: 0.24006
# [17428]	training's multi_logloss: 0.0605954	valid_1's multi_logloss: 0.240063
# [17429]	training's multi_logloss: 0.0605907	valid_1's multi_logloss: 0.240062
# [17430]	training's multi_logloss: 0.0605854	valid_1's multi_logloss: 0.240066
# [17431]	training's multi_logloss: 0.0605742	valid_1's multi_logloss: 0.240054
# [17432]	training's multi_logloss: 0.0605678	valid_1's multi_logloss: 0.24006
# [17433]	training's multi_logloss: 0.0605421	valid_1's multi_logloss: 0.240036
# [17434]	training's multi_logloss: 0.0605291	valid_1's multi_logloss: 0.240027
# [17435]	training's multi_logloss: 0.0605172	valid_1's multi_logloss: 0.240022
# [17436]	training's multi_logloss: 0.060511	valid_1's multi_logloss: 0.240018
# [17437]	training's multi_logloss: 0.0604901	valid_1's multi_logloss: 0.239989
# [17438]	training's multi_logloss: 0.060477	valid_1's multi_logloss: 0.239979
# [17439]	training's multi_logloss: 0.0604695	valid_1's multi_logloss: 0.23998
# [17440]	training's multi_logloss: 0.0604605	valid_1's multi_logloss: 0.239976
# [17441]	training's multi_logloss: 0.0604475	valid_1's multi_logloss: 0.23996
# ...
# [21624]	training's multi_logloss: 0.0308014	valid_1's multi_logloss: 0.229085
# [21625]	training's multi_logloss: 0.0307862	valid_1's multi_logloss: 0.229071
# [21626]	training's multi_logloss: 0.0307778	valid_1's multi_logloss: 0.229064
# [21627]	training's multi_logloss: 0.0307709	valid_1's multi_logloss: 0.229064
# [21628]	training's multi_logloss: 0.0307663	valid_1's multi_logloss: 0.229066
# [21629]	training's multi_logloss: 0.0307597	valid_1's multi_logloss: 0.229071
# [21630]	training's multi_logloss: 0.0307537	valid_1's multi_logloss: 0.22907
# [21631]	training's multi_logloss: 0.030748	valid_1's multi_logloss: 0.229065
# [21632]	training's multi_logloss: 0.0307446	valid_1's multi_logloss: 0.229067
# [21633]	training's multi_logloss: 0.0307396	valid_1's multi_logloss: 0.229069
# [21634]	training's multi_logloss: 0.0307292	valid_1's multi_logloss: 0.22906
# [21635]	training's multi_logloss: 0.0307266	valid_1's multi_logloss: 0.229057
# [21636]	training's multi_logloss: 0.0307181	valid_1's multi_logloss: 0.229054
# [21637]	training's multi_logloss: 0.0307117	valid_1's multi_logloss: 0.229053
# [21638]	training's multi_logloss: 0.0307022	valid_1's multi_logloss: 0.229049
# [21639]	training's multi_logloss: 0.0306943	valid_1's multi_logloss: 0.229044
# [21640]	training's multi_logloss: 0.0306864	valid_1's multi_logloss: 0.229039
# [21641]	training's multi_logloss: 0.0306833	valid_1's multi_logloss: 0.22904
# [21642]	training's multi_logloss: 0.0306803	valid_1's multi_logloss: 0.229037
# [21643]	training's multi_logloss: 0.0306743	valid_1's multi_logloss: 0.229033
# [21644]	training's multi_logloss: 0.0306667	valid_1's multi_logloss: 0.22903
# [21645]	training's multi_logloss: 0.0306649	valid_1's multi_logloss: 0.229037
# [21646]	training's multi_logloss: 0.0306592	valid_1's multi_logloss: 0.229033
# [21647]	training's multi_logloss: 0.030655	valid_1's multi_logloss: 0.229033
# [21648]	training's multi_logloss: 0.0306521	valid_1's multi_logloss: 0.229037
# [21649]	training's multi_logloss: 0.0306451	valid_1's multi_logloss: 0.229027
# [21650]	training's multi_logloss: 0.0306406	valid_1's multi_logloss: 0.229023
# [21651]	training's multi_logloss: 0.0306375	valid_1's multi_logloss: 0.229018
# [21652]	training's multi_logloss: 0.0306312	valid_1's multi_logloss: 0.229018
# [21653]	training's multi_logloss: 0.0306304	valid_1's multi_logloss: 0.229022
# [21654]	training's multi_logloss: 0.0306271	valid_1's multi_logloss: 0.229022
# [21655]	training's multi_logloss: 0.0306216	valid_1's multi_logloss: 0.229023
# [21656]	training's multi_logloss: 0.0306203	valid_1's multi_logloss: 0.229026
# [21657]	training's multi_logloss: 0.0306187	valid_1's multi_logloss: 0.229028
# [21658]	training's multi_logloss: 0.0306127	valid_1's multi_logloss: 0.229026
# [21659]	training's multi_logloss: 0.0306113	valid_1's multi_logloss: 0.229034
# [21660]	training's multi_logloss: 0.0306034	valid_1's multi_logloss: 0.229037
# [21661]	training's multi_logloss: 0.0305982	valid_1's multi_logloss: 0.229038
# [21662]	training's multi_logloss: 0.0305943	valid_1's multi_logloss: 0.229039
# [21663]	training's multi_logloss: 0.0305856	valid_1's multi_logloss: 0.229036
# [21664]	training's multi_logloss: 0.0305727	valid_1's multi_logloss: 0.229028
# [21665]	training's multi_logloss: 0.0305686	valid_1's multi_logloss: 0.229028
# [21666]	training's multi_logloss: 0.030567	valid_1's multi_logloss: 0.229034
# [21667]	training's multi_logloss: 0.0305607	valid_1's multi_logloss: 0.22903
# [21668]	training's multi_logloss: 0.0305521	valid_1's multi_logloss: 0.229029
# [21669]	training's multi_logloss: 0.0305472	valid_1's multi_logloss: 0.229024
# [21670]	training's multi_logloss: 0.0305396	valid_1's multi_logloss: 0.22902
# [21671]	training's multi_logloss: 0.0305328	valid_1's multi_logloss: 0.229019
# [21672]	training's multi_logloss: 0.0305251	valid_1's multi_logloss: 0.229011
# [21673]	training's multi_logloss: 0.0305202	valid_1's multi_logloss: 0.229002
# [21674]	training's multi_logloss: 0.0305141	valid_1's multi_logloss: 0.228998
# [21675]	training's multi_logloss: 0.0305079	valid_1's multi_logloss: 0.228994
# [21676]	training's multi_logloss: 0.0305011	valid_1's multi_logloss: 0.22899
# [21677]	training's multi_logloss: 0.0305001	valid_1's multi_logloss: 0.228991
# [21678]	training's multi_logloss: 0.030492	valid_1's multi_logloss: 0.228985
# [21679]	training's multi_logloss: 0.0304875	valid_1's multi_logloss: 0.228981
# [21680]	training's multi_logloss: 0.0304847	valid_1's multi_logloss: 0.228989
# [21681]	training's multi_logloss: 0.0304785	valid_1's multi_logloss: 0.228991
# [21682]	training's multi_logloss: 0.0304719	valid_1's multi_logloss: 0.228992
# [21683]	training's multi_logloss: 0.0304636	valid_1's multi_logloss: 0.228986
# [21684]	training's multi_logloss: 0.0304551	valid_1's multi_logloss: 0.228984
# [21685]	training's multi_logloss: 0.0304482	valid_1's multi_logloss: 0.22898
# [21686]	training's multi_logloss: 0.0304432	valid_1's multi_logloss: 0.228979
# [21687]	training's multi_logloss: 0.0304405	valid_1's multi_logloss: 0.228977
# [21688]	training's multi_logloss: 0.0304331	valid_1's multi_logloss: 0.228976
# [21689]	training's multi_logloss: 0.0304297	valid_1's multi_logloss: 0.228974
# [21690]	training's multi_logloss: 0.0304281	valid_1's multi_logloss: 0.228976
# [21691]	training's multi_logloss: 0.0304255	valid_1's multi_logloss: 0.228976
# [21692]	training's multi_logloss: 0.0304215	valid_1's multi_logloss: 0.228976
# [21693]	training's multi_logloss: 0.0304181	valid_1's multi_logloss: 0.228974
# [21694]	training's multi_logloss: 0.0304086	valid_1's multi_logloss: 0.228967
# [21695]	training's multi_logloss: 0.0304055	valid_1's multi_logloss: 0.228972
# [21696]	training's multi_logloss: 0.0304024	valid_1's multi_logloss: 0.228975
# [21697]	training's multi_logloss: 0.0304007	valid_1's multi_logloss: 0.228977
# [21698]	training's multi_logloss: 0.0303947	valid_1's multi_logloss: 0.228976
# [21699]	training's multi_logloss: 0.0303887	valid_1's multi_logloss: 0.228975
# [21700]	training's multi_logloss: 0.0303856	valid_1's multi_logloss: 0.228979
# [21701]	training's multi_logloss: 0.0303774	valid_1's multi_logloss: 0.228978
# [21702]	training's multi_logloss: 0.030374	valid_1's multi_logloss: 0.22898
# [21703]	training's multi_logloss: 0.0303708	valid_1's multi_logloss: 0.228984
# [21704]	training's multi_logloss: 0.0303647	valid_1's multi_logloss: 0.228983
# [21705]	training's multi_logloss: 0.0303633	valid_1's multi_logloss: 0.228991
# [21706]	training's multi_logloss: 0.0303558	valid_1's multi_logloss: 0.228987
# [21707]	training's multi_logloss: 0.0303527	valid_1's multi_logloss: 0.228987
# [21708]	training's multi_logloss: 0.0303454	valid_1's multi_logloss: 0.22898
# [21709]	training's multi_logloss: 0.0303403	valid_1's multi_logloss: 0.228978
# [21710]	training's multi_logloss: 0.0303358	valid_1's multi_logloss: 0.228976
# [21711]	training's multi_logloss: 0.0303295	valid_1's multi_logloss: 0.228974
# [21712]	training's multi_logloss: 0.0303247	valid_1's multi_logloss: 0.228975
# [21713]	training's multi_logloss: 0.0303163	valid_1's multi_logloss: 0.228969
# [21714]	training's multi_logloss: 0.0303091	valid_1's multi_logloss: 0.228967
# [21715]	training's multi_logloss: 0.0303009	valid_1's multi_logloss: 0.228963
# [21716]	training's multi_logloss: 0.0302945	valid_1's multi_logloss: 0.22896
# [21717]	training's multi_logloss: 0.0302916	valid_1's multi_logloss: 0.228966
# [21718]	training's multi_logloss: 0.0302837	valid_1's multi_logloss: 0.228963
# [21719]	training's multi_logloss: 0.0302806	valid_1's multi_logloss: 0.22896
# [21720]	training's multi_logloss: 0.0302767	valid_1's multi_logloss: 0.228958
# [21721]	training's multi_logloss: 0.0302736	valid_1's multi_logloss: 0.228957
# [21722]	training's multi_logloss: 0.0302673	valid_1's multi_logloss: 0.228959
# [21723]	training's multi_logloss: 0.0302588	valid_1's multi_logloss: 0.228955
# [21724]	training's multi_logloss: 0.0302573	valid_1's multi_logloss: 0.228956
# [21725]	training's multi_logloss: 0.0302534	valid_1's multi_logloss: 0.228956
# [21726]	training's multi_logloss: 0.0302513	valid_1's multi_logloss: 0.22896
# [21727]	training's multi_logloss: 0.030246	valid_1's multi_logloss: 0.228964
# [21728]	training's multi_logloss: 0.0302401	valid_1's multi_logloss: 0.228963
# [21729]	training's multi_logloss: 0.0302361	valid_1's multi_logloss: 0.228976
# [21730]	training's multi_logloss: 0.0302314	valid_1's multi_logloss: 0.228985
# [21731]	training's multi_logloss: 0.0302242	valid_1's multi_logloss: 0.228978
# [21732]	training's multi_logloss: 0.0302179	valid_1's multi_logloss: 0.228976
# [21733]	training's multi_logloss: 0.0302105	valid_1's multi_logloss: 0.228971
# [21734]	training's multi_logloss: 0.0302073	valid_1's multi_logloss: 0.22897
# [21735]	training's multi_logloss: 0.030205	valid_1's multi_logloss: 0.228979
# [21736]	training's multi_logloss: 0.0302011	valid_1's multi_logloss: 0.228975
# [21737]	training's multi_logloss: 0.0301995	valid_1's multi_logloss: 0.228979
# [21738]	training's multi_logloss: 0.0301972	valid_1's multi_logloss: 0.228979
# [21739]	training's multi_logloss: 0.0301935	valid_1's multi_logloss: 0.228983
# [21740]	training's multi_logloss: 0.0301873	valid_1's multi_logloss: 0.228978
# [21741]	training's multi_logloss: 0.0301839	valid_1's multi_logloss: 0.228979
# [21742]	training's multi_logloss: 0.0301763	valid_1's multi_logloss: 0.228972
# [21743]	training's multi_logloss: 0.0301713	valid_1's multi_logloss: 0.228973
# [21744]	training's multi_logloss: 0.0301644	valid_1's multi_logloss: 0.228966
# [21745]	training's multi_logloss: 0.0301583	valid_1's multi_logloss: 0.228964
# [21746]	training's multi_logloss: 0.0301545	valid_1's multi_logloss: 0.228963
# [21747]	training's multi_logloss: 0.0301515	valid_1's multi_logloss: 0.228965
# [21748]	training's multi_logloss: 0.030146	valid_1's multi_logloss: 0.228959
# [21749]	training's multi_logloss: 0.0301424	valid_1's multi_logloss: 0.228964
# [21750]	training's multi_logloss: 0.030136	valid_1's multi_logloss: 0.228972
# [21751]	training's multi_logloss: 0.0301299	valid_1's multi_logloss: 0.228971
# [21752]	training's multi_logloss: 0.0301268	valid_1's multi_logloss: 0.228971
# [21753]	training's multi_logloss: 0.0301221	valid_1's multi_logloss: 0.228962
# [21754]	training's multi_logloss: 0.0301181	valid_1's multi_logloss: 0.228967
# [21755]	training's multi_logloss: 0.0301111	valid_1's multi_logloss: 0.228966
# [21756]	training's multi_logloss: 0.0301071	valid_1's multi_logloss: 0.228969
# [21757]	training's multi_logloss: 0.0301016	valid_1's multi_logloss: 0.228969
# [21758]	training's multi_logloss: 0.0300966	valid_1's multi_logloss: 0.228968
# [21759]	training's multi_logloss: 0.0300923	valid_1's multi_logloss: 0.228969
# [21760]	training's multi_logloss: 0.0300861	valid_1's multi_logloss: 0.228971
# [21761]	training's multi_logloss: 0.0300847	valid_1's multi_logloss: 0.228976
# [21762]	training's multi_logloss: 0.0300792	valid_1's multi_logloss: 0.228978
# [21763]	training's multi_logloss: 0.0300736	valid_1's multi_logloss: 0.228972
# [21764]	training's multi_logloss: 0.0300702	valid_1's multi_logloss: 0.22897
# [21765]	training's multi_logloss: 0.030064	valid_1's multi_logloss: 0.228971
# [21766]	training's multi_logloss: 0.0300566	valid_1's multi_logloss: 0.228971
# [21767]	training's multi_logloss: 0.0300529	valid_1's multi_logloss: 0.228973
# [21768]	training's multi_logloss: 0.0300503	valid_1's multi_logloss: 0.228974
# [21769]	training's multi_logloss: 0.030047	valid_1's multi_logloss: 0.228978
# [21770]	training's multi_logloss: 0.0300419	valid_1's multi_logloss: 0.228971
# [21771]	training's multi_logloss: 0.030038	valid_1's multi_logloss: 0.228965
# [21772]	training's multi_logloss: 0.0300361	valid_1's multi_logloss: 0.22897
# [21773]	training's multi_logloss: 0.0300297	valid_1's multi_logloss: 0.228976
# [21774]	training's multi_logloss: 0.0300243	valid_1's multi_logloss: 0.228978
# [21775]	training's multi_logloss: 0.0300213	valid_1's multi_logloss: 0.22899
# [21776]	training's multi_logloss: 0.0300173	valid_1's multi_logloss: 0.228985
# [21777]	training's multi_logloss: 0.0300132	valid_1's multi_logloss: 0.228987
# [21778]	training's multi_logloss: 0.0300105	valid_1's multi_logloss: 0.228988
# [21779]	training's multi_logloss: 0.0300048	valid_1's multi_logloss: 0.228977
# [21780]	training's multi_logloss: 0.0299983	valid_1's multi_logloss: 0.22897
# [21781]	training's multi_logloss: 0.029993	valid_1's multi_logloss: 0.228969
# [21782]	training's multi_logloss: 0.0299914	valid_1's multi_logloss: 0.228976
# [21783]	training's multi_logloss: 0.0299866	valid_1's multi_logloss: 0.228976
# [21784]	training's multi_logloss: 0.029983	valid_1's multi_logloss: 0.22898
# [21785]	training's multi_logloss: 0.0299806	valid_1's multi_logloss: 0.228979
# [21786]	training's multi_logloss: 0.0299776	valid_1's multi_logloss: 0.228977
# [21787]	training's multi_logloss: 0.029975	valid_1's multi_logloss: 0.228979
# [21788]	training's multi_logloss: 0.0299722	valid_1's multi_logloss: 0.228983
# [21789]	training's multi_logloss: 0.0299699	valid_1's multi_logloss: 0.228987
# [21790]	training's multi_logloss: 0.0299652	valid_1's multi_logloss: 0.228985
# [21791]	training's multi_logloss: 0.0299612	valid_1's multi_logloss: 0.228987
# [21792]	training's multi_logloss: 0.0299547	valid_1's multi_logloss: 0.228986
# [21793]	training's multi_logloss: 0.029951	valid_1's multi_logloss: 0.228989
# [21794]	training's multi_logloss: 0.0299424	valid_1's multi_logloss: 0.228987
# [21795]	training's multi_logloss: 0.0299362	valid_1's multi_logloss: 0.228986
# [21796]	training's multi_logloss: 0.0299312	valid_1's multi_logloss: 0.228985
# [21797]	training's multi_logloss: 0.0299275	valid_1's multi_logloss: 0.228984
# [21798]	training's multi_logloss: 0.0299267	valid_1's multi_logloss: 0.228985
# [21799]	training's multi_logloss: 0.0299254	valid_1's multi_logloss: 0.228983
# [21800]	training's multi_logloss: 0.0299197	valid_1's multi_logloss: 0.228982
# [21801]	training's multi_logloss: 0.029912	valid_1's multi_logloss: 0.228978
# [21802]	training's multi_logloss: 0.0299078	valid_1's multi_logloss: 0.228975
# [21803]	training's multi_logloss: 0.0299058	valid_1's multi_logloss: 0.22898
# [21804]	training's multi_logloss: 0.0299014	valid_1's multi_logloss: 0.228983
# [21805]	training's multi_logloss: 0.0298995	valid_1's multi_logloss: 0.228993
# [21806]	training's multi_logloss: 0.0298941	valid_1's multi_logloss: 0.228993
# [21807]	training's multi_logloss: 0.0298929	valid_1's multi_logloss: 0.228998
# [21808]	training's multi_logloss: 0.029888	valid_1's multi_logloss: 0.229003
# [21809]	training's multi_logloss: 0.0298832	valid_1's multi_logloss: 0.229
# [21810]	training's multi_logloss: 0.0298791	valid_1's multi_logloss: 0.229004
# [21811]	training's multi_logloss: 0.0298703	valid_1's multi_logloss: 0.228998
# [21812]	training's multi_logloss: 0.0298665	valid_1's multi_logloss: 0.229003
# [21813]	training's multi_logloss: 0.0298622	valid_1's multi_logloss: 0.229003
# [21814]	training's multi_logloss: 0.0298579	valid_1's multi_logloss: 0.229006
# [21815]	training's multi_logloss: 0.0298519	valid_1's multi_logloss: 0.229005
# [21816]	training's multi_logloss: 0.0298442	valid_1's multi_logloss: 0.228999
# [21817]	training's multi_logloss: 0.0298376	valid_1's multi_logloss: 0.228995
# [21818]	training's multi_logloss: 0.0298277	valid_1's multi_logloss: 0.22899
# [21819]	training's multi_logloss: 0.0298207	valid_1's multi_logloss: 0.228992
# [21820]	training's multi_logloss: 0.0298094	valid_1's multi_logloss: 0.228984
# [21821]	training's multi_logloss: 0.0298028	valid_1's multi_logloss: 0.228978
# [21822]	training's multi_logloss: 0.0297957	valid_1's multi_logloss: 0.228973
# [21823]	training's multi_logloss: 0.0297877	valid_1's multi_logloss: 0.228968
# Early stopping, best iteration is:
# [21723]	training's multi_logloss: 0.0302588	valid_1's multi_logloss: 0.228955
# LGBMClassifier(bagging_fraction=1.0, bagging_freq=10, feature_fraction=1.0,
#                max_bin=512, max_depth=8, metric='multi_logloss',
#                num_iterations=28000, num_leaves=128, objective='multiclass',
#                task='train', verbose=0)

# %%
    # metrics = y_test, lgb_pred

# %%
lgb_pred = lgb.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(lgb_pred, y_test)
print('LightGBM accuracy score: {0:0.4f}'.format(accuracy_score(y_test, lgb_pred)))
# Out:
# LightGBM accuracy score: 0.9462

# %%
# Training set score
y_pred_train = lgb.predict(x_train)
print('LightGBM Model training-set accuracy score: {0:0.4f}'. format(accuracy_score(y_train, y_pred_train)))
# Testing set score
accuracy = accuracy_score(lgb_pred, y_test)
print('LightGBM Model testing-set accuracy score: {0:0.4f}'.format(accuracy_score(y_test, lgb_pred)))
# Out:
# LightGBM Model training-set accuracy score: 0.9966
# LightGBM Model testing-set accuracy score: 0.9462

# %%
# view confusion-matrix
# Print the Confusion Matrix and slice it into four pieces

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, lgb_pred)
print('Confusion matrix\n\n', cm)
# print('\nTrue Positives(TP) = ', cm[0,0])
# print('\nTrue Negatives(TN) = ', cm[1,1])
# print('\nFalse Positives(FP) = ', cm[0,1])
# print('\nFalse Negatives(FN) = ', cm[1,0])
# Out:
# Confusion matrix
#
#  [[47751  1118   577]
#  [ 3366 43651  2047]
#  [  360   498 48765]]

# %%
# # visualize confusion matrix with seaborn heatmap

# cm_matrix = pd.DataFrame(data=cm, columns=['Actual Positive:1', 'Actual Negative:0'], 
#                                  index=['Predict Positive:1', 'Predict Negative:0'])

# sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='YlGnBu')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10,8))
cm = confusion_matrix(y_test, lgb_pred)
cm_matrix = pd.DataFrame(data=cm, columns=['1', '2', '3'],
                                 index=['1', '2', '3'])
sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix\n")
plt.tight_layout()

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, lgb_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.93      0.97      0.95     49446
#            2       0.96      0.89      0.93     49064
#            3       0.95      0.98      0.97     49623
#
#     accuracy                           0.95    148133
#    macro avg       0.95      0.95      0.95    148133
# weighted avg       0.95      0.95      0.95    148133

# %% [markdown]
# ----

# %%
predict_train = lgb.predict(x_train)
print("train score : {}".format(lgb.score(x_train, y_train)))
predict_test = lgb.predict(x_test)

from sklearn.metrics import classification_report
print(classification_report(y_test, lgb.predict(x_test)))
print("test score : {}".format(lgb.score(x_test, y_test)))

# %% [markdown]
# ---

# %%
def get_clf_eval(y_test, lgb_pred):
    confusion = confusion_matrix(y_test, lgb_pred)
    accuracy = accuracy_score(y_test, lgb_pred)
    precision = precision_score(y_test, lgb_pred, average = 'macro')
    recall = recall_score(y_test, lgb_pred, average = 'macro')
    F1 = f1_score(y_test, lgb_pred, average = 'macro')
    # AUC = roc_auc_score(y_test, lgb_pred, multi_class='ovo')
    print('오차행렬:\n', confusion)
    print('\n정확도:{:.4f}'.format(accuracy))
    print('정밀도:{:.4f}'.format(precision))
    print('재현율:{:.4f}'.format(recall))
    print('F1:{:.4f}'.format(F1))
    # print('AUC:{:.4f}'.format(AUC))

# %%
get_clf_eval(y_test, lgb_pred)

# %% [markdown]
# ---

# %%
# plot_importance()를 이용한 피처 중요도 시각화

from lightgbm import plot_importance
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(figsize=(6, 6))
plot_importance(lgb, max_num_features=6, ax=ax) # 상위 6개만

# %% [markdown]
# ### 에러 측정

# %%
# mse = mean_squared_error(y_test, predict_test)
# r2 = r2_score(y_test, predict_test)

# %%
# print('Mean squared error: ', mse)
# print('R2 score: ', r2)

# %%
# final_result = pd.concat([y_test.reset_index(drop=True), pd.DataFrame(predict_test)], axis = 1)

# %%
# final_result.columns = ['label','predict']

# %%
# sns.regplot(x = 'label', y = 'predict', data = final_result)

# %% [markdown]
# ----

# %% [markdown]
# ### LGBMClassifier 상위 모델(?) -> HistGradientBoostingClassifier

# %%
# lgb_clf = lgb.LGBMClassifier(num_leaves=31, objective='binary')
# lgb_clf.fit(x_train, y_train)
# y_pred = lgb_clf.predict(x_test)
# accuracy_score(y_test, y_pred)

# d_train = lgb.Dataset(x_train, label=y_train)
# param = {'num_iterations': 100, 'learning_rate' : 0.1, 'max_depth' : -1, 'objective': 'binary', 'metric':'auc'}

# %%
# from sklearn.ensemble import HistGradientBoostingClassifier as hgbc

# %%
# hgbc.score(x_train)
