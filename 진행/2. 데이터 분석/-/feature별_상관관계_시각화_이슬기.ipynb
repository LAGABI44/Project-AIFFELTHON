# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score
# %matplotlib inline

import missingno as msno

# %%
df = pd.read_csv('/content/drive/MyDrive/슬기로운 건강생활/data/국민건강보험공단_건강검진정보_20211229.CSV', encoding='cp949')
df
# Out:
#         기준년도  가입자 일련번호  시도코드  성별코드  연령대 코드(5세단위)  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  \
# 0       2020         1    36     1             9        165          60  72.1
# 1       2020         2    27     2            13        150          65  81.0
# 2       2020         3    11     2            12        155          55  70.0
# 3       2020         4    31     1            13        160          70  90.8
# 4       2020         5    41     2            12        155          50  75.2
# ...      ...       ...   ...   ...           ...        ...         ...   ...
# 999995  2020    999996    41     2            13        145          55  81.0
# 999996  2020    999997    26     2            12        160          55  76.5
# 999997  2020    999998    48     1             9        175          70  85.0
# 999998  2020    999999    48     2             9        160          70  91.0
# 999999  2020   1000000    28     1            11        160          55  76.1
#
# ...

# %%
df.columns
# Out:
# Index(['기준년도', '가입자 일련번호', '시도코드', '성별코드', '연령대 코드(5세단위)', '신장(5Cm단위)',
#        '체중(5Kg 단위)', '허리둘레', '시력(좌)', '시력(우)', '청력(좌)', '청력(우)', '수축기 혈압',
#        '이완기 혈압', '식전혈당(공복혈당)', '총 콜레스테롤', '트리글리세라이드', 'HDL 콜레스테롤', 'LDL 콜레스테롤',
#        '혈색소', '요단백', '혈청크레아티닌', '(혈청지오티)AST', '(혈청지오티)ALT', '감마 지티피', '흡연상태',
#        '음주여부', '구강검진 수검여부', '치아우식증유무', '치석', '데이터 공개일자'],
#       dtype='object')

# %%
corr_df = df.corr()
corr_df = corr_df.apply(lambda x: round(x ,2))

# %% [markdown]
# #신장(5Cm단위)
# - 체중(5Kg 단위)

# %%
# 총 콜레스테롤 에 대한 다른 변수들의 상관관계
co = pd.DataFrame(corr_df["신장(5Cm단위)"].sort_values(ascending = False))  #Price에 대한 다른 변수 수치 뽑기, 내림차순 정렬
co.style.background_gradient(cmap='viridis')    #스타일 지정해서 범위 별 색깔 입히기
# Out:
# <style type="text/css">
# #T_60ec1_row0_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_60ec1_row1_col0 {
#   background-color: #7cd250;
#   color: #000000;
# }
# #T_60ec1_row2_col0 {
#   background-color: #46c06f;
#   color: #f1f1f1;
# }
# #T_60ec1_row3_col0 {
#   background-color: #42be71;
#   color: #f1f1f1;
# }
# #T_60ec1_row4_col0 {
#   background-color: #28ae80;
#   color: #f1f1f1;
# }
# #T_60ec1_row5_col0 {
#   background-color: #25ab82;
#   color: #f1f1f1;
# }
# #T_60ec1_row6_col0 {
#   background-color: #1e9b8a;
#   color: #f1f1f1;
# }
# #T_60ec1_row7_col0 {
#   background-color: #1f948c;
#   color: #f1f1f1;
# }
# #T_60ec1_row8_col0 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_60ec1_row9_col0, #T_60ec1_row10_col0 {
#   background-color: #218f8d;
#   color: #f1f1f1;
# }
# #T_60ec1_row11_col0, #T_60ec1_row12_col0 {
#   background-color: #228c8d;
#   color: #f1f1f1;
# }
# #T_60ec1_row13_col0 {
#   background-color: #23888e;
# ...

# %% [markdown]
# #체중(5Kg 단위)
# - 허리둘레
# - 신장(5Cm단위)

# %%
# 총 콜레스테롤 에 대한 다른 변수들의 상관관계
co = pd.DataFrame(corr_df["체중(5Kg 단위)"].sort_values(ascending = False))
co.style.background_gradient(cmap='viridis')    #스타일 지정해서 범위 별 색깔 입히기
# Out:
# <style type="text/css">
# #T_00980_row0_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_00980_row1_col0 {
#   background-color: #a0da39;
#   color: #000000;
# }
# #T_00980_row2_col0 {
#   background-color: #6ece58;
#   color: #000000;
# }
# #T_00980_row3_col0 {
#   background-color: #2fb47c;
#   color: #f1f1f1;
# }
# #T_00980_row4_col0 {
#   background-color: #21a585;
#   color: #f1f1f1;
# }
# #T_00980_row5_col0 {
#   background-color: #1f978b;
#   color: #f1f1f1;
# }
# #T_00980_row6_col0 {
#   background-color: #1f958b;
#   color: #f1f1f1;
# }
# #T_00980_row7_col0 {
#   background-color: #1f948c;
#   color: #f1f1f1;
# }
# #T_00980_row8_col0 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_00980_row9_col0, #T_00980_row10_col0, #T_00980_row11_col0 {
#   background-color: #228b8d;
#   color: #f1f1f1;
# }
# #T_00980_row12_col0 {
#   background-color: #24868e;
#   color: #f1f1f1;
# }
# #T_00980_row13_col0 {
#   background-color: #297a8e;
# ...

# %% [markdown]
# #허리둘레
# - 체중(5Kg 단위)

# %%
# 총 콜레스테롤 에 대한 다른 변수들의 상관관계
co = pd.DataFrame(corr_df["허리둘레"].sort_values(ascending = False))
co.style.background_gradient(cmap='viridis')    #스타일 지정해서 범위 별 색깔 입히기
# Out:
# <style type="text/css">
# #T_fad3f_row0_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_fad3f_row1_col0 {
#   background-color: #95d840;
#   color: #000000;
# }
# #T_fad3f_row2_col0 {
#   background-color: #1f978b;
#   color: #f1f1f1;
# }
# #T_fad3f_row3_col0 {
#   background-color: #1f958b;
#   color: #f1f1f1;
# }
# #T_fad3f_row4_col0 {
#   background-color: #228d8d;
#   color: #f1f1f1;
# }
# #T_fad3f_row5_col0 {
#   background-color: #23898e;
#   color: #f1f1f1;
# }
# #T_fad3f_row6_col0, #T_fad3f_row7_col0 {
#   background-color: #24868e;
#   color: #f1f1f1;
# }
# #T_fad3f_row8_col0 {
#   background-color: #26828e;
#   color: #f1f1f1;
# }
# #T_fad3f_row9_col0 {
#   background-color: #26818e;
#   color: #f1f1f1;
# }
# #T_fad3f_row10_col0 {
#   background-color: #287d8e;
#   color: #f1f1f1;
# }
# #T_fad3f_row11_col0 {
#   background-color: #2a788e;
#   color: #f1f1f1;
# }
# #T_fad3f_row12_col0, #T_fad3f_row13_col0 {
#   background-color: #2e6e8e;
# ...

# %% [markdown]
# #시력(좌)

# %%
# 총 콜레스테롤 에 대한 다른 변수들의 상관관계
co = pd.DataFrame(corr_df["시력(좌)"].sort_values(ascending = False))
co.style.background_gradient(cmap='viridis')    #스타일 지정해서 범위 별 색깔 입히기
# Out:
# <style type="text/css">
# #T_7950b_row0_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_7950b_row1_col0 {
#   background-color: #2c738e;
#   color: #f1f1f1;
# }
# #T_7950b_row2_col0 {
#   background-color: #3d4d8a;
#   color: #f1f1f1;
# }
# #T_7950b_row3_col0 {
#   background-color: #404588;
#   color: #f1f1f1;
# }
# #T_7950b_row4_col0, #T_7950b_row5_col0 {
#   background-color: #414287;
#   color: #f1f1f1;
# }
# #T_7950b_row6_col0 {
#   background-color: #424086;
#   color: #f1f1f1;
# }
# #T_7950b_row7_col0, #T_7950b_row8_col0, #T_7950b_row9_col0, #T_7950b_row10_col0, #T_7950b_row11_col0, #T_7950b_row12_col0, #T_7950b_row13_col0 {
#   background-color: #453581;
#   color: #f1f1f1;
# }
# #T_7950b_row14_col0, #T_7950b_row15_col0, #T_7950b_row16_col0, #T_7950b_row17_col0, #T_7950b_row18_col0 {
#   background-color: #46337f;
#   color: #f1f1f1;
# }
# #T_7950b_row19_col0, #T_7950b_row20_col0, #T_7950b_row21_col0 {
#   background-color: #46307e;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# #시력(우)

# %%
# 총 콜레스테롤 에 대한 다른 변수들의 상관관계
co = pd.DataFrame(corr_df["시력(우)"].sort_values(ascending = False))
co.style.background_gradient(cmap='viridis')    #스타일 지정해서 범위 별 색깔 입히기
# Out:
# <style type="text/css">
# #T_8cb3d_row0_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_8cb3d_row1_col0 {
#   background-color: #2c718e;
#   color: #f1f1f1;
# }
# #T_8cb3d_row2_col0 {
#   background-color: #3e4a89;
#   color: #f1f1f1;
# }
# #T_8cb3d_row3_col0, #T_8cb3d_row4_col0, #T_8cb3d_row5_col0 {
#   background-color: #424086;
#   color: #f1f1f1;
# }
# #T_8cb3d_row6_col0 {
#   background-color: #433e85;
#   color: #f1f1f1;
# }
# #T_8cb3d_row7_col0, #T_8cb3d_row8_col0, #T_8cb3d_row9_col0, #T_8cb3d_row10_col0, #T_8cb3d_row11_col0, #T_8cb3d_row12_col0, #T_8cb3d_row13_col0 {
#   background-color: #46337f;
#   color: #f1f1f1;
# }
# #T_8cb3d_row14_col0, #T_8cb3d_row15_col0, #T_8cb3d_row16_col0, #T_8cb3d_row17_col0 {
#   background-color: #46307e;
#   color: #f1f1f1;
# }
# #T_8cb3d_row18_col0, #T_8cb3d_row19_col0, #T_8cb3d_row20_col0 {
#   background-color: #472e7c;
#   color: #f1f1f1;
# }
# #T_8cb3d_row21_col0, #T_8cb3d_row22_col0 {
#   background-color: #472c7a;
# ...

# %%
# 총 콜레스테롤 에 대한 다른 변수들의 상관관계
co = pd.DataFrame(corr_df["청력(좌)"].sort_values(ascending = False))
co.style.background_gradient(cmap='viridis')    #스타일 지정해서 범위 별 색깔 입히기
# Out:
# <style type="text/css">
# #T_23ff2_row0_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_23ff2_row1_col0 {
#   background-color: #20a486;
#   color: #f1f1f1;
# }
# #T_23ff2_row2_col0 {
#   background-color: #375a8c;
#   color: #f1f1f1;
# }
# #T_23ff2_row3_col0 {
#   background-color: #472a7a;
#   color: #f1f1f1;
# }
# #T_23ff2_row4_col0 {
#   background-color: #482878;
#   color: #f1f1f1;
# }
# #T_23ff2_row5_col0, #T_23ff2_row6_col0 {
#   background-color: #482576;
#   color: #f1f1f1;
# }
# #T_23ff2_row7_col0, #T_23ff2_row8_col0 {
#   background-color: #482173;
#   color: #f1f1f1;
# }
# #T_23ff2_row9_col0 {
#   background-color: #481f70;
#   color: #f1f1f1;
# }
# #T_23ff2_row10_col0, #T_23ff2_row11_col0, #T_23ff2_row12_col0 {
#   background-color: #481b6d;
#   color: #f1f1f1;
# }
# #T_23ff2_row13_col0, #T_23ff2_row14_col0, #T_23ff2_row15_col0, #T_23ff2_row16_col0 {
#   background-color: #48186a;
#   color: #f1f1f1;
# }
# #T_23ff2_row17_col0, #T_23ff2_row18_col0 {
# ...

# %%
# 총 콜레스테롤 에 대한 다른 변수들의 상관관계
co = pd.DataFrame(corr_df["청력(우)"].sort_values(ascending = False))
co.style.background_gradient(cmap='viridis')    #스타일 지정해서 범위 별 색깔 입히기
# Out:
# <style type="text/css">
# #T_63de9_row0_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_63de9_row1_col0 {
#   background-color: #20a486;
#   color: #f1f1f1;
# }
# #T_63de9_row2_col0 {
#   background-color: #375a8c;
#   color: #f1f1f1;
# }
# #T_63de9_row3_col0 {
#   background-color: #472a7a;
#   color: #f1f1f1;
# }
# #T_63de9_row4_col0, #T_63de9_row5_col0, #T_63de9_row6_col0 {
#   background-color: #482576;
#   color: #f1f1f1;
# }
# #T_63de9_row7_col0, #T_63de9_row8_col0 {
#   background-color: #482173;
#   color: #f1f1f1;
# }
# #T_63de9_row9_col0 {
#   background-color: #481f70;
#   color: #f1f1f1;
# }
# #T_63de9_row10_col0, #T_63de9_row11_col0, #T_63de9_row12_col0, #T_63de9_row13_col0 {
#   background-color: #481b6d;
#   color: #f1f1f1;
# }
# #T_63de9_row14_col0, #T_63de9_row15_col0, #T_63de9_row16_col0 {
#   background-color: #48186a;
#   color: #f1f1f1;
# }
# #T_63de9_row17_col0, #T_63de9_row18_col0 {
#   background-color: #481668;
#   color: #f1f1f1;
# }
# ...

# %%
# 총 콜레스테롤 에 대한 다른 변수들의 상관관계
co = pd.DataFrame(corr_df["수축기 혈압"].sort_values(ascending = False))
co.style.background_gradient(cmap='viridis')    #스타일 지정해서 범위 별 색깔 입히기
# Out:
# <style type="text/css">
# #T_3692e_row0_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_3692e_row1_col0 {
#   background-color: #54c568;
#   color: #000000;
# }
# #T_3692e_row2_col0 {
#   background-color: #2e6e8e;
#   color: #f1f1f1;
# }
# #T_3692e_row3_col0 {
#   background-color: #33628d;
#   color: #f1f1f1;
# }
# #T_3692e_row4_col0 {
#   background-color: #38598c;
#   color: #f1f1f1;
# }
# #T_3692e_row5_col0 {
#   background-color: #3c4f8a;
#   color: #f1f1f1;
# }
# #T_3692e_row6_col0 {
#   background-color: #3d4d8a;
#   color: #f1f1f1;
# }
# #T_3692e_row7_col0 {
#   background-color: #3f4788;
#   color: #f1f1f1;
# }
# #T_3692e_row8_col0 {
#   background-color: #404588;
#   color: #f1f1f1;
# }
# #T_3692e_row9_col0 {
#   background-color: #443a83;
#   color: #f1f1f1;
# }
# #T_3692e_row10_col0, #T_3692e_row11_col0 {
#   background-color: #453882;
#   color: #f1f1f1;
# }
# #T_3692e_row12_col0, #T_3692e_row13_col0, #T_3692e_row14_col0 {
# ...

# %%
# 총 콜레스테롤 에 대한 다른 변수들의 상관관계
co = pd.DataFrame(corr_df["이완기 혈압"].sort_values(ascending = False))
co.style.background_gradient(cmap='viridis')    #스타일 지정해서 범위 별 색깔 입히기
# Out:
# <style type="text/css">
# #T_0a640_row0_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_0a640_row1_col0 {
#   background-color: #5ac864;
#   color: #000000;
# }
# #T_0a640_row2_col0 {
#   background-color: #2c718e;
#   color: #f1f1f1;
# }
# #T_0a640_row3_col0 {
#   background-color: #2d708e;
#   color: #f1f1f1;
# }
# #T_0a640_row4_col0 {
#   background-color: #2e6e8e;
#   color: #f1f1f1;
# }
# #T_0a640_row5_col0 {
#   background-color: #355e8d;
#   color: #f1f1f1;
# }
# #T_0a640_row6_col0 {
#   background-color: #38588c;
#   color: #f1f1f1;
# }
# #T_0a640_row7_col0 {
#   background-color: #39558c;
#   color: #f1f1f1;
# }
# #T_0a640_row8_col0 {
#   background-color: #3c508b;
#   color: #f1f1f1;
# }
# #T_0a640_row9_col0, #T_0a640_row10_col0, #T_0a640_row11_col0 {
#   background-color: #3d4e8a;
#   color: #f1f1f1;
# }
# #T_0a640_row12_col0 {
#   background-color: #3e4989;
#   color: #f1f1f1;
# }
# #T_0a640_row13_col0, #T_0a640_row14_col0 {
# ...

# %%
# 총 콜레스테롤 에 대한 다른 변수들의 상관관계
co = pd.DataFrame(corr_df["식전혈당(공복혈당)"].sort_values(ascending = False))
co.style.background_gradient(cmap='viridis')    #스타일 지정해서 범위 별 색깔 입히기
# Out:
# <style type="text/css">
# #T_9af67_row0_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_9af67_row1_col0 {
#   background-color: #34608d;
#   color: #f1f1f1;
# }
# #T_9af67_row2_col0 {
#   background-color: #38598c;
#   color: #f1f1f1;
# }
# #T_9af67_row3_col0 {
#   background-color: #3a538b;
#   color: #f1f1f1;
# }
# #T_9af67_row4_col0, #T_9af67_row5_col0 {
#   background-color: #3b518b;
#   color: #f1f1f1;
# }
# #T_9af67_row6_col0, #T_9af67_row7_col0 {
#   background-color: #3e4989;
#   color: #f1f1f1;
# }
# #T_9af67_row8_col0, #T_9af67_row9_col0 {
#   background-color: #3f4788;
#   color: #f1f1f1;
# }
# #T_9af67_row10_col0, #T_9af67_row11_col0 {
#   background-color: #404588;
#   color: #f1f1f1;
# }
# #T_9af67_row12_col0 {
#   background-color: #433d84;
#   color: #f1f1f1;
# }
# #T_9af67_row13_col0, #T_9af67_row14_col0 {
#   background-color: #443a83;
#   color: #f1f1f1;
# }
# #T_9af67_row15_col0, #T_9af67_row16_col0, #T_9af67_row17_col0 {
# ...

# %%
# 총 콜레스테롤 에 대한 다른 변수들의 상관관계
co = pd.DataFrame(corr_df["총 콜레스테롤"].sort_values(ascending = False))
co.style.background_gradient(cmap='viridis')    #스타일 지정해서 범위 별 색깔 입히기
# Out:
# <style type="text/css">
# #T_75e6e_row0_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_75e6e_row1_col0 {
#   background-color: #d8e219;
#   color: #000000;
# }
# #T_75e6e_row2_col0 {
#   background-color: #30698e;
#   color: #f1f1f1;
# }
# #T_75e6e_row3_col0 {
#   background-color: #31678e;
#   color: #f1f1f1;
# }
# #T_75e6e_row4_col0 {
#   background-color: #3a538b;
#   color: #f1f1f1;
# }
# #T_75e6e_row5_col0 {
#   background-color: #3e4989;
#   color: #f1f1f1;
# }
# #T_75e6e_row6_col0, #T_75e6e_row7_col0 {
#   background-color: #3f4788;
#   color: #f1f1f1;
# }
# #T_75e6e_row8_col0 {
#   background-color: #424186;
#   color: #f1f1f1;
# }
# #T_75e6e_row9_col0, #T_75e6e_row10_col0, #T_75e6e_row11_col0 {
#   background-color: #433d84;
#   color: #f1f1f1;
# }
# #T_75e6e_row12_col0, #T_75e6e_row13_col0 {
#   background-color: #443a83;
#   color: #f1f1f1;
# }
# #T_75e6e_row14_col0 {
#   background-color: #453882;
#   color: #f1f1f1;
# }
# ...

# %%
# 총 콜레스테롤 에 대한 다른 변수들의 상관관계
co = pd.DataFrame(corr_df["트리글리세라이드"].sort_values(ascending = False))
co.style.background_gradient(cmap='viridis')    #스타일 지정해서 범위 별 색깔 입히기
# Out:
# <style type="text/css">
# #T_01a00_row0_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_01a00_row1_col0 {
#   background-color: #25838e;
#   color: #f1f1f1;
# }
# #T_01a00_row2_col0 {
#   background-color: #26828e;
#   color: #f1f1f1;
# }
# #T_01a00_row3_col0 {
#   background-color: #27808e;
#   color: #f1f1f1;
# }
# #T_01a00_row4_col0 {
#   background-color: #297a8e;
#   color: #f1f1f1;
# }
# #T_01a00_row5_col0 {
#   background-color: #2a788e;
#   color: #f1f1f1;
# }
# #T_01a00_row6_col0 {
#   background-color: #2a768e;
#   color: #f1f1f1;
# }
# #T_01a00_row7_col0 {
#   background-color: #2d718e;
#   color: #f1f1f1;
# }
# #T_01a00_row8_col0 {
#   background-color: #2e6f8e;
#   color: #f1f1f1;
# }
# #T_01a00_row9_col0, #T_01a00_row10_col0 {
#   background-color: #2f6b8e;
#   color: #f1f1f1;
# }
# #T_01a00_row11_col0 {
#   background-color: #30698e;
#   color: #f1f1f1;
# }
# #T_01a00_row12_col0 {
#   background-color: #355f8d;
#   color: #f1f1f1;
# }
# ...

# %%
# 총 콜레스테롤 에 대한 다른 변수들의 상관관계
co = pd.DataFrame(corr_df["HDL 콜레스테롤"].sort_values(ascending = False))
co.style.background_gradient(cmap='viridis')    #스타일 지정해서 범위 별 색깔 입히기
# Out:
# <style type="text/css">
# #T_bc881_row0_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_bc881_row1_col0 {
#   background-color: #26828e;
#   color: #f1f1f1;
# }
# #T_bc881_row2_col0 {
#   background-color: #2a778e;
#   color: #f1f1f1;
# }
# #T_bc881_row3_col0, #T_bc881_row4_col0 {
#   background-color: #3a548c;
#   color: #f1f1f1;
# }
# #T_bc881_row5_col0, #T_bc881_row6_col0 {
#   background-color: #3d4e8a;
#   color: #f1f1f1;
# }
# #T_bc881_row7_col0 {
#   background-color: #3e4c8a;
#   color: #f1f1f1;
# }
# #T_bc881_row8_col0, #T_bc881_row9_col0 {
#   background-color: #3e4989;
#   color: #f1f1f1;
# }
# #T_bc881_row10_col0, #T_bc881_row11_col0, #T_bc881_row12_col0, #T_bc881_row13_col0, #T_bc881_row14_col0 {
#   background-color: #3f4788;
#   color: #f1f1f1;
# }
# #T_bc881_row15_col0, #T_bc881_row16_col0 {
#   background-color: #404588;
#   color: #f1f1f1;
# }
# #T_bc881_row17_col0 {
#   background-color: #424086;
#   color: #f1f1f1;
# }
# ...

# %%
# 총 콜레스테롤 에 대한 다른 변수들의 상관관계
co = pd.DataFrame(corr_df["LDL 콜레스테롤"].sort_values(ascending = False))
co.style.background_gradient(cmap='viridis')    #스타일 지정해서 범위 별 색깔 입히기
# Out:
# <style type="text/css">
# #T_85da5_row0_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_85da5_row1_col0 {
#   background-color: #d8e219;
#   color: #000000;
# }
# #T_85da5_row2_col0 {
#   background-color: #3f4889;
#   color: #f1f1f1;
# }
# #T_85da5_row3_col0, #T_85da5_row4_col0 {
#   background-color: #443b84;
#   color: #f1f1f1;
# }
# #T_85da5_row5_col0 {
#   background-color: #443983;
#   color: #f1f1f1;
# }
# #T_85da5_row6_col0, #T_85da5_row7_col0, #T_85da5_row8_col0 {
#   background-color: #453781;
#   color: #f1f1f1;
# }
# #T_85da5_row9_col0, #T_85da5_row10_col0 {
#   background-color: #46337f;
#   color: #f1f1f1;
# }
# #T_85da5_row11_col0, #T_85da5_row12_col0, #T_85da5_row13_col0 {
#   background-color: #46307e;
#   color: #f1f1f1;
# }
# #T_85da5_row14_col0, #T_85da5_row15_col0, #T_85da5_row16_col0, #T_85da5_row17_col0 {
#   background-color: #472e7c;
#   color: #f1f1f1;
# }
# #T_85da5_row18_col0, #T_85da5_row19_col0 {
#   background-color: #482878;
# ...

# %%
# 총 콜레스테롤 에 대한 다른 변수들의 상관관계
co = pd.DataFrame(corr_df["혈색소"].sort_values(ascending = False))
co.style.background_gradient(cmap='viridis')    #스타일 지정해서 범위 별 색깔 입히기
# Out:
# <style type="text/css">
# #T_b23cc_row0_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_b23cc_row1_col0 {
#   background-color: #3dbc74;
#   color: #f1f1f1;
# }
# #T_b23cc_row2_col0 {
#   background-color: #35b779;
#   color: #f1f1f1;
# }
# #T_b23cc_row3_col0 {
#   background-color: #2eb37c;
#   color: #f1f1f1;
# }
# #T_b23cc_row4_col0 {
#   background-color: #21a685;
#   color: #f1f1f1;
# }
# #T_b23cc_row5_col0 {
#   background-color: #1e9b8a;
#   color: #f1f1f1;
# }
# #T_b23cc_row6_col0 {
#   background-color: #1f998a;
#   color: #f1f1f1;
# }
# #T_b23cc_row7_col0 {
#   background-color: #1f968b;
#   color: #f1f1f1;
# }
# #T_b23cc_row8_col0 {
#   background-color: #1f948c;
#   color: #f1f1f1;
# }
# #T_b23cc_row9_col0 {
#   background-color: #20938c;
#   color: #f1f1f1;
# }
# #T_b23cc_row10_col0 {
#   background-color: #23898e;
#   color: #f1f1f1;
# }
# #T_b23cc_row11_col0, #T_b23cc_row12_col0, #T_b23cc_row13_col0 {
#   background-color: #25858e;
# ...

# %%
# 총 콜레스테롤 에 대한 다른 변수들의 상관관계
co = pd.DataFrame(corr_df["요단백"].sort_values(ascending = False))
co.style.background_gradient(cmap='viridis')    #스타일 지정해서 범위 별 색깔 입히기
# Out:
# <style type="text/css">
# #T_31d2e_row0_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_31d2e_row1_col0 {
#   background-color: #433e85;
#   color: #f1f1f1;
# }
# #T_31d2e_row2_col0 {
#   background-color: #453581;
#   color: #f1f1f1;
# }
# #T_31d2e_row3_col0 {
#   background-color: #482677;
#   color: #f1f1f1;
# }
# #T_31d2e_row4_col0, #T_31d2e_row5_col0 {
#   background-color: #482374;
#   color: #f1f1f1;
# }
# #T_31d2e_row6_col0, #T_31d2e_row7_col0 {
#   background-color: #482071;
#   color: #f1f1f1;
# }
# #T_31d2e_row8_col0, #T_31d2e_row9_col0, #T_31d2e_row10_col0 {
#   background-color: #481c6e;
#   color: #f1f1f1;
# }
# #T_31d2e_row11_col0, #T_31d2e_row12_col0 {
#   background-color: #481a6c;
#   color: #f1f1f1;
# }
# #T_31d2e_row13_col0, #T_31d2e_row14_col0, #T_31d2e_row15_col0, #T_31d2e_row16_col0 {
#   background-color: #481668;
#   color: #f1f1f1;
# }
# #T_31d2e_row17_col0, #T_31d2e_row18_col0 {
#   background-color: #471365;
#   color: #f1f1f1;
# }
# ...

# %%
# 총 콜레스테롤 에 대한 다른 변수들의 상관관계
co = pd.DataFrame(corr_df["혈청크레아티닌"].sort_values(ascending = False))
co.style.background_gradient(cmap='viridis')    #스타일 지정해서 범위 별 색깔 입히기
# Out:
# <style type="text/css">
# #T_9712a_row0_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_9712a_row1_col0 {
#   background-color: #297a8e;
#   color: #f1f1f1;
# }
# #T_9712a_row2_col0 {
#   background-color: #2b748e;
#   color: #f1f1f1;
# }
# #T_9712a_row3_col0 {
#   background-color: #2c718e;
#   color: #f1f1f1;
# }
# #T_9712a_row4_col0 {
#   background-color: #2d708e;
#   color: #f1f1f1;
# }
# #T_9712a_row5_col0 {
#   background-color: #2e6e8e;
#   color: #f1f1f1;
# }
# #T_9712a_row6_col0 {
#   background-color: #2f6c8e;
#   color: #f1f1f1;
# }
# #T_9712a_row7_col0 {
#   background-color: #355e8d;
#   color: #f1f1f1;
# }
# #T_9712a_row8_col0, #T_9712a_row9_col0, #T_9712a_row10_col0, #T_9712a_row11_col0 {
#   background-color: #365c8d;
#   color: #f1f1f1;
# }
# #T_9712a_row12_col0, #T_9712a_row13_col0, #T_9712a_row14_col0 {
#   background-color: #375a8c;
#   color: #f1f1f1;
# }
# #T_9712a_row15_col0 {
#   background-color: #38588c;
#   color: #f1f1f1;
# }
# ...

# %%
# 총 콜레스테롤 에 대한 다른 변수들의 상관관계
co = pd.DataFrame(corr_df["(혈청지오티)AST"].sort_values(ascending = False))
co.style.background_gradient(cmap='viridis')    #스타일 지정해서 범위 별 색깔 입히기
# Out:
# <style type="text/css">
# #T_9b4ed_row0_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_9b4ed_row1_col0 {
#   background-color: #60ca60;
#   color: #000000;
# }
# #T_9b4ed_row2_col0 {
#   background-color: #2d708e;
#   color: #f1f1f1;
# }
# #T_9b4ed_row3_col0, #T_9b4ed_row4_col0 {
#   background-color: #463480;
#   color: #f1f1f1;
# }
# #T_9b4ed_row5_col0 {
#   background-color: #46307e;
#   color: #f1f1f1;
# }
# #T_9b4ed_row6_col0 {
#   background-color: #472e7c;
#   color: #f1f1f1;
# }
# #T_9b4ed_row7_col0 {
#   background-color: #472c7a;
#   color: #f1f1f1;
# }
# #T_9b4ed_row8_col0, #T_9b4ed_row9_col0, #T_9b4ed_row10_col0 {
#   background-color: #482878;
#   color: #f1f1f1;
# }
# #T_9b4ed_row11_col0 {
#   background-color: #482576;
#   color: #f1f1f1;
# }
# #T_9b4ed_row12_col0, #T_9b4ed_row13_col0, #T_9b4ed_row14_col0 {
#   background-color: #482173;
#   color: #f1f1f1;
# }
# #T_9b4ed_row15_col0 {
#   background-color: #481f70;
#   color: #f1f1f1;
# }
# ...

# %%
# 총 콜레스테롤 에 대한 다른 변수들의 상관관계
co = pd.DataFrame(corr_df["(혈청지오티)ALT"].sort_values(ascending = False))
co.style.background_gradient(cmap='viridis')    #스타일 지정해서 범위 별 색깔 입히기
# Out:
# <style type="text/css">
# #T_37b4a_row0_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_37b4a_row1_col0 {
#   background-color: #6ece58;
#   color: #000000;
# }
# #T_37b4a_row2_col0 {
#   background-color: #25848e;
#   color: #f1f1f1;
# }
# #T_37b4a_row3_col0 {
#   background-color: #2f6c8e;
#   color: #f1f1f1;
# }
# #T_37b4a_row4_col0, #T_37b4a_row5_col0 {
#   background-color: #31688e;
#   color: #f1f1f1;
# }
# #T_37b4a_row6_col0 {
#   background-color: #38598c;
#   color: #f1f1f1;
# }
# #T_37b4a_row7_col0 {
#   background-color: #3a538b;
#   color: #f1f1f1;
# }
# #T_37b4a_row8_col0 {
#   background-color: #3b518b;
#   color: #f1f1f1;
# }
# #T_37b4a_row9_col0 {
#   background-color: #3c4f8a;
#   color: #f1f1f1;
# }
# #T_37b4a_row10_col0 {
#   background-color: #3d4d8a;
#   color: #f1f1f1;
# }
# #T_37b4a_row11_col0 {
#   background-color: #404588;
#   color: #f1f1f1;
# }
# #T_37b4a_row12_col0 {
#   background-color: #414287;
#   color: #f1f1f1;
# }
# ...

# %%
# 총 콜레스테롤 에 대한 다른 변수들의 상관관계
co = pd.DataFrame(corr_df["감마 지티피"].sort_values(ascending = False))
co.style.background_gradient(cmap='viridis')    #스타일 지정해서 범위 별 색깔 입히기
# Out:
# <style type="text/css">
# #T_386b8_row0_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_386b8_row1_col0 {
#   background-color: #228c8d;
#   color: #f1f1f1;
# }
# #T_386b8_row2_col0 {
#   background-color: #25848e;
#   color: #f1f1f1;
# }
# #T_386b8_row3_col0 {
#   background-color: #287d8e;
#   color: #f1f1f1;
# }
# #T_386b8_row4_col0 {
#   background-color: #2c738e;
#   color: #f1f1f1;
# }
# #T_386b8_row5_col0 {
#   background-color: #2e6f8e;
#   color: #f1f1f1;
# }
# #T_386b8_row6_col0, #T_386b8_row7_col0 {
#   background-color: #2f6b8e;
#   color: #f1f1f1;
# }
# #T_386b8_row8_col0, #T_386b8_row9_col0 {
#   background-color: #31678e;
#   color: #f1f1f1;
# }
# #T_386b8_row10_col0 {
#   background-color: #33638d;
#   color: #f1f1f1;
# }
# #T_386b8_row11_col0 {
#   background-color: #34618d;
#   color: #f1f1f1;
# }
# #T_386b8_row12_col0 {
#   background-color: #375b8d;
#   color: #f1f1f1;
# }
# #T_386b8_row13_col0, #T_386b8_row14_col0 {
# ...

# %%
# 총 콜레스테롤 에 대한 다른 변수들의 상관관계
co = pd.DataFrame(corr_df["흡연상태"].sort_values(ascending = False))
co.style.background_gradient(cmap='viridis')    #스타일 지정해서 범위 별 색깔 입히기
# Out:
# <style type="text/css">
# #T_2eebe_row0_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_2eebe_row1_col0 {
#   background-color: #38b977;
#   color: #f1f1f1;
# }
# #T_2eebe_row2_col0 {
#   background-color: #2db27d;
#   color: #f1f1f1;
# }
# #T_2eebe_row3_col0 {
#   background-color: #22a884;
#   color: #f1f1f1;
# }
# #T_2eebe_row4_col0 {
#   background-color: #1fa188;
#   color: #f1f1f1;
# }
# #T_2eebe_row5_col0 {
#   background-color: #1f968b;
#   color: #f1f1f1;
# }
# #T_2eebe_row6_col0 {
#   background-color: #1f948c;
#   color: #f1f1f1;
# }
# #T_2eebe_row7_col0 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_2eebe_row8_col0 {
#   background-color: #228c8d;
#   color: #f1f1f1;
# }
# #T_2eebe_row9_col0 {
#   background-color: #25848e;
#   color: #f1f1f1;
# }
# #T_2eebe_row10_col0 {
#   background-color: #26828e;
#   color: #f1f1f1;
# }
# #T_2eebe_row11_col0, #T_2eebe_row12_col0 {
#   background-color: #26818e;
#   color: #f1f1f1;
# }
# ...

# %%
# 총 콜레스테롤 에 대한 다른 변수들의 상관관계
co = pd.DataFrame(corr_df["음주여부"].sort_values(ascending = False))
co.style.background_gradient(cmap='viridis')    #스타일 지정해서 범위 별 색깔 입히기
# Out:
# <style type="text/css">
# #T_8dc12_row0_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_8dc12_row1_col0 {
#   background-color: #1f958b;
#   color: #f1f1f1;
# }
# #T_8dc12_row2_col0 {
#   background-color: #228d8d;
#   color: #f1f1f1;
# }
# #T_8dc12_row3_col0 {
#   background-color: #25838e;
#   color: #f1f1f1;
# }
# #T_8dc12_row4_col0 {
#   background-color: #26828e;
#   color: #f1f1f1;
# }
# #T_8dc12_row5_col0 {
#   background-color: #2c738e;
#   color: #f1f1f1;
# }
# #T_8dc12_row6_col0, #T_8dc12_row7_col0 {
#   background-color: #31678e;
#   color: #f1f1f1;
# }
# #T_8dc12_row8_col0 {
#   background-color: #32658e;
#   color: #f1f1f1;
# }
# #T_8dc12_row9_col0 {
#   background-color: #33638d;
#   color: #f1f1f1;
# }
# #T_8dc12_row10_col0, #T_8dc12_row11_col0, #T_8dc12_row12_col0 {
#   background-color: #34618d;
#   color: #f1f1f1;
# }
# #T_8dc12_row13_col0, #T_8dc12_row14_col0 {
#   background-color: #355f8d;
#   color: #f1f1f1;
# }
# #T_8dc12_row15_col0 {
# ...

# %%
# 총 콜레스테롤 에 대한 다른 변수들의 상관관계
co = pd.DataFrame(corr_df["구강검진 수검여부"].sort_values(ascending = False))
co.style.background_gradient(cmap='viridis')    #스타일 지정해서 범위 별 색깔 입히기
# Out:
# <style type="text/css">
# #T_d37ca_row0_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_d37ca_row1_col0, #T_d37ca_row2_col0 {
#   background-color: #433d84;
#   color: #f1f1f1;
# }
# #T_d37ca_row3_col0 {
#   background-color: #453882;
#   color: #f1f1f1;
# }
# #T_d37ca_row4_col0, #T_d37ca_row5_col0, #T_d37ca_row6_col0 {
#   background-color: #463480;
#   color: #f1f1f1;
# }
# #T_d37ca_row7_col0 {
#   background-color: #46327e;
#   color: #f1f1f1;
# }
# #T_d37ca_row8_col0 {
#   background-color: #472f7d;
#   color: #f1f1f1;
# }
# #T_d37ca_row9_col0, #T_d37ca_row10_col0, #T_d37ca_row11_col0 {
#   background-color: #472c7a;
#   color: #f1f1f1;
# }
# #T_d37ca_row12_col0, #T_d37ca_row13_col0 {
#   background-color: #482979;
#   color: #f1f1f1;
# }
# #T_d37ca_row14_col0, #T_d37ca_row15_col0, #T_d37ca_row16_col0, #T_d37ca_row17_col0 {
#   background-color: #482677;
#   color: #f1f1f1;
# }
# #T_d37ca_row18_col0 {
#   background-color: #482475;
#   color: #f1f1f1;
# }
# ...

# %%
# 총 콜레스테롤 에 대한 다른 변수들의 상관관계
co = pd.DataFrame(corr_df["치아우식증유무"].sort_values(ascending = False))
co.style.background_gradient(cmap='viridis')    #스타일 지정해서 범위 별 색깔 입히기
# Out:
# <style type="text/css">
# #T_312c1_row0_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_312c1_row1_col0 {
#   background-color: #3b528b;
#   color: #f1f1f1;
# }
# #T_312c1_row2_col0 {
#   background-color: #472e7c;
#   color: #f1f1f1;
# }
# #T_312c1_row3_col0, #T_312c1_row4_col0, #T_312c1_row5_col0 {
#   background-color: #482576;
#   color: #f1f1f1;
# }
# #T_312c1_row6_col0, #T_312c1_row7_col0, #T_312c1_row8_col0, #T_312c1_row9_col0, #T_312c1_row10_col0 {
#   background-color: #482173;
#   color: #f1f1f1;
# }
# #T_312c1_row11_col0, #T_312c1_row12_col0, #T_312c1_row13_col0, #T_312c1_row14_col0 {
#   background-color: #481f70;
#   color: #f1f1f1;
# }
# #T_312c1_row15_col0, #T_312c1_row16_col0, #T_312c1_row17_col0, #T_312c1_row18_col0, #T_312c1_row19_col0, #T_312c1_row20_col0 {
#   background-color: #481c6e;
#   color: #f1f1f1;
# }
# #T_312c1_row21_col0, #T_312c1_row22_col0, #T_312c1_row23_col0 {
#   background-color: #48186a;
#   color: #f1f1f1;
# }
# ...

# %%
# 총 콜레스테롤 에 대한 다른 변수들의 상관관계
co = pd.DataFrame(corr_df["치석"].sort_values(ascending = False))
co.style.background_gradient(cmap='viridis')    #스타일 지정해서 범위 별 색깔 입히기
# Out:
# <style type="text/css">
# #T_a363a_row0_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_a363a_row1_col0 {
#   background-color: #39568c;
#   color: #f1f1f1;
# }
# #T_a363a_row2_col0 {
#   background-color: #443b84;
#   color: #f1f1f1;
# }
# #T_a363a_row3_col0 {
#   background-color: #46307e;
#   color: #f1f1f1;
# }
# #T_a363a_row4_col0, #T_a363a_row5_col0, #T_a363a_row6_col0, #T_a363a_row7_col0 {
#   background-color: #472d7b;
#   color: #f1f1f1;
# }
# #T_a363a_row8_col0, #T_a363a_row9_col0, #T_a363a_row10_col0 {
#   background-color: #472a7a;
#   color: #f1f1f1;
# }
# #T_a363a_row11_col0, #T_a363a_row12_col0, #T_a363a_row13_col0, #T_a363a_row14_col0 {
#   background-color: #482878;
#   color: #f1f1f1;
# }
# #T_a363a_row15_col0, #T_a363a_row16_col0 {
#   background-color: #482475;
#   color: #f1f1f1;
# }
# #T_a363a_row17_col0, #T_a363a_row18_col0, #T_a363a_row19_col0, #T_a363a_row20_col0 {
#   background-color: #482173;
#   color: #f1f1f1;
# }
# ...
